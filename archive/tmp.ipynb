# %%
import sejin_tool_copy as tl

import wandb

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split

# %%
import json
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
import torch.nn.functional as F
import torch.optim as optim

import os
import json
from sklearn.preprocessing import LabelEncoder

import numpy as np
import math


def get_word_list(num_folders_start, num_folders_end):
    folder_path = 'morpheme/01'

    # 단어들을 저장할 리스트
    word_list = []
    
    # 파일 이름 얻어오기
    file_names = [f for f in os.listdir(folder_path) if f.endswith('.json') and "F_morpheme" in f]

    # 파일 이름을 번호 순서대로 정렬하기
    file_names.sort(key=lambda x: int(x.split('_')[2][4:]))

    file_names = file_names[:500]
    
    for idx in range(num_folders_start, num_folders_end + 1):
        for filename in file_names:
            file_path = os.path.join(folder_path, filename)
            
            with open(file_path, 'r', encoding='utf-8') as file:
                data = json.load(file)
                
                # 'data' 키 안의 요소들 순회
                for item in data['data']:
                    for attribute in item['attributes']:
                        word_list.append(attribute['name'])
                    

    # Label Encoder 초기화 및 학습
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(word_list)
    
    # 인코딩된 라벨과 원래 라벨 매칭하여 출력
    i = 0
    for original, encoded in zip(word_list, encoded_labels):
        print(f"{i}  Original Label: {original}, Encoded Label: {encoded}")
        i += 1
    
    return encoded_labels


def get_sequence_files(num_folders_start, num_folders_end):
    base_folder_path = 'keypoints'

    # 전체 시퀀스를 저장할 리스트
    sequence_files = []

    for idx in range(num_folders_start, num_folders_end + 1):

        folder_path = os.path.join(base_folder_path, f'{idx:02d}')
        
        # 각 폴더의 파일 이름을 저장할 리스트
        # folder_files = []
        
        # 파일 이름 얻어오기
        file_names = [f for f in os.listdir(folder_path) if "F" in f]
        
        # 파일 이름을 번호 순서대로 정렬하기
        file_names.sort(key=lambda x: int(x.split('_')[2][4:]))
        
        file_names = file_names[:500]
        
        for filename in file_names:
            file_path = os.path.join(folder_path, filename)
            
            json_names = [f for f in os.listdir(file_path) if "F" in f]       
            json_names.sort(key=lambda x: int(x.split('_')[5]))
            json_paths = []
            
            for i, jsonname in enumerate(json_names):
                if i % 3 == 0:
                    json_path = os.path.join(file_path, jsonname)
                    json_paths.append(json_path)
            
            sequence_files.append(json_paths)
        
    return sequence_files
                

def extract_keypoints(json_data):
    
    def append_coordinates(keypoints_list, array, dimensions, offset=0):
        step = dimensions + 1  # dimensions + 1 because of the confidence score
        for i in range(0, len(keypoints_list), step):
            idx = i // step + offset
            if dimensions == 2:
                array[idx] = [keypoints_list[i], keypoints_list[i + 1], 0]
            elif dimensions == 3:
                array[idx] = [keypoints_list[i], keypoints_list[i + 1], keypoints_list[i + 2]]
                
                
    keypoint_types_2d = ['face_keypoints_2d', 'pose_keypoints_2d', 'hand_left_keypoints_2d', 'hand_right_keypoints_2d']
    keypoint_types_3d = ['face_keypoints_3d', 'pose_keypoints_3d', 'hand_left_keypoints_3d', 'hand_right_keypoints_3d']
    
    #키포인트 개수 계산
    num_keypoints_2d = sum(len(json_data['people'][key]) // 3 for key in keypoint_types_2d if key in json_data['people'])
    num_keypoints_3d = sum(len(json_data['people'][key]) // 4 for key in keypoint_types_3d if key in json_data['people'])

    if num_keypoints_3d == 0: 
        #3d가 비어있을 때
        #numpy배열 초기화
        keypoints_2d = np.zeros((num_keypoints_2d, 3))  # (x, y, 0)
        
        offset_2d = 0
        
        for key in keypoint_types_2d:
            if key in json_data['people']:
                append_coordinates(json_data['people'][key], keypoints_2d, dimensions=2, offset=offset_2d)
                offset_2d += len(json_data['people'][key]) // 3
                
        keypoints = keypoints_2d
        
    else:
        #3d가 있을 때
        #키포인트 개수 계산

        #numpy배열 초기화
        keypoints_3d = np.zeros((num_keypoints_3d, 3))  # (x, y, z)

        offset_3d = 0

        for key in keypoint_types_3d:
            if key in json_data['people']:
                append_coordinates(json_data['people'][key], keypoints_3d, dimensions=3, offset=offset_3d)
                offset_3d += len(json_data['people'][key]) // 4

        keypoints = keypoints_3d
    
    return keypoints

def collate_fn(batch):    
    # batch는 keypoints와 labels의 튜플로 구성된 리스트
    keypoints, labels, idx = zip(*batch)
        
    # 각 keypoints 리스트에서 face, pose, left_hand, right_hand를 각각 분리
    face_keypoints = [k[0] for k in keypoints]
    pose_keypoints = [k[1] for k in keypoints]
    left_hand_keypoints = [k[2] for k in keypoints]
    right_hand_keypoints = [k[3] for k in keypoints]
    
    # keypoints는 3D 텐서이므로, 텐서 The line `리스트에서 시퀀스 길이(120)를 추출
    face_keypoints_padded = pad_sequence([k.permute(1, 0, 2) for k in face_keypoints], batch_first=True, padding_value=0)
    pose_keypoints_padded = pad_sequence([k.permute(1, 0, 2) for k in pose_keypoints], batch_first=True, padding_value=0)
    left_hand_keypoints_padded = pad_sequence([k.permute(1, 0, 2) for k in left_hand_keypoints], batch_first=True, padding_value=0)
    right_hand_keypoints_padded = pad_sequence([k.permute(1, 0, 2) for k in right_hand_keypoints], batch_first=True, padding_value=0)
    
    # 패딩 후 다시 원래 차원으로 복원
    face_keypoints_padded = face_keypoints_padded.permute(0, 2, 1, 3)
    pose_keypoints_padded = pose_keypoints_padded.permute(0, 2, 1, 3)
    left_hand_keypoints_padded = left_hand_keypoints_padded.permute(0, 2, 1, 3)
    right_hand_keypoints_padded = right_hand_keypoints_padded.permute(0, 2, 1, 3)
    
    # 각 시퀀스의 길이를 계산 (여기서는 모두 120이 동일함)
    lengths = torch.tensor([k.size(1) for k in keypoints[0]])
    
    
    # labels를 tensor로 변환
    labels = torch.tensor(labels)
    
    return (face_keypoints_padded,pose_keypoints_padded,left_hand_keypoints_padded,right_hand_keypoints_padded), labels, lengths, idx


class SignLanguageDataset(Dataset):
    def __init__(self, sequence_files, labels):
        self.data = []
        self.labels = labels
        for files in sequence_files:
            sequence = []
            for file in files:
                with open(file, 'r') as f:
                    json_data = json.load(f)
                    keypoints = extract_keypoints(json_data)
                    sequence.append(keypoints)
            self.data.append(sequence)
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        sequence = torch.tensor(self.data[idx], dtype=torch.float32)        
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        sequence = sequence.permute(2, 0, 1)
        
        # 데이터 분리: 얼굴, 왼손, 오른손, 포즈 (각각의 키포인트 개수는 데이터에 따라 설정)
        face_sequence = sequence[:, :, :70]  # 얼굴 keypoints
        pose_sequence = sequence[:, :, 70:95]  # 포즈 keypoints
        left_hand_sequence = sequence[:, :, 95:116]  # 왼손 keypoints
        right_hand_sequence = sequence[:, :, 116:137]  # 오른손 keypoints
        
        mean = torch.mean(face_sequence)
        std = torch.std(face_sequence)
        face_sequence = (face_sequence - mean) / std
        
        mean = torch.mean(pose_sequence)
        std = torch.std(pose_sequence)
        pose_sequence = (pose_sequence - mean) / std
        
        mean = torch.mean(left_hand_sequence)
        std = torch.std(left_hand_sequence)
        left_hand_sequence = (left_hand_sequence - mean) / std
        
        mean = torch.mean(right_hand_sequence)
        std = torch.std(right_hand_sequence)
        right_hand_sequence = (right_hand_sequence - mean) / std
        
        
        # 패딩 처리: 길이를 70으로 맞춤
        pose_sequence = F.pad(pose_sequence, (0, 70 - pose_sequence.size(2)), "constant", 0)
        left_hand_sequence = F.pad(left_hand_sequence, (0, 70 - left_hand_sequence.size(2)), "constant", 0)
        right_hand_sequence = F.pad(right_hand_sequence, (0, 70 - right_hand_sequence.size(2)), "constant", 0)

        # 마스크 생성: 패딩된 부분은 True, 나머지는 False
        pose_mask = pose_sequence.sum(dim=1) == 0  # 패딩된 부분은 모든 값이 0이므로 합이 0인 부분이 패딩된 부분
        left_hand_mask = left_hand_sequence.sum(dim=1) == 0
        right_hand_mask = right_hand_sequence.sum(dim=1) == 0
    
        return (face_sequence, pose_sequence, left_hand_sequence, right_hand_sequence), label, idx

class MultiEncoderTransformerModel(nn.Module):
    def __init__(self, input_dim, model_dim, num_heads, num_layers, num_classes):
        super(MultiEncoderTransformerModel, self).__init__()
        
        # Face Encoder
        self.face_input_fc = nn.Linear(input_dim, model_dim)
        self.face_positional_encoding = PositionalEncoding(dim_model=model_dim, dropout_p=0.1, max_len=500)
        face_encoder_layers = nn.TransformerEncoderLayer(d_model=model_dim, nhead=num_heads, batch_first=True)
        self.face_transformer_encoder = nn.TransformerEncoder(face_encoder_layers, num_layers)
        
        # Pose Encoder
        self.pose_input_fc = nn.Linear(input_dim, model_dim)
        self.pose_positional_encoding = PositionalEncoding(dim_model=model_dim, dropout_p=0.1, max_len=500)
        pose_encoder_layers = nn.TransformerEncoderLayer(d_model=model_dim, nhead=num_heads, batch_first=True)
        self.pose_transformer_encoder = nn.TransformerEncoder(pose_encoder_layers, num_layers)
        
        # Left Hand Encoder
        self.left_hand_input_fc = nn.Linear(input_dim, model_dim)
        self.left_hand_positional_encoding = PositionalEncoding(dim_model=model_dim, dropout_p=0.1, max_len=500)
        left_hand_encoder_layers = nn.TransformerEncoderLayer(d_model=model_dim, nhead=num_heads, batch_first=True)
        self.left_hand_transformer_encoder = nn.TransformerEncoder(left_hand_encoder_layers, num_layers)
        
        # Right Hand Encoder
        self.right_hand_input_fc = nn.Linear(input_dim, model_dim)
        self.right_hand_positional_encoding = PositionalEncoding(dim_model=model_dim, dropout_p=0.1, max_len=500)
        right_hand_encoder_layers = nn.TransformerEncoderLayer(d_model=model_dim, nhead=num_heads, batch_first=True)
        self.right_hand_transformer_encoder = nn.TransformerEncoder(right_hand_encoder_layers, num_layers)
        
        # 최종 결합 후 클래스 분류
        self.fc = nn.Linear(model_dim * 4, num_classes)  # 네 인코더 출력 결합

    def forward(self, face_input, pose_input, left_hand_input, right_hand_input, face_src_key_padding_mask=None, pose_src_key_padding_mask=None, left_src_key_padding_mask=None, right_src_key_padding_mask=None):
        # Face Encoder
        face_x = self.face_input_fc(face_input)
        face_x = self.face_positional_encoding(face_x)
        face_x = self.face_transformer_encoder(face_x, src_key_padding_mask=face_src_key_padding_mask)
        face_x = face_x.mean(dim=1)
        
        # Pose Encoder
        pose_x = self.pose_input_fc(pose_input)
        pose_x = self.pose_positional_encoding(pose_x)
        pose_x = self.pose_transformer_encoder(pose_x, src_key_padding_mask=pose_src_key_padding_mask)
        pose_x = pose_x.mean(dim=1)
        
        # Left Hand Encoder
        left_hand_x = self.left_hand_input_fc(left_hand_input)
        left_hand_x = self.left_hand_positional_encoding(left_hand_x)
        left_hand_x = self.left_hand_transformer_encoder(left_hand_x, src_key_padding_mask=left_src_key_padding_mask)
        left_hand_x = left_hand_x.mean(dim=1)
        
        # Right Hand Encoder
        right_hand_x = self.right_hand_input_fc(right_hand_input)
        right_hand_x = self.right_hand_positional_encoding(right_hand_x)
        right_hand_x = self.right_hand_transformer_encoder(right_hand_x, src_key_padding_mask=right_src_key_padding_mask)
        right_hand_x = right_hand_x.mean(dim=1)
        
        # 네 인코더의 출력 결합
        combined_x = torch.cat((face_x, left_hand_x, right_hand_x, pose_x), dim=-1)
        
        # Fully Connected Layer
        output = self.fc(combined_x)
        
        return output


class PositionalEncoding(nn.Module):
    def __init__(self, dim_model, dropout_p, max_len=5000):
        super().__init__()
        
        self.dropout = nn.Dropout(dropout_p)
        
        # 최대 길이에 대한 Positional Encoding 생성
        pos_encoding = torch.zeros(max_len, dim_model)
        positions_list = torch.arange(0, max_len, dtype=torch.float).view(-1, 1) # 0, 1, 2, 3, ...
        division_term = torch.exp(torch.arange(0, dim_model, 2).float() * (-math.log(10000.0)) / dim_model)
        
        pos_encoding[:, 0::2] = torch.sin(positions_list * division_term)
        pos_encoding[:, 1::2] = torch.cos(positions_list * division_term)
        
        # Positional Encoding을 모델의 버퍼로 등록
        pos_encoding = pos_encoding.unsqueeze(0)
        self.register_buffer("pos_encoding", pos_encoding)
    
    def forward(self, token_embedding: torch.tensor) -> torch.tensor:
        seq_len = token_embedding.size(1)
        pos_encoding = self.pos_encoding[:, :seq_len, :]
        return self.dropout(token_embedding + pos_encoding)


class EarlyStopping:
    def __init__(self, patience=20, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
train_encoded_labels = get_word_list(1, 4)
train_sequence_files = get_sequence_files(1, 4)


val_encoded_labels = get_word_list(5, 5)
val_sequence_files = get_sequence_files(5, 5)

train_dataset = SignLanguageDataset(train_sequence_files, train_encoded_labels)
val_dataset = SignLanguageDataset(val_sequence_files, val_encoded_labels)

device = torch.device('cuda' if torch.cuda.is_available else 'cpu')
# Out:
# 0  Original Label: 고민, Encoded Label: 53
# 1  Original Label: 뻔뻔, Encoded Label: 248
# 2  Original Label: 수어, Encoded Label: 285
# 3  Original Label: 남아, Encoded Label: 133
# 4  Original Label: 눈, Encoded Label: 140
# 5  Original Label: 독신, Encoded Label: 166
# 6  Original Label: 음료수, Encoded Label: 362
# 7  Original Label: 발가락, Encoded Label: 211
# 8  Original Label: 슬프다, Encoded Label: 291
# 9  Original Label: 자극, Encoded Label: 374
# 10  Original Label: 안타깝다, Encoded Label: 309
# 11  Original Label: 어색하다, Encoded Label: 317
# 12  Original Label: 여아, Encoded Label: 323
# 13  Original Label: 외국인, Encoded Label: 346
# 14  Original Label: 영아, Encoded Label: 335
# 15  Original Label: 신사, Encoded Label: 298
# 16  Original Label: 뉴질랜드, Encoded Label: 141
# 17  Original Label: 나사렛대학교, Encoded Label: 125
# 18  Original Label: 알아서, Encoded Label: 310
# 19  Original Label: 장애인, Encoded Label: 381
# 20  Original Label: 열아홉번째, Encoded Label: 334
# 21  Original Label: 침착, Encoded Label: 428
# 22  Original Label: 성실, Encoded Label: 269
# 23  Original Label: 학교연혁, Encoded Label: 450
# 24  Original Label: 싫어하다, Encoded Label: 304
# 25  Original Label: 급하다, Encoded Label: 111
# 26  Original Label: 필기시험, Encoded Label: 448
# 27  Original Label: 병문안, Encoded Label: 227
# 28  Original Label: 검사, Encoded Label: 36
# 29  Original Label: 결승전, Encoded Label: 39
# 30  Original Label: 낚시터, Encoded Label: 128
# 31  Original Label: 낚시대, Encoded Label: 127
# 32  Original Label: 당뇨병, Encoded Label: 153
# 33  Original Label: 독서, Encoded Label: 164
# 34  Original Label: 매표소, Encoded Label: 198
# 35  Original Label: 면역, Encoded Label: 200
# 36  Original Label: 감기, Encoded Label: 17
# 37  Original Label: 배드민턴, Encoded Label: 217
# 38  Original Label: 변비, Encoded Label: 225
# 39  Original Label: 병명, Encoded Label: 226
# 40  Original Label: 보건소, Encoded Label: 229
# 41  Original Label: 불면증, Encoded Label: 239
# 42  Original Label: 불행, Encoded Label: 242
# 43  Original Label: 붕대, Encoded Label: 243
# 44  Original Label: 사위, Encoded Label: 254
# 45  Original Label: 설사, Encoded Label: 266
# 46  Original Label: 성병, Encoded Label: 268
# 47  Original Label: 방충, Encoded Label: 216
# 48  Original Label: 소화제, Encoded Label: 276
# 49  Original Label: 손녀, Encoded Label: 277
# 50  Original Label: 손자, Encoded Label: 278
# 51  Original Label: 수면제, Encoded Label: 284
# 52  Original Label: 수집가, Encoded Label: 288
# 53  Original Label: 여행지, Encoded Label: 327
# 54  Original Label: 예식장, Encoded Label: 339
# 55  Original Label: 올림픽경기, Encoded Label: 343
# 56  Original Label: 회복, Encoded Label: 470
# 57  Original Label: 첫번째, Encoded Label: 410
# 58  Original Label: 운동경기, Encoded Label: 349
# 59  Original Label: 입원, Encoded Label: 372
# 60  Original Label: 재혼, Encoded Label: 385
# 61  Original Label: 진단서, Encoded Label: 399
# 62  Original Label: 축구장, Encoded Label: 419
# 63  Original Label: 치료, Encoded Label: 424
# 64  Original Label: 치료법, Encoded Label: 425
# 65  Original Label: 친아들, Encoded Label: 427
# 66  Original Label: 퇴원, Encoded Label: 440
# 67  Original Label: 한약, Encoded Label: 457
# 68  Original Label: 한약방, Encoded Label: 458
# 69  Original Label: 빈혈, Encoded Label: 247
# 70  Original Label: 화상, Encoded Label: 462
# 71  Original Label: 가래떡, Encoded Label: 3
# 72  Original Label: 고깃국, Encoded Label: 49
# 73  Original Label: 고추, Encoded Label: 57
# 74  Original Label: 고추가루, Encoded Label: 58
# 75  Original Label: 사골, Encoded Label: 250
# 76  Original Label: 배추국, Encoded Label: 218
# 77  Original Label: 꽈베기, Encoded Label: 123
# 78  Original Label: 벌꿀, Encoded Label: 223
# 79  Original Label: 꿀물, Encoded Label: 124
# 80  Original Label: 냄비, Encoded Label: 135
# 81  Original Label: 찬물, Encoded Label: 403
# 82  Original Label: 다과, Encoded Label: 144
# 83  Original Label: 지방경찰청장, Encoded Label: 397
# 84  Original Label: 된장찌게, Encoded Label: 180
# 85  Original Label: 돼지고기, Encoded Label: 179
# 86  Original Label: 두부, Encoded Label: 182
# 87  Original Label: 딸기, Encoded Label: 188
# 88  Original Label: 떡국, Encoded Label: 189
# 89  Original Label: 라면, Encoded Label: 190
# 90  Original Label: 막걸리, Encoded Label: 196
# 91  Original Label: 무, Encoded Label: 204
# 92  Original Label: 밥그릇, Encoded Label: 213
# 93  Original Label: 밥솥, Encoded Label: 214
# 94  Original Label: 보신탕, Encoded Label: 231
# 95  Original Label: 부엌, Encoded Label: 234
# 96  Original Label: 소불고기, Encoded Label: 273
# 97  Original Label: 비빔밥, Encoded Label: 245
# 98  Original Label: 사과, Encoded Label: 251
# 99  Original Label: 사이다, Encoded Label: 256
# 100  Original Label: 달다, Encoded Label: 149
# 101  Original Label: 소주, Encoded Label: 275
# 102  Original Label: 술잔, Encoded Label: 290
# 103  Original Label: 식당, Encoded Label: 292
# 104  Original Label: 쌀가루, Encoded Label: 305
# 105  Original Label: 냉커피, Encoded Label: 136
# 106  Original Label: 양식, Encoded Label: 313
# 107  Original Label: 위스키, Encoded Label: 357
# 108  Original Label: 술, Encoded Label: 289
# 109  Original Label: 용품, Encoded Label: 348
# 110  Original Label: 유리그릇, Encoded Label: 359
# 111  Original Label: 짬뽕, Encoded Label: 402
# 112  Original Label: 참외, Encoded Label: 405
# 113  Original Label: 칼국수, Encoded Label: 429
# 114  Original Label: 커피, Encoded Label: 430
# 115  Original Label: 콜라, Encoded Label: 432
# 116  Original Label: 콩가루, Encoded Label: 433
# 117  Original Label: 통조림, Encoded Label: 438
# 118  Original Label: 와인, Encoded Label: 344
# 119  Original Label: 백설기, Encoded Label: 219
# 120  Original Label: 가죽신, Encoded Label: 11
# 121  Original Label: 군복, Encoded Label: 100
# 122  Original Label: 포켓, Encoded Label: 446
# 123  Original Label: 양산, Encoded Label: 312
# 124  Original Label: 운동화, Encoded Label: 351
# 125  Original Label: 잠옷, Encoded Label: 377
# 126  Original Label: 이불, Encoded Label: 368
# 127  Original Label: 에어컨, Encoded Label: 321
# 128  Original Label: 행거, Encoded Label: 460
# 129  Original Label: 월세, Encoded Label: 355
# 130  Original Label: 전세, Encoded Label: 387
# 131  Original Label: 치약, Encoded Label: 426
# 132  Original Label: 가수, Encoded Label: 6
# 133  Original Label: 체감, Encoded Label: 412
# 134  Original Label: 경고, Encoded Label: 41
# 135  Original Label: 경찰서, Encoded Label: 45
# 136  Original Label: 공식, Encoded Label: 65
# 137  Original Label: 과장, Encoded Label: 70
# 138  Original Label: 관광버스, Encoded Label: 72
# 139  Original Label: 교수, Encoded Label: 80
# 140  Original Label: 교장, Encoded Label: 85
# 141  Original Label: 찻길, Encoded Label: 406
# 142  Original Label: 독일어, Encoded Label: 167
# 143  Original Label: 반환, Encoded Label: 210
# 144  Original Label: 음주운전, Encoded Label: 364
# 145  Original Label: 동아리, Encoded Label: 177
# 146  Original Label: 디자이너, Encoded Label: 186
# 147  Original Label: 마을버스, Encoded Label: 194
# 148  Original Label: 구급차, Encoded Label: 90
# 149  Original Label: 개입하지않는다, Encoded Label: 28
# 150  Original Label: 음주운전, Encoded Label: 364
# 151  Original Label: 사무, Encoded Label: 252
# 152  Original Label: 신입학, Encoded Label: 300
# 153  Original Label: 여객선, Encoded Label: 322
# 154  Original Label: 여행사, Encoded Label: 326
# 155  Original Label: 기차역, Encoded Label: 113
# 156  Original Label: 예술가, Encoded Label: 337
# 157  Original Label: 외국어, Encoded Label: 345
# 158  Original Label: 요리사, Encoded Label: 347
# 159  Original Label: 강요, Encoded Label: 23
# 160  Original Label: 운동선수, Encoded Label: 350
# 161  Original Label: 퇴임, Encoded Label: 441
# 162  Original Label: 의사, Encoded Label: 365
# 163  Original Label: 이력서, Encoded Label: 367
# 164  Original Label: 자가용, Encoded Label: 373
# 165  Original Label: 재택근무, Encoded Label: 383
# 166  Original Label: 연령제한, Encoded Label: 332
# 167  Original Label: 주차장, Encoded Label: 394
# 168  Original Label: 채팅, Encoded Label: 408
# 169  Original Label: 출근, Encoded Label: 421
# 170  Original Label: 코치, Encoded Label: 431
# 171  Original Label: 터미널, Encoded Label: 435
# 172  Original Label: 근무, Encoded Label: 105
# 173  Original Label: 통역사, Encoded Label: 437
# 174  Original Label: 퇴사, Encoded Label: 439
# 175  Original Label: 사직, Encoded Label: 257
# 176  Original Label: 판결, Encoded Label: 443
# 177  Original Label: 평가, Encoded Label: 444
# 178  Original Label: 두번째, Encoded Label: 181
# 179  Original Label: 항공사, Encoded Label: 459
# 180  Original Label: 교통안전교육, Encoded Label: 89
# 181  Original Label: 화상채팅, Encoded Label: 463
# 182  Original Label: 회식, Encoded Label: 472
# 183  Original Label: 교통기본교육, Encoded Label: 87
# 184  Original Label: 후원, Encoded Label: 475
# 185  Original Label: 희생, Encoded Label: 483
# 186  Original Label: 간호사, Encoded Label: 14
# 187  Original Label: 교통법교육, Encoded Label: 88
# 188  Original Label: 계약금, Encoded Label: 48
# 189  Original Label: 고용, Encoded Label: 56
# 190  Original Label: 사업장, Encoded Label: 253
# 191  Original Label: 버스값, Encoded Label: 222
# 192  Original Label: 구직, Encoded Label: 93
# 193  Original Label: 논, Encoded Label: 138
# 194  Original Label: 대기업, Encoded Label: 155
# 195  Original Label: 사육장, Encoded Label: 255
# 196  Original Label: 백화점, Encoded Label: 221
# 197  Original Label: 압류, Encoded Label: 311
# 198  Original Label: 거지, Encoded Label: 33
# 199  Original Label: 수입, Encoded Label: 287
# 200  Original Label: 신용카드, Encoded Label: 299
# 201  Original Label: 백수, Encoded Label: 220
# 202  Original Label: 아르바이트, Encoded Label: 308
# 203  Original Label: 샛길, Encoded Label: 261
# 204  Original Label: 일시불, Encoded Label: 369
# 205  Original Label: 주유소, Encoded Label: 393
# 206  Original Label: 집주인, Encoded Label: 401
# 207  Original Label: 한국은행, Encoded Label: 455
# 208  Original Label: 경찰청장, Encoded Label: 46
# 209  Original Label: 가정교육, Encoded Label: 9
# 210  Original Label: 고등학교, Encoded Label: 51
# 211  Original Label: 고등학생, Encoded Label: 52
# 212  Original Label: 교무실, Encoded Label: 78
# 213  Original Label: 개학, Encoded Label: 29
# 214  Original Label: 교실, Encoded Label: 81
# 215  Original Label: 교육자, Encoded Label: 83
# 216  Original Label: 국어학, Encoded Label: 96
# 217  Original Label: 낙제, Encoded Label: 126
# 218  Original Label: 예절, Encoded Label: 341
# 219  Original Label: 독서실, Encoded Label: 165
# 220  Original Label: 등교, Encoded Label: 184
# 221  Original Label: 맹학교, Encoded Label: 199
# 222  Original Label: 복습, Encoded Label: 233
# 223  Original Label: 분필, Encoded Label: 235
# 224  Original Label: 상장, Encoded Label: 260
# 225  Original Label: 서점, Encoded Label: 265
# 226  Original Label: 학업, Encoded Label: 454
# 227  Original Label: 실습, Encoded Label: 303
# 228  Original Label: 여학교, Encoded Label: 324
# 229  Original Label: 여학생, Encoded Label: 325
# 230  Original Label: 연구소, Encoded Label: 329
# 231  Original Label: 연구실, Encoded Label: 330
# 232  Original Label: 예습, Encoded Label: 338
# 233  Original Label: 유학, Encoded Label: 361
# 234  Original Label: 의학, Encoded Label: 366
# 235  Original Label: 지도, Encoded Label: 395
# 236  Original Label: 재학, Encoded Label: 384
# 237  Original Label: 연구, Encoded Label: 328
# 238  Original Label: 학부모, Encoded Label: 451
# 239  Original Label: 학식, Encoded Label: 453
# 240  Original Label: 훈련, Encoded Label: 476
# 241  Original Label: 경기도, Encoded Label: 42
# 242  Original Label: 경기도, Encoded Label: 42
# 243  Original Label: 경북, Encoded Label: 43
# 244  Original Label: 남산, Encoded Label: 131
# 245  Original Label: 울릉도, Encoded Label: 352
# 246  Original Label: 울산, Encoded Label: 353
# 247  Original Label: 전남, Encoded Label: 386
# 248  Original Label: 청주, Encoded Label: 411
# 249  Original Label: 충북, Encoded Label: 423
# 250  Original Label: 충남, Encoded Label: 422
# 251  Original Label: 불경, Encoded Label: 238
# 252  Original Label: 불경, Encoded Label: 238
# 253  Original Label: 성경책, Encoded Label: 267
# 254  Original Label: 신학, Encoded Label: 301
# 255  Original Label: 장로교, Encoded Label: 379
# 256  Original Label: 일요일, Encoded Label: 370
# 257  Original Label: 축하, Encoded Label: 420
# 258  Original Label: 회개, Encoded Label: 469
# 259  Original Label: 소감, Encoded Label: 272
# 260  Original Label: 장난, Encoded Label: 378
# 261  Original Label: 장인, Encoded Label: 382
# 262  Original Label: 희생자, Encoded Label: 484
# 263  Original Label: 디자인, Encoded Label: 187
# 264  Original Label: 돌무덤, Encoded Label: 172
# 265  Original Label: 쇠기둥, Encoded Label: 281
# 266  Original Label: 동화책, Encoded Label: 178
# 267  Original Label: 목공예, Encoded Label: 203
# 268  Original Label: 문학, Encoded Label: 207
# 269  Original Label: 문화유산, Encoded Label: 208
# 270  Original Label: 음악가, Encoded Label: 363
# 271  Original Label: 예술, Encoded Label: 336
# 272  Original Label: 초상화, Encoded Label: 414
# 273  Original Label: 토기, Encoded Label: 436
# 274  Original Label: 흑백영화, Encoded Label: 479
# 275  Original Label: 공군, Encoded Label: 62
# 276  Original Label: 감옥, Encoded Label: 18
# 277  Original Label: 국왕, Encoded Label: 97
# 278  Original Label: 보건복지, Encoded Label: 228
# 279  Original Label: 고소, Encoded Label: 54
# 280  Original Label: 유권자, Encoded Label: 358
# 281  Original Label: 절도죄, Encoded Label: 388
# 282  Original Label: 수감자, Encoded Label: 282
# 283  Original Label: 총무, Encoded Label: 415
# 284  Original Label: 강, Encoded Label: 20
# 285  Original Label: 달빛, Encoded Label: 150
# 286  Original Label: 장마, Encoded Label: 380
# 287  Original Label: 체온, Encoded Label: 413
# 288  Original Label: 파도, Encoded Label: 442
# 289  Original Label: 하늘, Encoded Label: 449
# 290  Original Label: 가시나무, Encoded Label: 7
# 291  Original Label: 강아지, Encoded Label: 21
# 292  Original Label: 구렁이, Encoded Label: 92
# 293  Original Label: 까마귀, Encoded Label: 120
# 294  Original Label: 꽃씨, Encoded Label: 121
# 295  Original Label: 꽃잎, Encoded Label: 122
# 296  Original Label: 웃는척, Encoded Label: 354
# 297  Original Label: 흡연실, Encoded Label: 482
# 298  Original Label: 무궁화, Encoded Label: 205
# 299  Original Label: 밤나무, Encoded Label: 212
# 300  Original Label: 벚꽃, Encoded Label: 224
# 301  Original Label: 깃털, Encoded Label: 119
# 302  Original Label: 솔잎, Encoded Label: 279
# 303  Original Label: 송아지, Encoded Label: 280
# 304  Original Label: 소뿔, Encoded Label: 274
# 305  Original Label: 양털, Encoded Label: 314
# 306  Original Label: 연꽃, Encoded Label: 331
# 307  Original Label: 참새, Encoded Label: 404
# 308  Original Label: 어젯밤, Encoded Label: 318
# 309  Original Label: 갈색, Encoded Label: 15
# 310  Original Label: 최상급, Encoded Label: 417
# 311  Original Label: 공휴일, Encoded Label: 68
# 312  Original Label: 세번째, Encoded Label: 270
# 313  Original Label: 네번째, Encoded Label: 137
# 314  Original Label: 흙내음, Encoded Label: 481
# 315  Original Label: 금요일, Encoded Label: 108
# 316  Original Label: 급행, Encoded Label: 112
# 317  Original Label: 남부지방, Encoded Label: 130
# 318  Original Label: 식목일, Encoded Label: 294
# 319  Original Label: 방금, Encoded Label: 215
# 320  Original Label: 100만원, Encoded Label: 0
# 321  Original Label: 보라색, Encoded Label: 230
# 322  Original Label: 분홍조명, Encoded Label: 237
# 323  Original Label: 분혹색, Encoded Label: 236
# 324  Original Label: 얼굴이빨개지다, Encoded Label: 319
# 325  Original Label: 사춘기, Encoded Label: 258
# 326  Original Label: 3.1절, Encoded Label: 2
# 327  Original Label: 생년월일, Encoded Label: 263
# 328  Original Label: 수요일, Encoded Label: 286
# 329  Original Label: 10만원, Encoded Label: 1
# 330  Original Label: 어떻게, Encoded Label: 315
# 331  Original Label: 어린이날, Encoded Label: 316
# 332  Original Label: 연말, Encoded Label: 333
# 333  Original Label: 예전, Encoded Label: 340
# 334  Original Label: 식전, Encoded Label: 295
# 335  Original Label: 월요일, Encoded Label: 356
# 336  Original Label: 일요일, Encoded Label: 370
# 337  Original Label: 자정, Encoded Label: 376
# 338  Original Label: 아까, Encoded Label: 307
# 339  Original Label: 진하기, Encoded Label: 400
# 340  Original Label: 검정머리, Encoded Label: 37
# 341  Original Label: 최대, Encoded Label: 416
# 342  Original Label: 최소, Encoded Label: 418
# 343  Original Label: 평일, Encoded Label: 445
# 344  Original Label: 한글날, Encoded Label: 456
# 345  Original Label: 현충일, Encoded Label: 461
# 346  Original Label: 화요일, Encoded Label: 464
# 347  Original Label: 황금색, Encoded Label: 468
# 348  Original Label: 흑백, Encoded Label: 478
# 349  Original Label: 흑색, Encoded Label: 480
# 350  Original Label: 임시협약, Encoded Label: 371
# 351  Original Label: 감금, Encoded Label: 16
# 352  Original Label: 탈춤, Encoded Label: 434
# 353  Original Label: 가명, Encoded Label: 4
# 354  Original Label: 가발, Encoded Label: 5
# 355  Original Label: 가위바위보, Encoded Label: 8
# 356  Original Label: 가족회의, Encoded Label: 10
# 357  Original Label: 가짜, Encoded Label: 12
# 358  Original Label: 서약서, Encoded Label: 264
# 359  Original Label: 간편, Encoded Label: 13
# 360  Original Label: 감옥, Encoded Label: 18
# 361  Original Label: 감옥살이, Encoded Label: 19
# 362  Original Label: 보호, Encoded Label: 232
# 363  Original Label: 견습, Encoded Label: 38
# 364  Original Label: 강약, Encoded Label: 22
# 365  Original Label: 강철, Encoded Label: 24
# 366  Original Label: 개똥, Encoded Label: 26
# 367  Original Label: 개명, Encoded Label: 27
# 368  Original Label: 신경쓰다, Encoded Label: 296
# 369  Original Label: 거목, Encoded Label: 30
# 370  Original Label: 거북선, Encoded Label: 31
# 371  Original Label: 거역, Encoded Label: 32
# 372  Original Label: 거지, Encoded Label: 33
# 373  Original Label: 건장, Encoded Label: 34
# 374  Original Label: 걸스카우트, Encoded Label: 35
# 375  Original Label: 거지, Encoded Label: 33
# 376  Original Label: 휴학, Encoded Label: 477
# 377  Original Label: 휴학, Encoded Label: 477
# 378  Original Label: 회칙, Encoded Label: 474
# 379  Original Label: 결승전, Encoded Label: 39
# 380  Original Label: 경찰행정, Encoded Label: 47
# 381  Original Label: 경비실, Encoded Label: 44
# 382  Original Label: 고아원, Encoded Label: 55
# 383  Original Label: 고춧잎, Encoded Label: 59
# 384  Original Label: 불알, Encoded Label: 241
# 385  Original Label: 황금기, Encoded Label: 467
# 386  Original Label: 골절, Encoded Label: 60
# 387  Original Label: 공식발표, Encoded Label: 66
# 388  Original Label: 맞추다, Encoded Label: 197
# 389  Original Label: 공군본부, Encoded Label: 63
# 390  Original Label: 공범, Encoded Label: 64
# 391  Original Label: 동거, Encoded Label: 175
# 392  Original Label: 공증, Encoded Label: 67
# 393  Original Label: 과로, Encoded Label: 69
# 394  Original Label: 실수, Encoded Label: 302
# 395  Original Label: 회상, Encoded Label: 471
# 396  Original Label: 과태료, Encoded Label: 71
# 397  Original Label: 관습, Encoded Label: 73
# 398  Original Label: 직인, Encoded Label: 398
# 399  Original Label: 정밀검사, Encoded Label: 389
# 400  Original Label: 대지, Encoded Label: 159
# 401  Original Label: 광업, Encoded Label: 74
# 402  Original Label: 미치광이, Encoded Label: 209
# 403  Original Label: 강풍, Encoded Label: 25
# 404  Original Label: 환대, Encoded Label: 466
# 405  Original Label: 교가, Encoded Label: 75
# 406  Original Label: 교기, Encoded Label: 76
# 407  Original Label: 지도, Encoded Label: 395
# 408  Original Label: 교기, Encoded Label: 76
# 409  Original Label: 교모, Encoded Label: 77
# 410  Original Label: 지도법, Encoded Label: 396
# 411  Original Label: 학습, Encoded Label: 452
# 412  Original Label: 지도, Encoded Label: 395
# 413  Original Label: 교육과정, Encoded Label: 82
# 414  Original Label: 교육청, Encoded Label: 84
# 415  Original Label: 교사직무, Encoded Label: 79
# 416  Original Label: 사거리, Encoded Label: 249
# 417  Original Label: 교탁, Encoded Label: 86
# 418  Original Label: 구두액, Encoded Label: 91
# 419  Original Label: 수갑, Encoded Label: 283
# 420  Original Label: 조직도, Encoded Label: 390
# 421  Original Label: 국그릇, Encoded Label: 94
# 422  Original Label: 국기, Encoded Label: 95
# 423  Original Label: 독립, Encoded Label: 163
# 424  Original Label: 군가, Encoded Label: 98
# 425  Original Label: 군마, Encoded Label: 99
# 426  Original Label: 다섯번째, Encoded Label: 146
# 427  Original Label: 군비행장, Encoded Label: 101
# 428  Original Label: 독재자, Encoded Label: 168
# 429  Original Label: 귀부인, Encoded Label: 102
# 430  Original Label: 상류층, Encoded Label: 259
# 431  Original Label: 모범, Encoded Label: 202
# 432  Original Label: 그날, Encoded Label: 104
# 433  Original Label: 기초확인, Encoded Label: 114
# 434  Original Label: 금식, Encoded Label: 106
# 435  Original Label: 얼마, Encoded Label: 320
# 436  Original Label: 금연, Encoded Label: 107
# 437  Original Label: 금욕, Encoded Label: 109
# 438  Original Label: 금주, Encoded Label: 110
# 439  Original Label: 불쌍, Encoded Label: 240
# 440  Original Label: 식도염, Encoded Label: 293
# 441  Original Label: 신기, Encoded Label: 297
# 442  Original Label: 신기, Encoded Label: 297
# 443  Original Label: 기혼, Encoded Label: 115
# 444  Original Label: 귀중품, Encoded Label: 103
# 445  Original Label: 길몽, Encoded Label: 116
# 446  Original Label: 길일, Encoded Label: 118
# 447  Original Label: 길운, Encoded Label: 117
# 448  Original Label: 고난이도, Encoded Label: 50
# 449  Original Label: 비좁다, Encoded Label: 246
# 450  Original Label: 유언, Encoded Label: 360
# 451  Original Label: 온실, Encoded Label: 342
# 452  Original Label: 고난이도, Encoded Label: 50
# 453  Original Label: 날쎄다, Encoded Label: 129
# 454  Original Label: 비루, Encoded Label: 244
# 455  Original Label: 쑥쓰럽다, Encoded Label: 306
# 456  Original Label: 남성적, Encoded Label: 132
# 457  Original Label: 내정, Encoded Label: 134
# 458  Original Label: 능숙, Encoded Label: 143
# 459  Original Label: 대모, Encoded Label: 157
# 460  Original Label: 농인, Encoded Label: 139
# 461  Original Label: 다복, Encoded Label: 145
# 462  Original Label: 결합을끊다, Encoded Label: 40
# 463  Original Label: 단명, Encoded Label: 147
# 464  Original Label: 단문, Encoded Label: 148
# 465  Original Label: 능력자, Encoded Label: 142
# 466  Original Label: 곰방대, Encoded Label: 61
# 467  Original Label: 담당, Encoded Label: 151
# 468  Original Label: 답안지, Encoded Label: 152
# 469  Original Label: 책임이사, Encoded Label: 409
# 470  Original Label: 채용자, Encoded Label: 407
# 471  Original Label: 대교, Encoded Label: 154
# 472  Original Label: 대독, Encoded Label: 156
# 473  Original Label: 대필, Encoded Label: 160
# 474  Original Label: 대성공, Encoded Label: 158
# 475  Original Label: 세수대야, Encoded Label: 271
# 476  Original Label: 확정, Encoded Label: 465
# 477  Original Label: 면적, Encoded Label: 201
# 478  Original Label: 회장, Encoded Label: 473
# 479  Original Label: 품격, Encoded Label: 447
# 480  Original Label: 도벽, Encoded Label: 161
# 481  Original Label: 도자기기술, Encoded Label: 162
# 482  Original Label: 자습, Encoded Label: 375
# 483  Original Label: 돌기둥, Encoded Label: 170
# 484  Original Label: 돌다리, Encoded Label: 171
# 485  Original Label: 돌벽, Encoded Label: 173
# 486  Original Label: 동갑, Encoded Label: 174
# 487  Original Label: 동메달, Encoded Label: 176
# 488  Original Label: 주민센터, Encoded Label: 392
# 489  Original Label: 독특, Encoded Label: 169
# 490  Original Label: 무덤덤, Encoded Label: 206
# 491  Original Label: 뒷산, Encoded Label: 183
# 492  Original Label: 등록금, Encoded Label: 185
# 493  Original Label: 담당, Encoded Label: 151
# 494  Original Label: 생각못하다, Encoded Label: 262
# 495  Original Label: 주문서, Encoded Label: 391
# 496  Original Label: 마구간, Encoded Label: 191
# 497  Original Label: 마술사, Encoded Label: 192
# 498  Original Label: 마스크, Encoded Label: 193
# 499  Original Label: 마음에들다, Encoded Label: 195
# 500  Original Label: 고민, Encoded Label: 53
# 501  Original Label: 뻔뻔, Encoded Label: 248
# 502  Original Label: 수어, Encoded Label: 285
# 503  Original Label: 남아, Encoded Label: 133
# 504  Original Label: 눈, Encoded Label: 140
# 505  Original Label: 독신, Encoded Label: 166
# 506  Original Label: 음료수, Encoded Label: 362
# 507  Original Label: 발가락, Encoded Label: 211
# 508  Original Label: 슬프다, Encoded Label: 291
# 509  Original Label: 자극, Encoded Label: 374
# 510  Original Label: 안타깝다, Encoded Label: 309
# 511  Original Label: 어색하다, Encoded Label: 317
# 512  Original Label: 여아, Encoded Label: 323
# 513  Original Label: 외국인, Encoded Label: 346
# 514  Original Label: 영아, Encoded Label: 335
# 515  Original Label: 신사, Encoded Label: 298
# 516  Original Label: 뉴질랜드, Encoded Label: 141
# 517  Original Label: 나사렛대학교, Encoded Label: 125
# 518  Original Label: 알아서, Encoded Label: 310
# 519  Original Label: 장애인, Encoded Label: 381
# 520  Original Label: 열아홉번째, Encoded Label: 334
# 521  Original Label: 침착, Encoded Label: 428
# 522  Original Label: 성실, Encoded Label: 269
# 523  Original Label: 학교연혁, Encoded Label: 450
# 524  Original Label: 싫어하다, Encoded Label: 304
# 525  Original Label: 급하다, Encoded Label: 111
# 526  Original Label: 필기시험, Encoded Label: 448
# 527  Original Label: 병문안, Encoded Label: 227
# 528  Original Label: 검사, Encoded Label: 36
# 529  Original Label: 결승전, Encoded Label: 39
# 530  Original Label: 낚시터, Encoded Label: 128
# 531  Original Label: 낚시대, Encoded Label: 127
# 532  Original Label: 당뇨병, Encoded Label: 153
# 533  Original Label: 독서, Encoded Label: 164
# 534  Original Label: 매표소, Encoded Label: 198
# 535  Original Label: 면역, Encoded Label: 200
# 536  Original Label: 감기, Encoded Label: 17
# 537  Original Label: 배드민턴, Encoded Label: 217
# 538  Original Label: 변비, Encoded Label: 225
# 539  Original Label: 병명, Encoded Label: 226
# 540  Original Label: 보건소, Encoded Label: 229
# 541  Original Label: 불면증, Encoded Label: 239
# 542  Original Label: 불행, Encoded Label: 242
# 543  Original Label: 붕대, Encoded Label: 243
# 544  Original Label: 사위, Encoded Label: 254
# 545  Original Label: 설사, Encoded Label: 266
# 546  Original Label: 성병, Encoded Label: 268
# 547  Original Label: 방충, Encoded Label: 216
# 548  Original Label: 소화제, Encoded Label: 276
# 549  Original Label: 손녀, Encoded Label: 277
# 550  Original Label: 손자, Encoded Label: 278
# 551  Original Label: 수면제, Encoded Label: 284
# 552  Original Label: 수집가, Encoded Label: 288
# 553  Original Label: 여행지, Encoded Label: 327
# 554  Original Label: 예식장, Encoded Label: 339
# 555  Original Label: 올림픽경기, Encoded Label: 343
# 556  Original Label: 회복, Encoded Label: 470
# 557  Original Label: 첫번째, Encoded Label: 410
# 558  Original Label: 운동경기, Encoded Label: 349
# 559  Original Label: 입원, Encoded Label: 372
# 560  Original Label: 재혼, Encoded Label: 385
# 561  Original Label: 진단서, Encoded Label: 399
# 562  Original Label: 축구장, Encoded Label: 419
# 563  Original Label: 치료, Encoded Label: 424
# 564  Original Label: 치료법, Encoded Label: 425
# 565  Original Label: 친아들, Encoded Label: 427
# 566  Original Label: 퇴원, Encoded Label: 440
# 567  Original Label: 한약, Encoded Label: 457
# 568  Original Label: 한약방, Encoded Label: 458
# 569  Original Label: 빈혈, Encoded Label: 247
# 570  Original Label: 화상, Encoded Label: 462
# 571  Original Label: 가래떡, Encoded Label: 3
# 572  Original Label: 고깃국, Encoded Label: 49
# 573  Original Label: 고추, Encoded Label: 57
# 574  Original Label: 고추가루, Encoded Label: 58
# 575  Original Label: 사골, Encoded Label: 250
# 576  Original Label: 배추국, Encoded Label: 218
# 577  Original Label: 꽈베기, Encoded Label: 123
# 578  Original Label: 벌꿀, Encoded Label: 223
# 579  Original Label: 꿀물, Encoded Label: 124
# 580  Original Label: 냄비, Encoded Label: 135
# 581  Original Label: 찬물, Encoded Label: 403
# 582  Original Label: 다과, Encoded Label: 144
# 583  Original Label: 지방경찰청장, Encoded Label: 397
# 584  Original Label: 된장찌게, Encoded Label: 180
# 585  Original Label: 돼지고기, Encoded Label: 179
# 586  Original Label: 두부, Encoded Label: 182
# 587  Original Label: 딸기, Encoded Label: 188
# 588  Original Label: 떡국, Encoded Label: 189
# 589  Original Label: 라면, Encoded Label: 190
# 590  Original Label: 막걸리, Encoded Label: 196
# 591  Original Label: 무, Encoded Label: 204
# 592  Original Label: 밥그릇, Encoded Label: 213
# 593  Original Label: 밥솥, Encoded Label: 214
# 594  Original Label: 보신탕, Encoded Label: 231
# 595  Original Label: 부엌, Encoded Label: 234
# 596  Original Label: 소불고기, Encoded Label: 273
# 597  Original Label: 비빔밥, Encoded Label: 245
# 598  Original Label: 사과, Encoded Label: 251
# 599  Original Label: 사이다, Encoded Label: 256
# 600  Original Label: 달다, Encoded Label: 149
# 601  Original Label: 소주, Encoded Label: 275
# 602  Original Label: 술잔, Encoded Label: 290
# 603  Original Label: 식당, Encoded Label: 292
# 604  Original Label: 쌀가루, Encoded Label: 305
# 605  Original Label: 냉커피, Encoded Label: 136
# 606  Original Label: 양식, Encoded Label: 313
# 607  Original Label: 위스키, Encoded Label: 357
# 608  Original Label: 술, Encoded Label: 289
# 609  Original Label: 용품, Encoded Label: 348
# 610  Original Label: 유리그릇, Encoded Label: 359
# 611  Original Label: 짬뽕, Encoded Label: 402
# 612  Original Label: 참외, Encoded Label: 405
# 613  Original Label: 칼국수, Encoded Label: 429
# 614  Original Label: 커피, Encoded Label: 430
# 615  Original Label: 콜라, Encoded Label: 432
# 616  Original Label: 콩가루, Encoded Label: 433
# 617  Original Label: 통조림, Encoded Label: 438
# 618  Original Label: 와인, Encoded Label: 344
# 619  Original Label: 백설기, Encoded Label: 219
# 620  Original Label: 가죽신, Encoded Label: 11
# 621  Original Label: 군복, Encoded Label: 100
# 622  Original Label: 포켓, Encoded Label: 446
# 623  Original Label: 양산, Encoded Label: 312
# 624  Original Label: 운동화, Encoded Label: 351
# 625  Original Label: 잠옷, Encoded Label: 377
# 626  Original Label: 이불, Encoded Label: 368
# 627  Original Label: 에어컨, Encoded Label: 321
# 628  Original Label: 행거, Encoded Label: 460
# 629  Original Label: 월세, Encoded Label: 355
# 630  Original Label: 전세, Encoded Label: 387
# 631  Original Label: 치약, Encoded Label: 426
# 632  Original Label: 가수, Encoded Label: 6
# 633  Original Label: 체감, Encoded Label: 412
# 634  Original Label: 경고, Encoded Label: 41
# 635  Original Label: 경찰서, Encoded Label: 45
# 636  Original Label: 공식, Encoded Label: 65
# 637  Original Label: 과장, Encoded Label: 70
# 638  Original Label: 관광버스, Encoded Label: 72
# 639  Original Label: 교수, Encoded Label: 80
# 640  Original Label: 교장, Encoded Label: 85
# 641  Original Label: 찻길, Encoded Label: 406
# 642  Original Label: 독일어, Encoded Label: 167
# 643  Original Label: 반환, Encoded Label: 210
# 644  Original Label: 음주운전, Encoded Label: 364
# 645  Original Label: 동아리, Encoded Label: 177
# 646  Original Label: 디자이너, Encoded Label: 186
# 647  Original Label: 마을버스, Encoded Label: 194
# 648  Original Label: 구급차, Encoded Label: 90
# 649  Original Label: 개입하지않는다, Encoded Label: 28
# 650  Original Label: 음주운전, Encoded Label: 364
# 651  Original Label: 사무, Encoded Label: 252
# 652  Original Label: 신입학, Encoded Label: 300
# 653  Original Label: 여객선, Encoded Label: 322
# 654  Original Label: 여행사, Encoded Label: 326
# 655  Original Label: 기차역, Encoded Label: 113
# 656  Original Label: 예술가, Encoded Label: 337
# 657  Original Label: 외국어, Encoded Label: 345
# 658  Original Label: 요리사, Encoded Label: 347
# 659  Original Label: 강요, Encoded Label: 23
# 660  Original Label: 운동선수, Encoded Label: 350
# 661  Original Label: 퇴임, Encoded Label: 441
# 662  Original Label: 의사, Encoded Label: 365
# 663  Original Label: 이력서, Encoded Label: 367
# 664  Original Label: 자가용, Encoded Label: 373
# 665  Original Label: 재택근무, Encoded Label: 383
# 666  Original Label: 연령제한, Encoded Label: 332
# 667  Original Label: 주차장, Encoded Label: 394
# 668  Original Label: 채팅, Encoded Label: 408
# 669  Original Label: 출근, Encoded Label: 421
# 670  Original Label: 코치, Encoded Label: 431
# 671  Original Label: 터미널, Encoded Label: 435
# 672  Original Label: 근무, Encoded Label: 105
# 673  Original Label: 통역사, Encoded Label: 437
# 674  Original Label: 퇴사, Encoded Label: 439
# 675  Original Label: 사직, Encoded Label: 257
# 676  Original Label: 판결, Encoded Label: 443
# 677  Original Label: 평가, Encoded Label: 444
# 678  Original Label: 두번째, Encoded Label: 181
# 679  Original Label: 항공사, Encoded Label: 459
# 680  Original Label: 교통안전교육, Encoded Label: 89
# 681  Original Label: 화상채팅, Encoded Label: 463
# 682  Original Label: 회식, Encoded Label: 472
# 683  Original Label: 교통기본교육, Encoded Label: 87
# 684  Original Label: 후원, Encoded Label: 475
# 685  Original Label: 희생, Encoded Label: 483
# 686  Original Label: 간호사, Encoded Label: 14
# 687  Original Label: 교통법교육, Encoded Label: 88
# 688  Original Label: 계약금, Encoded Label: 48
# 689  Original Label: 고용, Encoded Label: 56
# 690  Original Label: 사업장, Encoded Label: 253
# 691  Original Label: 버스값, Encoded Label: 222
# 692  Original Label: 구직, Encoded Label: 93
# 693  Original Label: 논, Encoded Label: 138
# 694  Original Label: 대기업, Encoded Label: 155
# 695  Original Label: 사육장, Encoded Label: 255
# 696  Original Label: 백화점, Encoded Label: 221
# 697  Original Label: 압류, Encoded Label: 311
# 698  Original Label: 거지, Encoded Label: 33
# 699  Original Label: 수입, Encoded Label: 287
# 700  Original Label: 신용카드, Encoded Label: 299
# 701  Original Label: 백수, Encoded Label: 220
# 702  Original Label: 아르바이트, Encoded Label: 308
# 703  Original Label: 샛길, Encoded Label: 261
# 704  Original Label: 일시불, Encoded Label: 369
# 705  Original Label: 주유소, Encoded Label: 393
# 706  Original Label: 집주인, Encoded Label: 401
# 707  Original Label: 한국은행, Encoded Label: 455
# 708  Original Label: 경찰청장, Encoded Label: 46
# 709  Original Label: 가정교육, Encoded Label: 9
# 710  Original Label: 고등학교, Encoded Label: 51
# 711  Original Label: 고등학생, Encoded Label: 52
# 712  Original Label: 교무실, Encoded Label: 78
# 713  Original Label: 개학, Encoded Label: 29
# 714  Original Label: 교실, Encoded Label: 81
# 715  Original Label: 교육자, Encoded Label: 83
# 716  Original Label: 국어학, Encoded Label: 96
# 717  Original Label: 낙제, Encoded Label: 126
# 718  Original Label: 예절, Encoded Label: 341
# 719  Original Label: 독서실, Encoded Label: 165
# 720  Original Label: 등교, Encoded Label: 184
# 721  Original Label: 맹학교, Encoded Label: 199
# 722  Original Label: 복습, Encoded Label: 233
# 723  Original Label: 분필, Encoded Label: 235
# 724  Original Label: 상장, Encoded Label: 260
# 725  Original Label: 서점, Encoded Label: 265
# 726  Original Label: 학업, Encoded Label: 454
# 727  Original Label: 실습, Encoded Label: 303
# 728  Original Label: 여학교, Encoded Label: 324
# 729  Original Label: 여학생, Encoded Label: 325
# 730  Original Label: 연구소, Encoded Label: 329
# 731  Original Label: 연구실, Encoded Label: 330
# 732  Original Label: 예습, Encoded Label: 338
# 733  Original Label: 유학, Encoded Label: 361
# 734  Original Label: 의학, Encoded Label: 366
# 735  Original Label: 지도, Encoded Label: 395
# 736  Original Label: 재학, Encoded Label: 384
# 737  Original Label: 연구, Encoded Label: 328
# 738  Original Label: 학부모, Encoded Label: 451
# 739  Original Label: 학식, Encoded Label: 453
# 740  Original Label: 훈련, Encoded Label: 476
# 741  Original Label: 경기도, Encoded Label: 42
# 742  Original Label: 경기도, Encoded Label: 42
# 743  Original Label: 경북, Encoded Label: 43
# 744  Original Label: 남산, Encoded Label: 131
# 745  Original Label: 울릉도, Encoded Label: 352
# 746  Original Label: 울산, Encoded Label: 353
# 747  Original Label: 전남, Encoded Label: 386
# 748  Original Label: 청주, Encoded Label: 411
# 749  Original Label: 충북, Encoded Label: 423
# 750  Original Label: 충남, Encoded Label: 422
# 751  Original Label: 불경, Encoded Label: 238
# 752  Original Label: 불경, Encoded Label: 238
# 753  Original Label: 성경책, Encoded Label: 267
# 754  Original Label: 신학, Encoded Label: 301
# 755  Original Label: 장로교, Encoded Label: 379
# 756  Original Label: 일요일, Encoded Label: 370
# 757  Original Label: 축하, Encoded Label: 420
# 758  Original Label: 회개, Encoded Label: 469
# 759  Original Label: 소감, Encoded Label: 272
# 760  Original Label: 장난, Encoded Label: 378
# 761  Original Label: 장인, Encoded Label: 382
# 762  Original Label: 희생자, Encoded Label: 484
# 763  Original Label: 디자인, Encoded Label: 187
# 764  Original Label: 돌무덤, Encoded Label: 172
# 765  Original Label: 쇠기둥, Encoded Label: 281
# 766  Original Label: 동화책, Encoded Label: 178
# 767  Original Label: 목공예, Encoded Label: 203
# 768  Original Label: 문학, Encoded Label: 207
# 769  Original Label: 문화유산, Encoded Label: 208
# 770  Original Label: 음악가, Encoded Label: 363
# 771  Original Label: 예술, Encoded Label: 336
# 772  Original Label: 초상화, Encoded Label: 414
# 773  Original Label: 토기, Encoded Label: 436
# 774  Original Label: 흑백영화, Encoded Label: 479
# 775  Original Label: 공군, Encoded Label: 62
# 776  Original Label: 감옥, Encoded Label: 18
# 777  Original Label: 국왕, Encoded Label: 97
# 778  Original Label: 보건복지, Encoded Label: 228
# 779  Original Label: 고소, Encoded Label: 54
# 780  Original Label: 유권자, Encoded Label: 358
# 781  Original Label: 절도죄, Encoded Label: 388
# 782  Original Label: 수감자, Encoded Label: 282
# 783  Original Label: 총무, Encoded Label: 415
# 784  Original Label: 강, Encoded Label: 20
# 785  Original Label: 달빛, Encoded Label: 150
# 786  Original Label: 장마, Encoded Label: 380
# 787  Original Label: 체온, Encoded Label: 413
# 788  Original Label: 파도, Encoded Label: 442
# 789  Original Label: 하늘, Encoded Label: 449
# 790  Original Label: 가시나무, Encoded Label: 7
# 791  Original Label: 강아지, Encoded Label: 21
# 792  Original Label: 구렁이, Encoded Label: 92
# 793  Original Label: 까마귀, Encoded Label: 120
# 794  Original Label: 꽃씨, Encoded Label: 121
# 795  Original Label: 꽃잎, Encoded Label: 122
# 796  Original Label: 웃는척, Encoded Label: 354
# 797  Original Label: 흡연실, Encoded Label: 482
# 798  Original Label: 무궁화, Encoded Label: 205
# 799  Original Label: 밤나무, Encoded Label: 212
# 800  Original Label: 벚꽃, Encoded Label: 224
# 801  Original Label: 깃털, Encoded Label: 119
# 802  Original Label: 솔잎, Encoded Label: 279
# 803  Original Label: 송아지, Encoded Label: 280
# 804  Original Label: 소뿔, Encoded Label: 274
# 805  Original Label: 양털, Encoded Label: 314
# 806  Original Label: 연꽃, Encoded Label: 331
# 807  Original Label: 참새, Encoded Label: 404
# 808  Original Label: 어젯밤, Encoded Label: 318
# 809  Original Label: 갈색, Encoded Label: 15
# 810  Original Label: 최상급, Encoded Label: 417
# 811  Original Label: 공휴일, Encoded Label: 68
# 812  Original Label: 세번째, Encoded Label: 270
# 813  Original Label: 네번째, Encoded Label: 137
# 814  Original Label: 흙내음, Encoded Label: 481
# 815  Original Label: 금요일, Encoded Label: 108
# 816  Original Label: 급행, Encoded Label: 112
# 817  Original Label: 남부지방, Encoded Label: 130
# 818  Original Label: 식목일, Encoded Label: 294
# 819  Original Label: 방금, Encoded Label: 215
# 820  Original Label: 100만원, Encoded Label: 0
# 821  Original Label: 보라색, Encoded Label: 230
# 822  Original Label: 분홍조명, Encoded Label: 237
# 823  Original Label: 분혹색, Encoded Label: 236
# 824  Original Label: 얼굴이빨개지다, Encoded Label: 319
# 825  Original Label: 사춘기, Encoded Label: 258
# 826  Original Label: 3.1절, Encoded Label: 2
# 827  Original Label: 생년월일, Encoded Label: 263
# 828  Original Label: 수요일, Encoded Label: 286
# 829  Original Label: 10만원, Encoded Label: 1
# 830  Original Label: 어떻게, Encoded Label: 315
# 831  Original Label: 어린이날, Encoded Label: 316
# 832  Original Label: 연말, Encoded Label: 333
# 833  Original Label: 예전, Encoded Label: 340
# 834  Original Label: 식전, Encoded Label: 295
# 835  Original Label: 월요일, Encoded Label: 356
# 836  Original Label: 일요일, Encoded Label: 370
# 837  Original Label: 자정, Encoded Label: 376
# 838  Original Label: 아까, Encoded Label: 307
# 839  Original Label: 진하기, Encoded Label: 400
# 840  Original Label: 검정머리, Encoded Label: 37
# 841  Original Label: 최대, Encoded Label: 416
# 842  Original Label: 최소, Encoded Label: 418
# 843  Original Label: 평일, Encoded Label: 445
# 844  Original Label: 한글날, Encoded Label: 456
# 845  Original Label: 현충일, Encoded Label: 461
# 846  Original Label: 화요일, Encoded Label: 464
# 847  Original Label: 황금색, Encoded Label: 468
# 848  Original Label: 흑백, Encoded Label: 478
# 849  Original Label: 흑색, Encoded Label: 480
# 850  Original Label: 임시협약, Encoded Label: 371
# 851  Original Label: 감금, Encoded Label: 16
# 852  Original Label: 탈춤, Encoded Label: 434
# 853  Original Label: 가명, Encoded Label: 4
# 854  Original Label: 가발, Encoded Label: 5
# 855  Original Label: 가위바위보, Encoded Label: 8
# 856  Original Label: 가족회의, Encoded Label: 10
# 857  Original Label: 가짜, Encoded Label: 12
# 858  Original Label: 서약서, Encoded Label: 264
# 859  Original Label: 간편, Encoded Label: 13
# 860  Original Label: 감옥, Encoded Label: 18
# 861  Original Label: 감옥살이, Encoded Label: 19
# 862  Original Label: 보호, Encoded Label: 232
# 863  Original Label: 견습, Encoded Label: 38
# 864  Original Label: 강약, Encoded Label: 22
# 865  Original Label: 강철, Encoded Label: 24
# 866  Original Label: 개똥, Encoded Label: 26
# 867  Original Label: 개명, Encoded Label: 27
# 868  Original Label: 신경쓰다, Encoded Label: 296
# 869  Original Label: 거목, Encoded Label: 30
# 870  Original Label: 거북선, Encoded Label: 31
# 871  Original Label: 거역, Encoded Label: 32
# 872  Original Label: 거지, Encoded Label: 33
# 873  Original Label: 건장, Encoded Label: 34
# 874  Original Label: 걸스카우트, Encoded Label: 35
# 875  Original Label: 거지, Encoded Label: 33
# 876  Original Label: 휴학, Encoded Label: 477
# 877  Original Label: 휴학, Encoded Label: 477
# 878  Original Label: 회칙, Encoded Label: 474
# 879  Original Label: 결승전, Encoded Label: 39
# 880  Original Label: 경찰행정, Encoded Label: 47
# 881  Original Label: 경비실, Encoded Label: 44
# 882  Original Label: 고아원, Encoded Label: 55
# 883  Original Label: 고춧잎, Encoded Label: 59
# 884  Original Label: 불알, Encoded Label: 241
# 885  Original Label: 황금기, Encoded Label: 467
# 886  Original Label: 골절, Encoded Label: 60
# 887  Original Label: 공식발표, Encoded Label: 66
# 888  Original Label: 맞추다, Encoded Label: 197
# 889  Original Label: 공군본부, Encoded Label: 63
# 890  Original Label: 공범, Encoded Label: 64
# 891  Original Label: 동거, Encoded Label: 175
# 892  Original Label: 공증, Encoded Label: 67
# 893  Original Label: 과로, Encoded Label: 69
# 894  Original Label: 실수, Encoded Label: 302
# 895  Original Label: 회상, Encoded Label: 471
# 896  Original Label: 과태료, Encoded Label: 71
# 897  Original Label: 관습, Encoded Label: 73
# 898  Original Label: 직인, Encoded Label: 398
# 899  Original Label: 정밀검사, Encoded Label: 389
# 900  Original Label: 대지, Encoded Label: 159
# 901  Original Label: 광업, Encoded Label: 74
# 902  Original Label: 미치광이, Encoded Label: 209
# 903  Original Label: 강풍, Encoded Label: 25
# 904  Original Label: 환대, Encoded Label: 466
# 905  Original Label: 교가, Encoded Label: 75
# 906  Original Label: 교기, Encoded Label: 76
# 907  Original Label: 지도, Encoded Label: 395
# 908  Original Label: 교기, Encoded Label: 76
# 909  Original Label: 교모, Encoded Label: 77
# 910  Original Label: 지도법, Encoded Label: 396
# 911  Original Label: 학습, Encoded Label: 452
# 912  Original Label: 지도, Encoded Label: 395
# 913  Original Label: 교육과정, Encoded Label: 82
# 914  Original Label: 교육청, Encoded Label: 84
# 915  Original Label: 교사직무, Encoded Label: 79
# 916  Original Label: 사거리, Encoded Label: 249
# 917  Original Label: 교탁, Encoded Label: 86
# 918  Original Label: 구두액, Encoded Label: 91
# 919  Original Label: 수갑, Encoded Label: 283
# 920  Original Label: 조직도, Encoded Label: 390
# 921  Original Label: 국그릇, Encoded Label: 94
# 922  Original Label: 국기, Encoded Label: 95
# 923  Original Label: 독립, Encoded Label: 163
# 924  Original Label: 군가, Encoded Label: 98
# 925  Original Label: 군마, Encoded Label: 99
# 926  Original Label: 다섯번째, Encoded Label: 146
# 927  Original Label: 군비행장, Encoded Label: 101
# 928  Original Label: 독재자, Encoded Label: 168
# 929  Original Label: 귀부인, Encoded Label: 102
# 930  Original Label: 상류층, Encoded Label: 259
# 931  Original Label: 모범, Encoded Label: 202
# 932  Original Label: 그날, Encoded Label: 104
# 933  Original Label: 기초확인, Encoded Label: 114
# 934  Original Label: 금식, Encoded Label: 106
# 935  Original Label: 얼마, Encoded Label: 320
# 936  Original Label: 금연, Encoded Label: 107
# 937  Original Label: 금욕, Encoded Label: 109
# 938  Original Label: 금주, Encoded Label: 110
# 939  Original Label: 불쌍, Encoded Label: 240
# 940  Original Label: 식도염, Encoded Label: 293
# 941  Original Label: 신기, Encoded Label: 297
# 942  Original Label: 신기, Encoded Label: 297
# 943  Original Label: 기혼, Encoded Label: 115
# 944  Original Label: 귀중품, Encoded Label: 103
# 945  Original Label: 길몽, Encoded Label: 116
# 946  Original Label: 길일, Encoded Label: 118
# 947  Original Label: 길운, Encoded Label: 117
# 948  Original Label: 고난이도, Encoded Label: 50
# 949  Original Label: 비좁다, Encoded Label: 246
# 950  Original Label: 유언, Encoded Label: 360
# 951  Original Label: 온실, Encoded Label: 342
# 952  Original Label: 고난이도, Encoded Label: 50
# 953  Original Label: 날쎄다, Encoded Label: 129
# 954  Original Label: 비루, Encoded Label: 244
# 955  Original Label: 쑥쓰럽다, Encoded Label: 306
# 956  Original Label: 남성적, Encoded Label: 132
# 957  Original Label: 내정, Encoded Label: 134
# 958  Original Label: 능숙, Encoded Label: 143
# 959  Original Label: 대모, Encoded Label: 157
# 960  Original Label: 농인, Encoded Label: 139
# 961  Original Label: 다복, Encoded Label: 145
# 962  Original Label: 결합을끊다, Encoded Label: 40
# 963  Original Label: 단명, Encoded Label: 147
# 964  Original Label: 단문, Encoded Label: 148
# 965  Original Label: 능력자, Encoded Label: 142
# 966  Original Label: 곰방대, Encoded Label: 61
# 967  Original Label: 담당, Encoded Label: 151
# 968  Original Label: 답안지, Encoded Label: 152
# 969  Original Label: 책임이사, Encoded Label: 409
# 970  Original Label: 채용자, Encoded Label: 407
# 971  Original Label: 대교, Encoded Label: 154
# 972  Original Label: 대독, Encoded Label: 156
# 973  Original Label: 대필, Encoded Label: 160
# 974  Original Label: 대성공, Encoded Label: 158
# 975  Original Label: 세수대야, Encoded Label: 271
# 976  Original Label: 확정, Encoded Label: 465
# 977  Original Label: 면적, Encoded Label: 201
# 978  Original Label: 회장, Encoded Label: 473
# 979  Original Label: 품격, Encoded Label: 447
# 980  Original Label: 도벽, Encoded Label: 161
# 981  Original Label: 도자기기술, Encoded Label: 162
# 982  Original Label: 자습, Encoded Label: 375
# 983  Original Label: 돌기둥, Encoded Label: 170
# 984  Original Label: 돌다리, Encoded Label: 171
# 985  Original Label: 돌벽, Encoded Label: 173
# 986  Original Label: 동갑, Encoded Label: 174
# 987  Original Label: 동메달, Encoded Label: 176
# 988  Original Label: 주민센터, Encoded Label: 392
# 989  Original Label: 독특, Encoded Label: 169
# 990  Original Label: 무덤덤, Encoded Label: 206
# 991  Original Label: 뒷산, Encoded Label: 183
# 992  Original Label: 등록금, Encoded Label: 185
# 993  Original Label: 담당, Encoded Label: 151
# 994  Original Label: 생각못하다, Encoded Label: 262
# 995  Original Label: 주문서, Encoded Label: 391
# 996  Original Label: 마구간, Encoded Label: 191
# 997  Original Label: 마술사, Encoded Label: 192
# 998  Original Label: 마스크, Encoded Label: 193
# 999  Original Label: 마음에들다, Encoded Label: 195
# 1000  Original Label: 고민, Encoded Label: 53
# 1001  Original Label: 뻔뻔, Encoded Label: 248
# 1002  Original Label: 수어, Encoded Label: 285
# 1003  Original Label: 남아, Encoded Label: 133
# 1004  Original Label: 눈, Encoded Label: 140
# 1005  Original Label: 독신, Encoded Label: 166
# 1006  Original Label: 음료수, Encoded Label: 362
# 1007  Original Label: 발가락, Encoded Label: 211
# 1008  Original Label: 슬프다, Encoded Label: 291
# 1009  Original Label: 자극, Encoded Label: 374
# 1010  Original Label: 안타깝다, Encoded Label: 309
# 1011  Original Label: 어색하다, Encoded Label: 317
# 1012  Original Label: 여아, Encoded Label: 323
# 1013  Original Label: 외국인, Encoded Label: 346
# 1014  Original Label: 영아, Encoded Label: 335
# 1015  Original Label: 신사, Encoded Label: 298
# 1016  Original Label: 뉴질랜드, Encoded Label: 141
# 1017  Original Label: 나사렛대학교, Encoded Label: 125
# 1018  Original Label: 알아서, Encoded Label: 310
# 1019  Original Label: 장애인, Encoded Label: 381
# 1020  Original Label: 열아홉번째, Encoded Label: 334
# 1021  Original Label: 침착, Encoded Label: 428
# 1022  Original Label: 성실, Encoded Label: 269
# 1023  Original Label: 학교연혁, Encoded Label: 450
# 1024  Original Label: 싫어하다, Encoded Label: 304
# 1025  Original Label: 급하다, Encoded Label: 111
# 1026  Original Label: 필기시험, Encoded Label: 448
# 1027  Original Label: 병문안, Encoded Label: 227
# 1028  Original Label: 검사, Encoded Label: 36
# 1029  Original Label: 결승전, Encoded Label: 39
# 1030  Original Label: 낚시터, Encoded Label: 128
# 1031  Original Label: 낚시대, Encoded Label: 127
# 1032  Original Label: 당뇨병, Encoded Label: 153
# 1033  Original Label: 독서, Encoded Label: 164
# 1034  Original Label: 매표소, Encoded Label: 198
# 1035  Original Label: 면역, Encoded Label: 200
# 1036  Original Label: 감기, Encoded Label: 17
# 1037  Original Label: 배드민턴, Encoded Label: 217
# 1038  Original Label: 변비, Encoded Label: 225
# 1039  Original Label: 병명, Encoded Label: 226
# 1040  Original Label: 보건소, Encoded Label: 229
# 1041  Original Label: 불면증, Encoded Label: 239
# 1042  Original Label: 불행, Encoded Label: 242
# 1043  Original Label: 붕대, Encoded Label: 243
# 1044  Original Label: 사위, Encoded Label: 254
# 1045  Original Label: 설사, Encoded Label: 266
# 1046  Original Label: 성병, Encoded Label: 268
# 1047  Original Label: 방충, Encoded Label: 216
# 1048  Original Label: 소화제, Encoded Label: 276
# 1049  Original Label: 손녀, Encoded Label: 277
# 1050  Original Label: 손자, Encoded Label: 278
# 1051  Original Label: 수면제, Encoded Label: 284
# 1052  Original Label: 수집가, Encoded Label: 288
# 1053  Original Label: 여행지, Encoded Label: 327
# 1054  Original Label: 예식장, Encoded Label: 339
# 1055  Original Label: 올림픽경기, Encoded Label: 343
# 1056  Original Label: 회복, Encoded Label: 470
# 1057  Original Label: 첫번째, Encoded Label: 410
# 1058  Original Label: 운동경기, Encoded Label: 349
# 1059  Original Label: 입원, Encoded Label: 372
# 1060  Original Label: 재혼, Encoded Label: 385
# 1061  Original Label: 진단서, Encoded Label: 399
# 1062  Original Label: 축구장, Encoded Label: 419
# 1063  Original Label: 치료, Encoded Label: 424
# 1064  Original Label: 치료법, Encoded Label: 425
# 1065  Original Label: 친아들, Encoded Label: 427
# 1066  Original Label: 퇴원, Encoded Label: 440
# 1067  Original Label: 한약, Encoded Label: 457
# 1068  Original Label: 한약방, Encoded Label: 458
# 1069  Original Label: 빈혈, Encoded Label: 247
# 1070  Original Label: 화상, Encoded Label: 462
# 1071  Original Label: 가래떡, Encoded Label: 3
# 1072  Original Label: 고깃국, Encoded Label: 49
# 1073  Original Label: 고추, Encoded Label: 57
# 1074  Original Label: 고추가루, Encoded Label: 58
# 1075  Original Label: 사골, Encoded Label: 250
# 1076  Original Label: 배추국, Encoded Label: 218
# 1077  Original Label: 꽈베기, Encoded Label: 123
# 1078  Original Label: 벌꿀, Encoded Label: 223
# 1079  Original Label: 꿀물, Encoded Label: 124
# ...
# 140  Original Label: 교장, Encoded Label: 85
# 141  Original Label: 찻길, Encoded Label: 406
# 142  Original Label: 독일어, Encoded Label: 167
# 143  Original Label: 반환, Encoded Label: 210
# 144  Original Label: 음주운전, Encoded Label: 364
# 145  Original Label: 동아리, Encoded Label: 177
# 146  Original Label: 디자이너, Encoded Label: 186
# 147  Original Label: 마을버스, Encoded Label: 194
# 148  Original Label: 구급차, Encoded Label: 90
# 149  Original Label: 개입하지않는다, Encoded Label: 28
# 150  Original Label: 음주운전, Encoded Label: 364
# 151  Original Label: 사무, Encoded Label: 252
# 152  Original Label: 신입학, Encoded Label: 300
# 153  Original Label: 여객선, Encoded Label: 322
# 154  Original Label: 여행사, Encoded Label: 326
# 155  Original Label: 기차역, Encoded Label: 113
# 156  Original Label: 예술가, Encoded Label: 337
# 157  Original Label: 외국어, Encoded Label: 345
# 158  Original Label: 요리사, Encoded Label: 347
# 159  Original Label: 강요, Encoded Label: 23
# 160  Original Label: 운동선수, Encoded Label: 350
# 161  Original Label: 퇴임, Encoded Label: 441
# 162  Original Label: 의사, Encoded Label: 365
# 163  Original Label: 이력서, Encoded Label: 367
# 164  Original Label: 자가용, Encoded Label: 373
# 165  Original Label: 재택근무, Encoded Label: 383
# 166  Original Label: 연령제한, Encoded Label: 332
# 167  Original Label: 주차장, Encoded Label: 394
# 168  Original Label: 채팅, Encoded Label: 408
# 169  Original Label: 출근, Encoded Label: 421
# 170  Original Label: 코치, Encoded Label: 431
# 171  Original Label: 터미널, Encoded Label: 435
# 172  Original Label: 근무, Encoded Label: 105
# 173  Original Label: 통역사, Encoded Label: 437
# 174  Original Label: 퇴사, Encoded Label: 439
# 175  Original Label: 사직, Encoded Label: 257
# 176  Original Label: 판결, Encoded Label: 443
# 177  Original Label: 평가, Encoded Label: 444
# 178  Original Label: 두번째, Encoded Label: 181
# 179  Original Label: 항공사, Encoded Label: 459
# 180  Original Label: 교통안전교육, Encoded Label: 89
# 181  Original Label: 화상채팅, Encoded Label: 463
# 182  Original Label: 회식, Encoded Label: 472
# 183  Original Label: 교통기본교육, Encoded Label: 87
# 184  Original Label: 후원, Encoded Label: 475
# 185  Original Label: 희생, Encoded Label: 483
# 186  Original Label: 간호사, Encoded Label: 14
# 187  Original Label: 교통법교육, Encoded Label: 88
# 188  Original Label: 계약금, Encoded Label: 48
# 189  Original Label: 고용, Encoded Label: 56
# 190  Original Label: 사업장, Encoded Label: 253
# 191  Original Label: 버스값, Encoded Label: 222
# 192  Original Label: 구직, Encoded Label: 93
# 193  Original Label: 논, Encoded Label: 138
# 194  Original Label: 대기업, Encoded Label: 155
# 195  Original Label: 사육장, Encoded Label: 255
# 196  Original Label: 백화점, Encoded Label: 221
# 197  Original Label: 압류, Encoded Label: 311
# 198  Original Label: 거지, Encoded Label: 33
# 199  Original Label: 수입, Encoded Label: 287
# 200  Original Label: 신용카드, Encoded Label: 299
# 201  Original Label: 백수, Encoded Label: 220
# 202  Original Label: 아르바이트, Encoded Label: 308
# 203  Original Label: 샛길, Encoded Label: 261
# 204  Original Label: 일시불, Encoded Label: 369
# 205  Original Label: 주유소, Encoded Label: 393
# 206  Original Label: 집주인, Encoded Label: 401
# 207  Original Label: 한국은행, Encoded Label: 455
# 208  Original Label: 경찰청장, Encoded Label: 46
# 209  Original Label: 가정교육, Encoded Label: 9
# 210  Original Label: 고등학교, Encoded Label: 51
# 211  Original Label: 고등학생, Encoded Label: 52
# 212  Original Label: 교무실, Encoded Label: 78
# 213  Original Label: 개학, Encoded Label: 29
# 214  Original Label: 교실, Encoded Label: 81
# 215  Original Label: 교육자, Encoded Label: 83
# 216  Original Label: 국어학, Encoded Label: 96
# 217  Original Label: 낙제, Encoded Label: 126
# 218  Original Label: 예절, Encoded Label: 341
# 219  Original Label: 독서실, Encoded Label: 165
# 220  Original Label: 등교, Encoded Label: 184
# 221  Original Label: 맹학교, Encoded Label: 199
# 222  Original Label: 복습, Encoded Label: 233
# 223  Original Label: 분필, Encoded Label: 235
# 224  Original Label: 상장, Encoded Label: 260
# 225  Original Label: 서점, Encoded Label: 265
# 226  Original Label: 학업, Encoded Label: 454
# 227  Original Label: 실습, Encoded Label: 303
# 228  Original Label: 여학교, Encoded Label: 324
# 229  Original Label: 여학생, Encoded Label: 325
# 230  Original Label: 연구소, Encoded Label: 329
# 231  Original Label: 연구실, Encoded Label: 330
# 232  Original Label: 예습, Encoded Label: 338
# 233  Original Label: 유학, Encoded Label: 361
# 234  Original Label: 의학, Encoded Label: 366
# 235  Original Label: 지도, Encoded Label: 395
# 236  Original Label: 재학, Encoded Label: 384
# 237  Original Label: 연구, Encoded Label: 328
# 238  Original Label: 학부모, Encoded Label: 451
# 239  Original Label: 학식, Encoded Label: 453
# 240  Original Label: 훈련, Encoded Label: 476
# 241  Original Label: 경기도, Encoded Label: 42
# 242  Original Label: 경기도, Encoded Label: 42
# 243  Original Label: 경북, Encoded Label: 43
# 244  Original Label: 남산, Encoded Label: 131
# 245  Original Label: 울릉도, Encoded Label: 352
# 246  Original Label: 울산, Encoded Label: 353
# 247  Original Label: 전남, Encoded Label: 386
# 248  Original Label: 청주, Encoded Label: 411
# 249  Original Label: 충북, Encoded Label: 423
# 250  Original Label: 충남, Encoded Label: 422
# 251  Original Label: 불경, Encoded Label: 238
# 252  Original Label: 불경, Encoded Label: 238
# 253  Original Label: 성경책, Encoded Label: 267
# 254  Original Label: 신학, Encoded Label: 301
# 255  Original Label: 장로교, Encoded Label: 379
# 256  Original Label: 일요일, Encoded Label: 370
# 257  Original Label: 축하, Encoded Label: 420
# 258  Original Label: 회개, Encoded Label: 469
# 259  Original Label: 소감, Encoded Label: 272
# 260  Original Label: 장난, Encoded Label: 378
# 261  Original Label: 장인, Encoded Label: 382
# 262  Original Label: 희생자, Encoded Label: 484
# 263  Original Label: 디자인, Encoded Label: 187
# 264  Original Label: 돌무덤, Encoded Label: 172
# 265  Original Label: 쇠기둥, Encoded Label: 281
# 266  Original Label: 동화책, Encoded Label: 178
# 267  Original Label: 목공예, Encoded Label: 203
# 268  Original Label: 문학, Encoded Label: 207
# 269  Original Label: 문화유산, Encoded Label: 208
# 270  Original Label: 음악가, Encoded Label: 363
# 271  Original Label: 예술, Encoded Label: 336
# 272  Original Label: 초상화, Encoded Label: 414
# 273  Original Label: 토기, Encoded Label: 436
# 274  Original Label: 흑백영화, Encoded Label: 479
# 275  Original Label: 공군, Encoded Label: 62
# 276  Original Label: 감옥, Encoded Label: 18
# 277  Original Label: 국왕, Encoded Label: 97
# 278  Original Label: 보건복지, Encoded Label: 228
# 279  Original Label: 고소, Encoded Label: 54
# 280  Original Label: 유권자, Encoded Label: 358
# 281  Original Label: 절도죄, Encoded Label: 388
# 282  Original Label: 수감자, Encoded Label: 282
# 283  Original Label: 총무, Encoded Label: 415
# 284  Original Label: 강, Encoded Label: 20
# 285  Original Label: 달빛, Encoded Label: 150
# 286  Original Label: 장마, Encoded Label: 380
# 287  Original Label: 체온, Encoded Label: 413
# 288  Original Label: 파도, Encoded Label: 442
# 289  Original Label: 하늘, Encoded Label: 449
# 290  Original Label: 가시나무, Encoded Label: 7
# 291  Original Label: 강아지, Encoded Label: 21
# 292  Original Label: 구렁이, Encoded Label: 92
# 293  Original Label: 까마귀, Encoded Label: 120
# 294  Original Label: 꽃씨, Encoded Label: 121
# 295  Original Label: 꽃잎, Encoded Label: 122
# 296  Original Label: 웃는척, Encoded Label: 354
# 297  Original Label: 흡연실, Encoded Label: 482
# 298  Original Label: 무궁화, Encoded Label: 205
# 299  Original Label: 밤나무, Encoded Label: 212
# 300  Original Label: 벚꽃, Encoded Label: 224
# 301  Original Label: 깃털, Encoded Label: 119
# 302  Original Label: 솔잎, Encoded Label: 279
# 303  Original Label: 송아지, Encoded Label: 280
# 304  Original Label: 소뿔, Encoded Label: 274
# 305  Original Label: 양털, Encoded Label: 314
# 306  Original Label: 연꽃, Encoded Label: 331
# 307  Original Label: 참새, Encoded Label: 404
# 308  Original Label: 어젯밤, Encoded Label: 318
# 309  Original Label: 갈색, Encoded Label: 15
# 310  Original Label: 최상급, Encoded Label: 417
# 311  Original Label: 공휴일, Encoded Label: 68
# 312  Original Label: 세번째, Encoded Label: 270
# 313  Original Label: 네번째, Encoded Label: 137
# 314  Original Label: 흙내음, Encoded Label: 481
# 315  Original Label: 금요일, Encoded Label: 108
# 316  Original Label: 급행, Encoded Label: 112
# 317  Original Label: 남부지방, Encoded Label: 130
# 318  Original Label: 식목일, Encoded Label: 294
# 319  Original Label: 방금, Encoded Label: 215
# 320  Original Label: 100만원, Encoded Label: 0
# 321  Original Label: 보라색, Encoded Label: 230
# 322  Original Label: 분홍조명, Encoded Label: 237
# 323  Original Label: 분혹색, Encoded Label: 236
# 324  Original Label: 얼굴이빨개지다, Encoded Label: 319
# 325  Original Label: 사춘기, Encoded Label: 258
# 326  Original Label: 3.1절, Encoded Label: 2
# 327  Original Label: 생년월일, Encoded Label: 263
# 328  Original Label: 수요일, Encoded Label: 286
# 329  Original Label: 10만원, Encoded Label: 1
# 330  Original Label: 어떻게, Encoded Label: 315
# 331  Original Label: 어린이날, Encoded Label: 316
# 332  Original Label: 연말, Encoded Label: 333
# 333  Original Label: 예전, Encoded Label: 340
# 334  Original Label: 식전, Encoded Label: 295
# 335  Original Label: 월요일, Encoded Label: 356
# 336  Original Label: 일요일, Encoded Label: 370
# 337  Original Label: 자정, Encoded Label: 376
# 338  Original Label: 아까, Encoded Label: 307
# 339  Original Label: 진하기, Encoded Label: 400
# 340  Original Label: 검정머리, Encoded Label: 37
# 341  Original Label: 최대, Encoded Label: 416
# 342  Original Label: 최소, Encoded Label: 418
# 343  Original Label: 평일, Encoded Label: 445
# 344  Original Label: 한글날, Encoded Label: 456
# 345  Original Label: 현충일, Encoded Label: 461
# 346  Original Label: 화요일, Encoded Label: 464
# 347  Original Label: 황금색, Encoded Label: 468
# 348  Original Label: 흑백, Encoded Label: 478
# 349  Original Label: 흑색, Encoded Label: 480
# 350  Original Label: 임시협약, Encoded Label: 371
# 351  Original Label: 감금, Encoded Label: 16
# 352  Original Label: 탈춤, Encoded Label: 434
# 353  Original Label: 가명, Encoded Label: 4
# 354  Original Label: 가발, Encoded Label: 5
# 355  Original Label: 가위바위보, Encoded Label: 8
# 356  Original Label: 가족회의, Encoded Label: 10
# 357  Original Label: 가짜, Encoded Label: 12
# 358  Original Label: 서약서, Encoded Label: 264
# 359  Original Label: 간편, Encoded Label: 13
# 360  Original Label: 감옥, Encoded Label: 18
# 361  Original Label: 감옥살이, Encoded Label: 19
# 362  Original Label: 보호, Encoded Label: 232
# 363  Original Label: 견습, Encoded Label: 38
# 364  Original Label: 강약, Encoded Label: 22
# 365  Original Label: 강철, Encoded Label: 24
# 366  Original Label: 개똥, Encoded Label: 26
# 367  Original Label: 개명, Encoded Label: 27
# 368  Original Label: 신경쓰다, Encoded Label: 296
# 369  Original Label: 거목, Encoded Label: 30
# 370  Original Label: 거북선, Encoded Label: 31
# 371  Original Label: 거역, Encoded Label: 32
# 372  Original Label: 거지, Encoded Label: 33
# 373  Original Label: 건장, Encoded Label: 34
# 374  Original Label: 걸스카우트, Encoded Label: 35
# 375  Original Label: 거지, Encoded Label: 33
# 376  Original Label: 휴학, Encoded Label: 477
# 377  Original Label: 휴학, Encoded Label: 477
# 378  Original Label: 회칙, Encoded Label: 474
# 379  Original Label: 결승전, Encoded Label: 39
# 380  Original Label: 경찰행정, Encoded Label: 47
# 381  Original Label: 경비실, Encoded Label: 44
# 382  Original Label: 고아원, Encoded Label: 55
# 383  Original Label: 고춧잎, Encoded Label: 59
# 384  Original Label: 불알, Encoded Label: 241
# 385  Original Label: 황금기, Encoded Label: 467
# 386  Original Label: 골절, Encoded Label: 60
# 387  Original Label: 공식발표, Encoded Label: 66
# 388  Original Label: 맞추다, Encoded Label: 197
# 389  Original Label: 공군본부, Encoded Label: 63
# 390  Original Label: 공범, Encoded Label: 64
# 391  Original Label: 동거, Encoded Label: 175
# 392  Original Label: 공증, Encoded Label: 67
# 393  Original Label: 과로, Encoded Label: 69
# 394  Original Label: 실수, Encoded Label: 302
# 395  Original Label: 회상, Encoded Label: 471
# 396  Original Label: 과태료, Encoded Label: 71
# 397  Original Label: 관습, Encoded Label: 73
# 398  Original Label: 직인, Encoded Label: 398
# 399  Original Label: 정밀검사, Encoded Label: 389
# 400  Original Label: 대지, Encoded Label: 159
# 401  Original Label: 광업, Encoded Label: 74
# 402  Original Label: 미치광이, Encoded Label: 209
# 403  Original Label: 강풍, Encoded Label: 25
# 404  Original Label: 환대, Encoded Label: 466
# 405  Original Label: 교가, Encoded Label: 75
# 406  Original Label: 교기, Encoded Label: 76
# 407  Original Label: 지도, Encoded Label: 395
# 408  Original Label: 교기, Encoded Label: 76
# 409  Original Label: 교모, Encoded Label: 77
# 410  Original Label: 지도법, Encoded Label: 396
# 411  Original Label: 학습, Encoded Label: 452
# 412  Original Label: 지도, Encoded Label: 395
# 413  Original Label: 교육과정, Encoded Label: 82
# 414  Original Label: 교육청, Encoded Label: 84
# 415  Original Label: 교사직무, Encoded Label: 79
# 416  Original Label: 사거리, Encoded Label: 249
# 417  Original Label: 교탁, Encoded Label: 86
# 418  Original Label: 구두액, Encoded Label: 91
# 419  Original Label: 수갑, Encoded Label: 283
# 420  Original Label: 조직도, Encoded Label: 390
# 421  Original Label: 국그릇, Encoded Label: 94
# 422  Original Label: 국기, Encoded Label: 95
# 423  Original Label: 독립, Encoded Label: 163
# 424  Original Label: 군가, Encoded Label: 98
# 425  Original Label: 군마, Encoded Label: 99
# 426  Original Label: 다섯번째, Encoded Label: 146
# 427  Original Label: 군비행장, Encoded Label: 101
# 428  Original Label: 독재자, Encoded Label: 168
# 429  Original Label: 귀부인, Encoded Label: 102
# 430  Original Label: 상류층, Encoded Label: 259
# 431  Original Label: 모범, Encoded Label: 202
# 432  Original Label: 그날, Encoded Label: 104
# 433  Original Label: 기초확인, Encoded Label: 114
# 434  Original Label: 금식, Encoded Label: 106
# 435  Original Label: 얼마, Encoded Label: 320
# 436  Original Label: 금연, Encoded Label: 107
# 437  Original Label: 금욕, Encoded Label: 109
# 438  Original Label: 금주, Encoded Label: 110
# 439  Original Label: 불쌍, Encoded Label: 240
# 440  Original Label: 식도염, Encoded Label: 293
# 441  Original Label: 신기, Encoded Label: 297
# 442  Original Label: 신기, Encoded Label: 297
# 443  Original Label: 기혼, Encoded Label: 115
# 444  Original Label: 귀중품, Encoded Label: 103
# 445  Original Label: 길몽, Encoded Label: 116
# 446  Original Label: 길일, Encoded Label: 118
# 447  Original Label: 길운, Encoded Label: 117
# 448  Original Label: 고난이도, Encoded Label: 50
# 449  Original Label: 비좁다, Encoded Label: 246
# 450  Original Label: 유언, Encoded Label: 360
# 451  Original Label: 온실, Encoded Label: 342
# 452  Original Label: 고난이도, Encoded Label: 50
# 453  Original Label: 날쎄다, Encoded Label: 129
# 454  Original Label: 비루, Encoded Label: 244
# 455  Original Label: 쑥쓰럽다, Encoded Label: 306
# 456  Original Label: 남성적, Encoded Label: 132
# 457  Original Label: 내정, Encoded Label: 134
# 458  Original Label: 능숙, Encoded Label: 143
# 459  Original Label: 대모, Encoded Label: 157
# 460  Original Label: 농인, Encoded Label: 139
# 461  Original Label: 다복, Encoded Label: 145
# 462  Original Label: 결합을끊다, Encoded Label: 40
# 463  Original Label: 단명, Encoded Label: 147
# 464  Original Label: 단문, Encoded Label: 148
# 465  Original Label: 능력자, Encoded Label: 142
# 466  Original Label: 곰방대, Encoded Label: 61
# 467  Original Label: 담당, Encoded Label: 151
# 468  Original Label: 답안지, Encoded Label: 152
# 469  Original Label: 책임이사, Encoded Label: 409
# 470  Original Label: 채용자, Encoded Label: 407
# 471  Original Label: 대교, Encoded Label: 154
# 472  Original Label: 대독, Encoded Label: 156
# 473  Original Label: 대필, Encoded Label: 160
# 474  Original Label: 대성공, Encoded Label: 158
# 475  Original Label: 세수대야, Encoded Label: 271
# 476  Original Label: 확정, Encoded Label: 465
# 477  Original Label: 면적, Encoded Label: 201
# 478  Original Label: 회장, Encoded Label: 473
# 479  Original Label: 품격, Encoded Label: 447
# 480  Original Label: 도벽, Encoded Label: 161
# 481  Original Label: 도자기기술, Encoded Label: 162
# 482  Original Label: 자습, Encoded Label: 375
# 483  Original Label: 돌기둥, Encoded Label: 170
# 484  Original Label: 돌다리, Encoded Label: 171
# 485  Original Label: 돌벽, Encoded Label: 173
# 486  Original Label: 동갑, Encoded Label: 174
# 487  Original Label: 동메달, Encoded Label: 176
# 488  Original Label: 주민센터, Encoded Label: 392
# 489  Original Label: 독특, Encoded Label: 169
# 490  Original Label: 무덤덤, Encoded Label: 206
# 491  Original Label: 뒷산, Encoded Label: 183
# 492  Original Label: 등록금, Encoded Label: 185
# 493  Original Label: 담당, Encoded Label: 151
# 494  Original Label: 생각못하다, Encoded Label: 262
# 495  Original Label: 주문서, Encoded Label: 391
# 496  Original Label: 마구간, Encoded Label: 191
# 497  Original Label: 마술사, Encoded Label: 192
# 498  Original Label: 마스크, Encoded Label: 193
# 499  Original Label: 마음에들다, Encoded Label: 195

# %%
# 모델 초기화
input_dim = 70 * 3 # 각 키포인트의 2D 좌표(2)와 3D 좌표(3)를 사용
model_dim = 512  # 모델 차원
num_heads = 8  # 멀티헤드 어텐션의 헤드 수
num_layers = 3  # Transformer 레이어 수
num_classes = 2771  # 출력 클래스 수

learning_rate = 0.0001

num_epochs = 20
batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,  collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False,  collate_fn=collate_fn)

model = MultiEncoderTransformerModel(input_dim, model_dim, num_heads, num_layers, num_classes).to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
batch = next(iter(train_loader))

sequences, labels, lengths, idx = batch

print(f"Batch Sequence Shapes: {[seq.shape for seq in sequences]}")
print(f"idx: {idx}")
print(f"origin_word: {[train_encoded_labels[i] for i in idx]}")
print(f"Batch Labels: {labels}")
print(f"Batch Lengths: {lengths}")
# Out:
# Batch Sequence Shapes: [torch.Size([64, 3, 66, 70]), torch.Size([64, 3, 66, 70]), torch.Size([64, 3, 66, 70]), torch.Size([64, 3, 66, 70])]
# idx: (1464, 22, 137, 1612, 809, 1298, 158, 1952, 1412, 559, 1452, 1646, 1807, 1888, 1311, 1932, 893, 698, 1220, 1603, 1393, 914, 1780, 98, 1257, 1080, 722, 1273, 1038, 328, 635, 992, 477, 383, 652, 1297, 976, 1016, 550, 1043, 1554, 804, 867, 1861, 1406, 1150, 538, 631, 415, 1560, 1427, 526, 1851, 1166, 108, 27, 650, 1438, 1171, 1013, 1582, 307, 824, 1201)
# origin_word: [np.int64(148), np.int64(269), np.int64(70), np.int64(405), np.int64(15), np.int64(205), np.int64(347), np.int64(50), np.int64(395), np.int64(372), np.int64(50), np.int64(186), np.int64(404), np.int64(197), np.int64(68), np.int64(104), np.int64(69), np.int64(33), np.int64(184), np.int64(292), np.int64(69), np.int64(84), np.int64(358), np.int64(251), np.int64(420), np.int64(135), np.int64(233), np.int64(436), np.int64(225), np.int64(286), np.int64(45), np.int64(185), np.int64(201), np.int64(59), np.int64(300), np.int64(482), np.int64(465), np.int64(141), np.int64(278), np.int64(243), np.int64(339), np.int64(274), np.int64(27), np.int64(19), np.int64(76), np.int64(364), np.int64(225), np.int64(426), np.int64(79), np.int64(385), np.int64(101), np.int64(448), np.int64(16), np.int64(332), np.int64(289), np.int64(227), np.int64(364), np.int64(110), np.int64(435), np.int64(346), np.int64(144), np.int64(404), np.int64(319), np.int64(220)]
# Batch Labels: tensor([148, 269,  70, 405,  15, 205, 347,  50, 395, 372,  50, 186, 404, 197,
#          68, 104,  69,  33, 184, 292,  69,  84, 358, 251, 420, 135, 233, 436,
#         225, 286,  45, 185, 201,  59, 300, 482, 465, 141, 278, 243, 339, 274,
#          27,  19,  76, 364, 225, 426,  79, 385, 101, 448,  16, 332, 289, 227,
#         364, 110, 435, 346, 144, 404, 319, 220])
# Batch Lengths: tensor([43, 43, 43, 43])

# %%
for epoch in range(num_epochs):
    model.train()
    for (face_sequence, pose_sequence, left_hand_sequence, right_hand_sequence), labels, lengths, idx in train_loader:

    
        face_sequence = face_sequence.to(device)
        pose_sequence = pose_sequence.to(device)
        left_hand_sequence = left_hand_sequence.to(device)
        right_hand_sequence = right_hand_sequence.to(device)
        labels = labels.to(device)
        
        # 마스킹 생성
        face_src_key_padding_mask = (face_sequence.sum(dim=-1) == 0)
        face_src_key_padding_mask = face_src_key_padding_mask.any(dim=1).to(device)
        pose_src_key_padding_mask = (pose_sequence.sum(dim=-1) == 0)
        pose_src_key_padding_mask = pose_src_key_padding_mask.any(dim=1).to(device)
        left_src_key_padding_mask = (left_hand_sequence.sum(dim=-1) == 0)
        left_src_key_padding_mask = left_src_key_padding_mask.any(dim=1).to(device)
        right_src_key_padding_mask = (right_hand_sequence.sum(dim=-1) == 0)
        right_src_key_padding_mask = right_src_key_padding_mask.any(dim=1).to(device)

        # 입력 텐서 변환: [batch_size, 3, seq_len, num_joints] -> [batch_size, seq_len, 3 * num_joints]
        batch_size, coord, seq_len, num_joints = face_sequence.size()
        face_sequence = face_sequence.permute(0, 2, 3, 1).contiguous()  # [batch_size, seq_len, num_joints, coord]
        face_sequence = face_sequence.view(batch_size, seq_len, -1)  # [batch_size, seq_len, num_joints * coord]
        
        batch_size, coord, seq_len, num_joints = pose_sequence.size()
        pose_sequence = pose_sequence.permute(0, 2, 3, 1).contiguous()  # [batch_size, seq_len, num_joints, coord]
        pose_sequence = pose_sequence.view(batch_size, seq_len, -1)  # [batch_size, seq_len, num_joints * coord]
        
        batch_size, coord, seq_len, num_joints = left_hand_sequence.size()
        left_hand_sequence = left_hand_sequence.permute(0, 2, 3, 1).contiguous()  # [batch_size, seq_len, num_joints, coord]
        left_hand_sequence = left_hand_sequence.view(batch_size, seq_len, -1)  # [batch_size, seq_len, num_joints * coord]
        
        batch_size, coord, seq_len, num_joints = right_hand_sequence.size()
        right_hand_sequence = right_hand_sequence.permute(0, 2, 3, 1).contiguous()  # [batch_size, seq_len, num_joints, coord]
        right_hand_sequence = right_hand_sequence.view(batch_size, seq_len, -1)  # [batch_size, seq_len, num_joints * coord]
        

        # Forward pass
        outputs = model(face_sequence, pose_sequence, left_hand_sequence, right_hand_sequence, face_src_key_padding_mask, pose_src_key_padding_mask, left_src_key_padding_mask, right_src_key_padding_mask)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
    
    print("epoch:", epoch)
    print(f' Loss: {loss.item():.4f}')
# Out:
# epoch: 0
#  Loss: 6.7982
# epoch: 1
#  Loss: 6.4162
# epoch: 2
#  Loss: 6.4639
# epoch: 3
#  Loss: 6.4326
# epoch: 4
#  Loss: 6.4034
# epoch: 5
#  Loss: 6.0066
# epoch: 6
#  Loss: 6.4408
# epoch: 7
#  Loss: 6.1401
# epoch: 8
#  Loss: 6.0992
# epoch: 9
#  Loss: 5.6206
# epoch: 10
#  Loss: 5.3548
# epoch: 11
#  Loss: 5.0769
# epoch: 12
#  Loss: 5.1882
# epoch: 13
#  Loss: 4.8830
# epoch: 14
#  Loss: 4.8014
# epoch: 15
#  Loss: 4.6861
# epoch: 16
#  Loss: 4.4659
# epoch: 17
#  Loss: 4.3497
# epoch: 18
#  Loss: 3.7853
# epoch: 19
#  Loss: 3.6928
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Validation loop
model.eval()
val_loss = 0

def create_padding_mask(sequences, pad_token=0):
    return (sequences == pad_token)

with torch.no_grad():
    for (face_sequence, pose_sequence, left_hand_sequence, right_hand_sequence), labels, lengths in val_loader:
        
        mean = torch.mean(face_sequence)
        std = torch.std(face_sequence)
        face_sequence = (face_sequence - mean) / std
        
        mean = torch.mean(pose_sequence)
        std = torch.std(pose_sequence)
        pose_sequence = (pose_sequence - mean) / std
        
        mean = torch.mean(left_hand_sequence)
        std = torch.std(left_hand_sequence)
        left_hand_sequence = (left_hand_sequence - mean) / std
        
        mean = torch.mean(right_hand_sequence)
        std = torch.std(right_hand_sequence)
        right_hand_sequence = (right_hand_sequence - mean) / std
        
        face_sequence, pose_sequence, left_hand_sequence, right_hand_sequence = face_sequence.to(device), pose_sequence.to(device), left_hand_sequence.to(device), right_hand_sequence.to(device)
        labels = labels.to(device)

        # 입력 텐서 변환: [batch_size, 3, seq_len, num_joints] -> [batch_size, seq_len, 3 * num_joints]
        batch_size, coord, seq_len, num_joints = face_sequence.size()
        face_sequence = face_sequence.permute(0, 2, 3, 1).contiguous()  # [batch_size, seq_len, num_joints, coord]
        face_sequence = face_sequence.view(batch_size, seq_len, -1)  # [batch_size, seq_len, num_joints * coord]
        
        batch_size, coord, seq_len, num_joints = pose_sequence.size()
        pose_sequence = pose_sequence.permute(0, 2, 3, 1).contiguous()  # [batch_size, seq_len, num_joints, coord]
        pose_sequence = pose_sequence.view(batch_size, seq_len, -1)  # [batch_size, seq_len, num_joints * coord]
        
        batch_size, coord, seq_len, num_joints = left_hand_sequence.size()
        left_hand_sequence = left_hand_sequence.permute(0, 2, 3, 1).contiguous()  # [batch_size, seq_len, num_joints, coord]
        left_hand_sequence = left_hand_sequence.view(batch_size, seq_len, -1)  # [batch_size, seq_len, num_joints * coord]
        
        batch_size, coord, seq_len, num_joints = right_hand_sequence.size()
        right_hand_sequence = right_hand_sequence.permute(0, 2, 3, 1).contiguous()  # [batch_size, seq_len, num_joints, coord]
        right_hand_sequence = right_hand_sequence.view(batch_size, seq_len, -1)  # [batch_size, seq_len, num_joints * coord]
        
        # 패딩 마스크 생성
        face_src_key_padding_mask = create_padding_mask(face_sequence[:,:,0])
        face_src_key_padding_mask = face_src_key_padding_mask.to(device)
        pose_src_key_padding_mask = create_padding_mask(pose_sequence[:,:,0])
        pose_src_key_padding_mask = pose_src_key_padding_mask.to(device)
        left_src_key_padding_mask = create_padding_mask(left_hand_sequence[:,:,0])
        left_src_key_padding_mask = left_src_key_padding_mask.to(device)
        right_src_key_padding_mask = create_padding_mask(right_hand_sequence[:,:,0])
        right_src_key_padding_mask = right_src_key_padding_mask.to(device)

        outputs = model(face_sequence, pose_sequence, left_hand_sequence, right_hand_sequence, face_src_key_padding_mask, pose_src_key_padding_mask, left_src_key_padding_mask, right_src_key_padding_mask)
        # outputs = model(sequences, src_key_padding_mask=src_key_padding_mask)
        loss = criterion(outputs, labels)
        val_loss += loss.item()

        val_loss /= len(val_loader)

        # 에폭당 loss 값을 기록합니다.
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Val Loss: {val_loss:.4f}')
# Out:
# Epoch [10/10], Loss: 6.2703, Val Loss: 0.0502
# Epoch [10/10], Loss: 6.1798, Val Loss: 0.0498
# Epoch [10/10], Loss: 6.2312, Val Loss: 0.0502
# Epoch [10/10], Loss: 6.2064, Val Loss: 0.0501
# Epoch [10/10], Loss: 6.3671, Val Loss: 0.0513
# Epoch [10/10], Loss: 6.2023, Val Loss: 0.0500
# Epoch [10/10], Loss: 6.1910, Val Loss: 0.0499
# Epoch [10/10], Loss: 5.9558, Val Loss: 0.0480
# Epoch [10/10], Loss: 6.1560, Val Loss: 0.0496
# Epoch [10/10], Loss: 6.1087, Val Loss: 0.0493
# Epoch [10/10], Loss: 5.9922, Val Loss: 0.0483
# Epoch [10/10], Loss: 6.4378, Val Loss: 0.0519
# Epoch [10/10], Loss: 6.0837, Val Loss: 0.0491
# Epoch [10/10], Loss: 6.1323, Val Loss: 0.0495
# Epoch [10/10], Loss: 6.5607, Val Loss: 0.0529
# Epoch [10/10], Loss: 6.2301, Val Loss: 0.0503
# Epoch [10/10], Loss: 6.1727, Val Loss: 0.0498
# Epoch [10/10], Loss: 6.1926, Val Loss: 0.0499
# Epoch [10/10], Loss: 6.1358, Val Loss: 0.0495
# Epoch [10/10], Loss: 6.1682, Val Loss: 0.0497
# Epoch [10/10], Loss: 6.4028, Val Loss: 0.0516
# Epoch [10/10], Loss: 6.0642, Val Loss: 0.0489
# Epoch [10/10], Loss: 6.3819, Val Loss: 0.0514
# Epoch [10/10], Loss: 6.1437, Val Loss: 0.0496
# Epoch [10/10], Loss: 6.1835, Val Loss: 0.0499
# Epoch [10/10], Loss: 6.1993, Val Loss: 0.0500
# Epoch [10/10], Loss: 6.2472, Val Loss: 0.0504
# Epoch [10/10], Loss: 6.1640, Val Loss: 0.0497
# Epoch [10/10], Loss: 6.1622, Val Loss: 0.0497
# Epoch [10/10], Loss: 6.0966, Val Loss: 0.0492
# Epoch [10/10], Loss: 6.1907, Val Loss: 0.0499
# Epoch [10/10], Loss: 6.4210, Val Loss: 0.0518
# Epoch [10/10], Loss: 6.3160, Val Loss: 0.0509
# Epoch [10/10], Loss: 6.0576, Val Loss: 0.0489
# Epoch [10/10], Loss: 6.2347, Val Loss: 0.0503
# Epoch [10/10], Loss: 6.4063, Val Loss: 0.0517
# Epoch [10/10], Loss: 6.2088, Val Loss: 0.0501
# Epoch [10/10], Loss: 6.2024, Val Loss: 0.0500
# Epoch [10/10], Loss: 6.2007, Val Loss: 0.0500
# Epoch [10/10], Loss: 6.3642, Val Loss: 0.0513
# Epoch [10/10], Loss: 6.3966, Val Loss: 0.0516
# Epoch [10/10], Loss: 6.1101, Val Loss: 0.0493
# Epoch [10/10], Loss: 6.3878, Val Loss: 0.0515
# Epoch [10/10], Loss: 6.0683, Val Loss: 0.0490
# Epoch [10/10], Loss: 6.3148, Val Loss: 0.0509
# Epoch [10/10], Loss: 6.1751, Val Loss: 0.0498
# Epoch [10/10], Loss: 6.2479, Val Loss: 0.0504
# Epoch [10/10], Loss: 6.1446, Val Loss: 0.0496
# Epoch [10/10], Loss: 6.0201, Val Loss: 0.0486
# Epoch [10/10], Loss: 6.0929, Val Loss: 0.0491
# Epoch [10/10], Loss: 6.1550, Val Loss: 0.0496
# Epoch [10/10], Loss: 6.2915, Val Loss: 0.0507
# Epoch [10/10], Loss: 6.3424, Val Loss: 0.0511
# Epoch [10/10], Loss: 6.2641, Val Loss: 0.0505
# Epoch [10/10], Loss: 6.1972, Val Loss: 0.0500
# Epoch [10/10], Loss: 6.2467, Val Loss: 0.0504
# Epoch [10/10], Loss: 6.1256, Val Loss: 0.0494
# Epoch [10/10], Loss: 6.4250, Val Loss: 0.0518
# Epoch [10/10], Loss: 5.9730, Val Loss: 0.0482
# Epoch [10/10], Loss: 6.2176, Val Loss: 0.0501
# Epoch [10/10], Loss: 6.0205, Val Loss: 0.0486
# Epoch [10/10], Loss: 6.4216, Val Loss: 0.0518
# Epoch [10/10], Loss: 6.1260, Val Loss: 0.0494
# Epoch [10/10], Loss: 6.2073, Val Loss: 0.0501
# Epoch [10/10], Loss: 6.2233, Val Loss: 0.0502
# Epoch [10/10], Loss: 6.0784, Val Loss: 0.0490
# Epoch [10/10], Loss: 6.0307, Val Loss: 0.0486
# Epoch [10/10], Loss: 6.3200, Val Loss: 0.0509
# Epoch [10/10], Loss: 6.3954, Val Loss: 0.0516
# Epoch [10/10], Loss: 6.0346, Val Loss: 0.0487
# Epoch [10/10], Loss: 6.1408, Val Loss: 0.0495
# Epoch [10/10], Loss: 6.0595, Val Loss: 0.0489
# Epoch [10/10], Loss: 6.6060, Val Loss: 0.0532
# Epoch [10/10], Loss: 6.4087, Val Loss: 0.0517
# Epoch [10/10], Loss: 6.2649, Val Loss: 0.0505
# Epoch [10/10], Loss: 6.0646, Val Loss: 0.0489
# Epoch [10/10], Loss: 6.2685, Val Loss: 0.0505
# Epoch [10/10], Loss: 6.2140, Val Loss: 0.0501
# Epoch [10/10], Loss: 6.2474, Val Loss: 0.0504
# Epoch [10/10], Loss: 6.2182, Val Loss: 0.0501
# Epoch [10/10], Loss: 6.1431, Val Loss: 0.0495
# Epoch [10/10], Loss: 6.3212, Val Loss: 0.0510
# Epoch [10/10], Loss: 6.2212, Val Loss: 0.0502
# Epoch [10/10], Loss: 6.4072, Val Loss: 0.0517
# Epoch [10/10], Loss: 6.1692, Val Loss: 0.0498
# Epoch [10/10], Loss: 6.1761, Val Loss: 0.0498
# Epoch [10/10], Loss: 6.3475, Val Loss: 0.0512
# Epoch [10/10], Loss: 6.1785, Val Loss: 0.0498
# Epoch [10/10], Loss: 6.3535, Val Loss: 0.0512
# Epoch [10/10], Loss: 6.0618, Val Loss: 0.0489
# Epoch [10/10], Loss: 6.0200, Val Loss: 0.0486
# Epoch [10/10], Loss: 6.1845, Val Loss: 0.0499
# Epoch [10/10], Loss: 6.1978, Val Loss: 0.0500
# Epoch [10/10], Loss: 6.0711, Val Loss: 0.0490
# Epoch [10/10], Loss: 5.9802, Val Loss: 0.0482
# Epoch [10/10], Loss: 6.1367, Val Loss: 0.0495
# Epoch [10/10], Loss: 6.2783, Val Loss: 0.0506
# Epoch [10/10], Loss: 6.2372, Val Loss: 0.0503
# Epoch [10/10], Loss: 6.1206, Val Loss: 0.0494
# Epoch [10/10], Loss: 6.2669, Val Loss: 0.0505
# Epoch [10/10], Loss: 6.3536, Val Loss: 0.0512
# Epoch [10/10], Loss: 5.6584, Val Loss: 0.0457
# Epoch [10/10], Loss: 5.9662, Val Loss: 0.0481
# Epoch [10/10], Loss: 5.8807, Val Loss: 0.0474
# Epoch [10/10], Loss: 6.1210, Val Loss: 0.0493
# Epoch [10/10], Loss: 6.3270, Val Loss: 0.0510
# Epoch [10/10], Loss: 6.2705, Val Loss: 0.0506
# Epoch [10/10], Loss: 6.0994, Val Loss: 0.0492
# Epoch [10/10], Loss: 6.1119, Val Loss: 0.0493
# Epoch [10/10], Loss: 6.2937, Val Loss: 0.0507
# Epoch [10/10], Loss: 6.1770, Val Loss: 0.0498
# Epoch [10/10], Loss: 6.3109, Val Loss: 0.0509
# Epoch [10/10], Loss: 5.8789, Val Loss: 0.0474
# Epoch [10/10], Loss: 5.9402, Val Loss: 0.0479
# Epoch [10/10], Loss: 6.2592, Val Loss: 0.0505
# Epoch [10/10], Loss: 6.1944, Val Loss: 0.0500
# Epoch [10/10], Loss: 6.3317, Val Loss: 0.0511
# Epoch [10/10], Loss: 6.2982, Val Loss: 0.0508
# Epoch [10/10], Loss: 6.3878, Val Loss: 0.0515
# Epoch [10/10], Loss: 6.1107, Val Loss: 0.0493
# Epoch [10/10], Loss: 6.2085, Val Loss: 0.0501
# Epoch [10/10], Loss: 6.2952, Val Loss: 0.0508
# Epoch [10/10], Loss: 6.0656, Val Loss: 0.0489
# Epoch [10/10], Loss: 6.2581, Val Loss: 0.0505
# Epoch [10/10], Loss: 6.2718, Val Loss: 0.0506
