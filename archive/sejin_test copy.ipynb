# %% [markdown]
# ## 필요한 모듈 선언 ##

# %%
# 필요한 모듈 선언
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import numpy as np
import os
import json
from sklearn.preprocessing import LabelEncoder
import math

# %%
device = torch.device('cuda' if torch.cuda.is_available else 'cpu')
print('device : ', device)
# Out:
# device :  cuda

# %%
def get_word_list(start, end):
    folder_path = 'morpheme/01'

    # 단어들을 저장할 리스트
    word_list = []

    # 파일 이름 얻어오기
    file_names = [f for f in os.listdir(folder_path) if f.endswith('.json') and "F_morpheme" in f]

    # 파일 이름을 번호 순서대로 정렬하기
    file_names.sort(key=lambda x: int(x.split('_')[2][4:]))

    for filename in file_names:
        file_path = os.path.join(folder_path, filename)
        
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
            
            # 'data' 키 안의 요소들 순회
            for item in data['data']:
                for attribute in item['attributes']:
                    word_list.append(attribute['name'])

    # 결과 출력 
    #print(len(word_list))
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(word_list)
    # label_mapping 딕셔너리 생성
    folder_to_label = {}
    for i, word in enumerate(word_list):
        for j in range(start, end + 1):  # 01부터 07까지
            folder_name = f"NIA_SL_WORD{str(i+1).zfill(4)}_REAL{str(j).zfill(2)}_F"
            folder_to_label[folder_name] = encoded_labels[i]
    return folder_to_label, label_encoder, word_list

# %%
folder_to_label, label_encoder, word_list = get_word_list(1, 1)
print(folder_to_label)
# Out:
# {'NIA_SL_WORD0001_REAL01_F': np.int64(178), 'NIA_SL_WORD0002_REAL01_F': np.int64(1147), 'NIA_SL_WORD0003_REAL01_F': np.int64(1426), 'NIA_SL_WORD0004_REAL01_F': np.int64(486), 'NIA_SL_WORD0005_REAL01_F': np.int64(545), 'NIA_SL_WORD0006_REAL01_F': np.int64(633), 'NIA_SL_WORD0007_REAL01_F': np.int64(1960), 'NIA_SL_WORD0008_REAL01_F': np.int64(882), 'NIA_SL_WORD0009_REAL01_F': np.int64(1458), 'NIA_SL_WORD0010_REAL01_F': np.int64(2101), 'NIA_SL_WORD0011_REAL01_F': np.int64(1581), 'NIA_SL_WORD0012_REAL01_F': np.int64(1640), 'NIA_SL_WORD0013_REAL01_F': np.int64(1680), 'NIA_SL_WORD0014_REAL01_F': np.int64(1833), 'NIA_SL_WORD0015_REAL01_F': np.int64(1739), 'NIA_SL_WORD0016_REAL01_F': np.int64(1485), 'NIA_SL_WORD0017_REAL01_F': np.int64(550), 'NIA_SL_WORD0018_REAL01_F': np.int64(461), 'NIA_SL_WORD0019_REAL01_F': np.int64(1586), 'NIA_SL_WORD0020_REAL01_F': np.int64(2138), 'NIA_SL_WORD0021_REAL01_F': np.int64(1721), 'NIA_SL_WORD0022_REAL01_F': np.int64(2495), 'NIA_SL_WORD0023_REAL01_F': np.int64(1356), 'NIA_SL_WORD0024_REAL01_F': np.int64(2638), 'NIA_SL_WORD0025_REAL01_F': np.int64(1506), 'NIA_SL_WORD0026_REAL01_F': np.int64(396), 'NIA_SL_WORD0027_REAL01_F': np.int64(2626), 'NIA_SL_WORD0028_REAL01_F': np.int64(1039), 'NIA_SL_WORD0029_REAL01_F': np.int64(116), 'NIA_SL_WORD0030_REAL01_F': np.int64(130), 'NIA_SL_WORD0031_REAL01_F': np.int64(470), 'NIA_SL_WORD0032_REAL01_F': np.int64(469), 'NIA_SL_WORD0033_REAL01_F': np.int64(584), 'NIA_SL_WORD0034_REAL01_F': np.int64(629), 'NIA_SL_WORD0035_REAL01_F': np.int64(749), 'NIA_SL_WORD0036_REAL01_F': np.int64(764), 'NIA_SL_WORD0037_REAL01_F': np.int64(41), 'NIA_SL_WORD0038_REAL01_F': np.int64(902), 'NIA_SL_WORD0039_REAL01_F': np.int64(1029), 'NIA_SL_WORD0040_REAL01_F': np.int64(1038), 'NIA_SL_WORD0041_REAL01_F': np.int64(1045), 'NIA_SL_WORD0042_REAL01_F': np.int64(1113), 'NIA_SL_WORD0043_REAL01_F': np.int64(1122), 'NIA_SL_WORD0044_REAL01_F': np.int64(1124), 'NIA_SL_WORD0045_REAL01_F': np.int64(1202), 'NIA_SL_WORD0046_REAL01_F': np.int64(1334), 'NIA_SL_WORD0047_REAL01_F': np.int64(1351), 'NIA_SL_WORD0048_REAL01_F': np.int64(900), 'NIA_SL_WORD0049_REAL01_F': np.int64(1391), 'NIA_SL_WORD0050_REAL01_F': np.int64(1398), 'NIA_SL_WORD0051_REAL01_F': np.int64(1399), 'NIA_SL_WORD0052_REAL01_F': np.int64(1419), 'NIA_SL_WORD0053_REAL01_F': np.int64(1437), 'NIA_SL_WORD0054_REAL01_F': np.int64(1691), 'NIA_SL_WORD0055_REAL01_F': np.int64(1767), 'NIA_SL_WORD0056_REAL01_F': np.int64(1819), 'NIA_SL_WORD0057_REAL01_F': np.int64(2734), 'NIA_SL_WORD0058_REAL01_F': np.int64(2369), 'NIA_SL_WORD0059_REAL01_F': np.int64(1867), 'NIA_SL_WORD0060_REAL01_F': np.int64(2097), 'NIA_SL_WORD0061_REAL01_F': np.int64(2160), 'NIA_SL_WORD0062_REAL01_F': np.int64(2280), 'NIA_SL_WORD0063_REAL01_F': np.int64(2423), 'NIA_SL_WORD0064_REAL01_F': np.int64(2450), 'NIA_SL_WORD0065_REAL01_F': np.int64(2451), 'NIA_SL_WORD0066_REAL01_F': np.int64(2460), 'NIA_SL_WORD0067_REAL01_F': np.int64(2549), 'NIA_SL_WORD0068_REAL01_F': np.int64(2655), 'NIA_SL_WORD0069_REAL01_F': np.int64(2656), 'NIA_SL_WORD0070_REAL01_F': np.int64(1139), 'NIA_SL_WORD0071_REAL01_F': np.int64(2708), 'NIA_SL_WORD0072_REAL01_F': np.int64(12), 'NIA_SL_WORD0073_REAL01_F': np.int64(168), 'NIA_SL_WORD0074_REAL01_F': np.int64(201), 'NIA_SL_WORD0075_REAL01_F': np.int64(202), 'NIA_SL_WORD0076_REAL01_F': np.int64(1157), 'NIA_SL_WORD0077_REAL01_F': np.int64(906), 'NIA_SL_WORD0078_REAL01_F': np.int64(450), 'NIA_SL_WORD0079_REAL01_F': np.int64(1018), 'NIA_SL_WORD0080_REAL01_F': np.int64(451), 'NIA_SL_WORD0081_REAL01_F': np.int64(504), 'NIA_SL_WORD0082_REAL01_F': np.int64(2316), 'NIA_SL_WORD0083_REAL01_F': np.int64(556), 'NIA_SL_WORD0084_REAL01_F': np.int64(2271), 'NIA_SL_WORD0085_REAL01_F': np.int64(672), 'NIA_SL_WORD0086_REAL01_F': np.int64(671), 'NIA_SL_WORD0087_REAL01_F': np.int64(677), 'NIA_SL_WORD0088_REAL01_F': np.int64(693), 'NIA_SL_WORD0089_REAL01_F': np.int64(696), 'NIA_SL_WORD0090_REAL01_F': np.int64(705), 'NIA_SL_WORD0091_REAL01_F': np.int64(726), 'NIA_SL_WORD0092_REAL01_F': np.i ...

# %%
print(label_encoder.inverse_transform([2632]))
# Out:
# ['하는수없다']

# %% [markdown]
# ## Dataset 클래스 선언 ##

# %%
# 임시!!!!!
class SignLanguageDataset(Dataset):
    def __init__(self, data_dir, folder_to_label):
        self.data_dir = data_dir
        self.folder_to_label = folder_to_label
        self.data, self.labels = self.load_data()

    def load_data(self):
        file_list = []
        labels = []
        for folder_name in os.listdir(self.data_dir):
            if folder_name.endswith("F") and folder_name in self.folder_to_label:  # "F"로 끝나는 폴더만 처리
                label = self.folder_to_label[folder_name]
                label = int(label)
                label_name = label_encoder.inverse_transform([label])
                folder_path = os.path.join(self.data_dir, folder_name)
                if os.path.isdir(folder_path):
                    json_files = [os.path.join(folder_path, file_name) for file_name in os.listdir(folder_path) if file_name.endswith('.json')]
                    file_list.append(json_files)
                    labels.append(label)
                    print(f"Label: {label_name},label_num: {label} Folder: {folder_name}, Frame count: {len(json_files)}")
        return file_list, labels
    

    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        all_keypoints = []
        
        json_file_list = self.data[index]
        label = self.labels[index]
        for file_path in json_file_list:
            with open(file_path, 'r') as f:
                data = json.load(f)
            frame_data = data['people']
            if frame_data:
                keypoints_2d = np.array(frame_data['face_keypoints_2d'] +
                                        frame_data['pose_keypoints_2d'] +
                                        frame_data['hand_left_keypoints_2d'] +
                                        frame_data['hand_right_keypoints_2d'])
                keypoints_2d = keypoints_2d.reshape(-1, 3)[:, :2].flatten()  # (num_keypoints * 2,)
                
                keypoints_3d = np.array(frame_data['face_keypoints_3d'] +
                                        frame_data['pose_keypoints_3d'] +
                                        frame_data['hand_left_keypoints_3d'] +
                                        frame_data['hand_right_keypoints_3d'])
                keypoints_3d = keypoints_3d.reshape(-1, 4)[:, :3].flatten() 
                
                keypoints = np.concatenate((keypoints_2d, keypoints_3d))
                all_keypoints.append(keypoints)
        
        all_keypoints = np.array(all_keypoints)  # (num_frames, num_keypoints * (2 + 3))
        return torch.tensor(all_keypoints, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# %%
# 리얼리얼 임시
class SignLanguageDataset(Dataset):
    def __init__(self, data_dir, folder_to_label, start, end, label_encoder):
        self.data_dir = data_dir
        self.folder_to_label = folder_to_label
        self.load_num_start = start
        self.load_num_end = end
        self.label_encoder = label_encoder
        self.data, self.labels = self.load_data()

    def load_data(self):
        file_list = []
        labels = []
        for subdir in range(self.load_num_start, self.load_num_end + 1):  # 01~07 디렉토리
            subdir_path = os.path.join(self.data_dir, f'{subdir:02d}')
            for folder_name in os.listdir(subdir_path):
                if folder_name.endswith("F") and folder_name in self.folder_to_label:  # "F"로 끝나는 폴더만 처리
                    label = self.folder_to_label[folder_name]
                    label = int(label)
                    label_name = label_encoder.inverse_transform([label])
                    folder_path = os.path.join(subdir_path, folder_name)
                    if os.path.isdir(folder_path):
                        json_files = [os.path.join(folder_path, file_name) for file_name in os.listdir(folder_path) if file_name.endswith('.json')]
                        file_list.append(json_files)
                        labels.append(label)
                        print(f"Label: {label_name},label_num: {label} Folder: {folder_name}, Frame count: {len(json_files)}")
        return file_list, labels
    

    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        all_keypoints = []
        
        json_file_list = self.data[index]
        label = self.labels[index]
        for file_path in json_file_list:
            with open(file_path, 'r') as f:
                data = json.load(f)
            frame_data = data['people']
            if frame_data:
                keypoints_2d = np.array(frame_data['face_keypoints_2d'] +
                                        frame_data['pose_keypoints_2d'] +
                                        frame_data['hand_left_keypoints_2d'] +
                                        frame_data['hand_right_keypoints_2d'])
                keypoints_2d = keypoints_2d.reshape(-1, 3)[:, :2].flatten()  # (num_keypoints * 2,)
                
                keypoints_3d = np.array(frame_data['face_keypoints_3d'] +
                                        frame_data['pose_keypoints_3d'] +
                                        frame_data['hand_left_keypoints_3d'] +
                                        frame_data['hand_right_keypoints_3d'])
                keypoints_3d = keypoints_3d.reshape(-1, 4)[:, :3].flatten() 
                
                keypoints = np.concatenate((keypoints_2d, keypoints_3d))
                all_keypoints.append(keypoints)
        
        all_keypoints = np.array(all_keypoints)  # (num_frames, num_keypoints * (2 + 3))
        return torch.tensor(all_keypoints, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# %%
print(len(dta))

# %%
from torch.nn.utils.rnn import pad_sequence
# Collate 함수 정의
def collate_fn(batch):
    keypoints, labels = zip(*batch)
    keypoints = [torch.tensor(k) for k in keypoints]
    labels = torch.tensor(labels)
    keypoints_padded = pad_sequence(keypoints, batch_first=True, padding_value=0)
    lengths = torch.tensor([len(k) for k in keypoints])
    return keypoints_padded, labels, lengths

# %%
root_dir = "keypoints"

# %%
print(os.listdir(root_dir))
label = int((''.join(filter(str.isdigit, 'NIA_SL_WORD0101_REAL01_L')))[0:4])
# Out:
# ['NIA_SL_WORD1731_REAL01_L', 'NIA_SL_WORD2775_REAL01_U', 'NIA_SL_WORD1948_REAL01_R', 'NIA_SL_WORD1083_REAL01_R', 'NIA_SL_WORD2918_REAL01_R', 'NIA_SL_WORD1709_REAL01_D', 'NIA_SL_WORD1075_REAL01_U', 'NIA_SL_WORD0223_REAL01_R', 'NIA_SL_WORD2794_REAL01_R', 'NIA_SL_WORD0687_REAL01_R', 'NIA_SL_WORD0019_REAL01_D', 'NIA_SL_WORD0438_REAL01_L', 'NIA_SL_WORD0293_REAL01_L', 'NIA_SL_WORD2787_REAL01_R', 'NIA_SL_WORD2515_REAL01_U', 'NIA_SL_WORD2600_REAL01_D', 'NIA_SL_WORD1123_REAL01_D', 'NIA_SL_WORD1025_REAL01_U', 'NIA_SL_WORD1923_REAL01_F', 'NIA_SL_WORD1533_REAL01_L', 'NIA_SL_WORD1081_REAL01_L', 'NIA_SL_WORD2814_REAL01_L', 'NIA_SL_WORD2298_REAL01_U', 'NIA_SL_WORD2050_REAL01_D', 'NIA_SL_WORD1890_REAL01_L', 'NIA_SL_WORD0141_REAL01_U', 'NIA_SL_WORD0973_REAL01_F', 'NIA_SL_WORD2832_REAL01_F', 'NIA_SL_WORD0164_REAL01_L', 'NIA_SL_WORD0462_REAL01_U', 'NIA_SL_WORD2981_REAL01_D', 'NIA_SL_WORD2439_REAL01_L', 'NIA_SL_WORD0457_REAL01_D', 'NIA_SL_WORD0958_REAL01_F', 'NIA_SL_WORD1274_REAL01_D', 'NIA_SL_WORD2596_REAL01_D', 'NIA_SL_WORD2673_REAL01_L', 'NIA_SL_WORD0182_REAL01_L', 'NIA_SL_WORD0708_REAL01_U', 'NIA_SL_WORD2310_REAL01_F', 'NIA_SL_WORD0437_REAL01_D', 'NIA_SL_WORD0837_REAL01_D', 'NIA_SL_WORD1211_REAL01_D', 'NIA_SL_WORD1864_REAL01_L', 'NIA_SL_WORD1432_REAL01_U', 'NIA_SL_WORD0387_REAL01_R', 'NIA_SL_WORD2691_REAL01_D', 'NIA_SL_WORD0854_REAL01_R', 'NIA_SL_WORD2766_REAL01_R', 'NIA_SL_WORD2079_REAL01_D', 'NIA_SL_WORD1594_REAL01_D', 'NIA_SL_WORD1857_REAL01_F', 'NIA_SL_WORD1207_REAL01_U', 'NIA_SL_WORD0085_REAL01_R', 'NIA_SL_WORD1747_REAL01_D', 'NIA_SL_WORD1474_REAL01_U', 'NIA_SL_WORD1776_REAL01_U', 'NIA_SL_WORD0952_REAL01_U', 'NIA_SL_WORD0304_REAL01_L', 'NIA_SL_WORD0961_REAL01_D', 'NIA_SL_WORD1336_REAL01_F', 'NIA_SL_WORD2666_REAL01_D', 'NIA_SL_WORD0097_REAL01_F', 'NIA_SL_WORD1358_REAL01_L', 'NIA_SL_WORD2901_REAL01_R', 'NIA_SL_WORD0744_REAL01_L', 'NIA_SL_WORD0257_REAL01_R', 'NIA_SL_WORD1986_REAL01_L', 'NIA_SL_WORD0028_REAL01_U', 'NIA_SL_WORD1335_REAL01_U', 'NIA_SL_WORD1623_REAL01_D', 'NIA_SL_WORD2991_REAL01_F', 'NIA_SL_WORD2115_REAL01_L', 'NIA_SL_WORD2524_REAL01_D', 'NIA_SL_WORD0349_REAL01_F', 'NIA_SL_WORD0856_REAL01_L', 'NIA_SL_WORD2337_REAL01_D', 'NIA_SL_WORD0674_REAL01_R', 'NIA_SL_WORD0792_REAL01_L', 'NIA_SL_WORD0651_REAL01_R', 'NIA_SL_WORD1530_REAL01_L', 'NIA_SL_WORD0385_REAL01_F', 'NIA_SL_WORD1795_REAL01_D', 'NIA_SL_WORD1395_REAL01_L', 'NIA_SL_WORD2491_REAL01_L', 'NIA_SL_WORD0805_REAL01_L', 'NIA_SL_WORD2724_REAL01_R', 'NIA_SL_WORD2527_REAL01_L', 'NIA_SL_WORD0899_REAL01_L', 'NIA_SL_WORD2640_REAL01_F', 'NIA_SL_WORD1886_REAL01_U', 'NIA_SL_WORD0398_REAL01_D', 'NIA_SL_WORD2244_REAL01_U', 'NIA_SL_WORD0580_REAL01_F', 'NIA_SL_WORD1703_REAL01_L', 'NIA_SL_WORD2210_REAL01_U', 'NIA_SL_WORD1189_REAL01_R', 'NIA_SL_WORD2162_REAL01_F', 'NIA_SL_WORD2046_REAL01_R', 'NIA_SL_WORD2338_REAL01_D', 'NIA_SL_WORD1591_REAL01_D', 'NIA_SL_WORD2332_REAL01_F', 'NIA_SL_WORD1516_REAL01_L', 'NIA_SL_WORD1380_REAL01_U', 'NIA_SL_WORD0134_REAL01_L', 'NIA_SL_WORD1975_REAL01_U', 'NIA_SL_WORD2898_REAL01_R', 'NIA_SL_WORD1249_REAL01_L', 'NIA_SL_WORD0032_REAL01_L', 'NIA_SL_WORD1592_REAL01_L', 'NIA_SL_WORD2470_REAL01_R', 'NIA_SL_WORD2208_REAL01_L', 'NIA_SL_WORD0395_REAL01_R', 'NIA_SL_WORD0985_REAL01_F', 'NIA_SL_WORD0821_REAL01_D', 'NIA_SL_WORD1798_REAL01_R', 'NIA_SL_WORD0678_REAL01_L', 'NIA_SL_WORD0497_REAL01_L', 'NIA_SL_WORD2255_REAL01_F', 'NIA_SL_WORD1956_REAL01_F', 'NIA_SL_WORD1864_REAL01_D', 'NIA_SL_WORD0375_REAL01_L', 'NIA_SL_WORD0905_REAL01_F', 'NIA_SL_WORD0441_REAL01_R', 'NIA_SL_WORD1860_REAL01_D', 'NIA_SL_WORD1581_REAL01_D', 'NIA_SL_WORD1026_REAL01_U', 'NIA_SL_WORD2247_REAL01_R', 'NIA_SL_WORD2133_REAL01_D', 'NIA_SL_WORD0884_REAL01_U', 'NIA_SL_WORD1517_REAL01_F', 'NIA_SL_WORD2883_REAL01_R', 'NIA_SL_WORD1747_REAL01_U', 'NIA_SL_WORD1713_REAL01_R', 'NIA_SL_WORD0176_REAL01_D', 'NIA_SL_WORD1989_REAL01_U', 'NIA_SL_WORD2938_REAL01_D', 'NIA_SL_WORD0202_REAL01_U', 'NIA_SL_WORD1146_REAL01_D', 'NIA_SL_WORD0782_REAL01_F', 'NIA_SL_WORD1425_REAL01_F', 'NIA_SL_WORD1236_REAL01_L', 'NIA_SL_WORD0639_REAL01 ...

# %%
batch_size = 1
dataset = SignLanguageDataset(root_dir, folder_to_label, 1, 1, label_encoder)
dataloader = DataLoader(dataset, batch_size, collate_fn=collate_fn)  
print(dataloader)
# Out:
# Label: ['하는수없다'],label_num: 2632 Folder: NIA_SL_WORD1923_REAL01_F, Frame count: 116
# Label: ['못견디다'],label_num: 786 Folder: NIA_SL_WORD0973_REAL01_F, Frame count: 114
# Label: ['이백'],label_num: 1994 Folder: NIA_SL_WORD2832_REAL01_F, Frame count: 95
# Label: ['칩거'],label_num: 2496 Folder: NIA_SL_WORD0958_REAL01_F, Frame count: 107
# Label: ['임기응변'],label_num: 2089 Folder: NIA_SL_WORD2310_REAL01_F, Frame count: 147
# Label: ['남원시청'],label_num: 493 Folder: NIA_SL_WORD1857_REAL01_F, Frame count: 135
# Label: ['잘못하다'],label_num: 2122 Folder: NIA_SL_WORD1336_REAL01_F, Frame count: 143
# Label: ['소불고기'],label_num: 1383 Folder: NIA_SL_WORD0097_REAL01_F, Frame count: 115
# Label: ['백억'],label_num: 955 Folder: NIA_SL_WORD2991_REAL01_F, Frame count: 102
# Label: ['흑백'],label_num: 2755 Folder: NIA_SL_WORD0349_REAL01_F, Frame count: 101
# Label: ['불알'],label_num: 1119 Folder: NIA_SL_WORD0385_REAL01_F, Frame count: 99
# Label: ['구'],label_num: 295 Folder: NIA_SL_WORD2640_REAL01_F, Frame count: 89
# Label: ['희미'],label_num: 2765 Folder: NIA_SL_WORD0580_REAL01_F, Frame count: 130
# Label: ['처남'],label_num: 2342 Folder: NIA_SL_WORD2162_REAL01_F, Frame count: 133
# Label: ['막히다'],label_num: 730 Folder: NIA_SL_WORD2332_REAL01_F, Frame count: 111
# Label: ['자승자박'],label_num: 2111 Folder: NIA_SL_WORD0985_REAL01_F, Frame count: 104
# Label: ['마지못하다'],label_num: 721 Folder: NIA_SL_WORD2255_REAL01_F, Frame count: 120
# Label: ['봉화군지부'],label_num: 1071 Folder: NIA_SL_WORD1956_REAL01_F, Frame count: 125
# Label: ['바래다'],label_num: 870 Folder: NIA_SL_WORD0905_REAL01_F, Frame count: 128
# Label: ['울보'],label_num: 1879 Folder: NIA_SL_WORD1517_REAL01_F, Frame count: 139
# Label: ['자살자'],label_num: 2108 Folder: NIA_SL_WORD0782_REAL01_F, Frame count: 130
# Label: ['금천'],label_num: 392 Folder: NIA_SL_WORD1425_REAL01_F, Frame count: 123
# Label: ['팔십사'],label_num: 2580 Folder: NIA_SL_WORD2716_REAL01_F, Frame count: 122
# Label: ['얼굴'],label_num: 1647 Folder: NIA_SL_WORD1210_REAL01_F, Frame count: 148
# Label: ['마라톤'],label_num: 709 Folder: NIA_SL_WORD1525_REAL01_F, Frame count: 126
# Label: ['마포구지부'],label_num: 725 Folder: NIA_SL_WORD1040_REAL01_F, Frame count: 111
# Label: ['고성군지부'],label_num: 182 Folder: NIA_SL_WORD2416_REAL01_F, Frame count: 144
# Label: ['추녀'],label_num: 2418 Folder: NIA_SL_WORD0876_REAL01_F, Frame count: 123
# Label: ['송년회'],label_num: 1406 Folder: NIA_SL_WORD0653_REAL01_F, Frame count: 147
# Label: ['상품'],label_num: 1281 Folder: NIA_SL_WORD0620_REAL01_F, Frame count: 135
# Label: ['교실'],label_num: 285 Folder: NIA_SL_WORD0215_REAL01_F, Frame count: 122
# Label: ['도벽'],label_num: 619 Folder: NIA_SL_WORD0481_REAL01_F, Frame count: 118
# Label: ['잊다'],label_num: 2098 Folder: NIA_SL_WORD1106_REAL01_F, Frame count: 118
# Label: ['중앙대학교'],label_num: 2259 Folder: NIA_SL_WORD1477_REAL01_F, Frame count: 171
# Label: ['햅쌀'],label_num: 2671 Folder: NIA_SL_WORD2113_REAL01_F, Frame count: 131
# Label: ['싫다'],label_num: 1505 Folder: NIA_SL_WORD1385_REAL01_F, Frame count: 125
# Label: ['영주시청'],label_num: 1752 Folder: NIA_SL_WORD1976_REAL01_F, Frame count: 149
# Label: ['분홍조명'],label_num: 1106 Folder: NIA_SL_WORD0323_REAL01_F, Frame count: 115
# Label: ['곡성군지부'],label_num: 209 Folder: NIA_SL_WORD1889_REAL01_F, Frame count: 118
# Label: ['방법'],label_num: 895 Folder: NIA_SL_WORD1190_REAL01_F, Frame count: 139
# Label: ['입원'],label_num: 2097 Folder: NIA_SL_WORD0060_REAL01_F, Frame count: 128
# Label: ['성공'],label_num: 1340 Folder: NIA_SL_WORD1541_REAL01_F, Frame count: 129
# Label: ['중도포기'],label_num: 2250 Folder: NIA_SL_WORD2002_REAL01_F, Frame count: 132
# Label: ['부천시수어통역센터'],label_num: 1090 Folder: NIA_SL_WORD1672_REAL01_F, Frame count: 163
# Label: ['예식장'],label_num: 1767 Folder: NIA_SL_WORD0055_REAL01_F, Frame count: 114
# Label: ['서구주민지원센터'],label_num: 1300 Folder: NIA_SL_WORD1091_REAL01_F, Frame count: 109
# Label: ['김제시지부'],label_num: 425 Folder: NIA_SL_WORD1852_REAL01_F, Frame count: 112
# Label: ['팔랑귀'],label_num: 2569 Folder: NIA_SL_WORD2313_REAL01_F, Frame count: 114
# Label: ['시댁'],label_num: 1464 Folder: NIA_SL_WORD0669_REAL01_F, Frame count: 123
# Label: ['거저먹다'],label_num: 97 Folder: NIA_SL_WORD2293_REAL01_F, Frame count: 128
# Label: ['붕대'],label_num: 1124 Folder: NIA_SL_WORD0044_REAL01_F, Frame count: 124
# Label: ['구리시청'],label_num: 308 Folder: NIA_SL_WORD1658_REAL01_F, Frame count: 150
# Label: ['황소고집'],label_num: 2730 Folder: NIA_SL_WORD0740_REAL01_F, Frame count: 130
# Label: ['입맛에맞지않다'],label_num: 2096 Folder: NIA_SL_WORD0954_REAL01_F, Frame count: 110
# Label: ['육십일'],label_num: 1944 Folder: NIA_SL_WORD2693_REAL01_F, Frame count: 118
# Label: ['설사'],label_num: 1334 Folder: NIA_SL_WORD0046_REAL01_F, Frame count: 120
# Label: ['종소리'],label_num: 2228 Folder: NIA_SL_WORD0820_REAL01_F, Frame count: 127
# Label: ['육백억'],label_num: 1930 Folder: NIA_SL_WORD2996_REAL01_F, Frame count: 104
# Label: ['구조'],label_num: 337 Folder: NIA_SL_WORD1588_REAL01_F, Frame count: 129
# Label: ['얕보다'],label_num: 1632 Folder: NIA_SL_WORD2345_REAL01_F, Frame count: 106
# Label: ['골키퍼'],label_num: 212 Folder: NIA_SL_WORD1502_REAL01_F, Frame count: 114
# Label: ['뽐내다'],label_num: 1149 Folder: NIA_SL_WORD2061_REAL01_F, Frame count: 132
# Label: ['수어'],label_num: 1426 Folder: NIA_SL_WORD0003_REAL01_F, Frame count: 94
# Label: ['백팔십오'],label_num: 1008 Folder: NIA_SL_WORD2817_REAL01_F, Frame count: 117
# Label: ['아하'],label_num: 1553 Folder: NIA_SL_WORD2480_REAL01_F, Frame count: 102
# Label: ['유학'],label_num: 1924 Folder: NIA_SL_WORD0234_REAL01_F, Frame count: 131
# Label: ['들러리'],label_num: 681 Folder: NIA_SL_WORD2283_REAL01_F, Frame count: 117
# Label: ['무분별'],label_num: 804 Folder: NIA_SL_WORD2074_REAL01_F, Frame count: 122
# Label: ['양천구주민지원센터'],label_num: 1624 Folder: NIA_SL_WORD1060_REAL01_F, Frame count: 127
# Label: ['여행자'],label_num: 1690 Folder: NIA_SL_WORD2064_REAL01_F, Frame count: 133
# Label: ['깨물다'],label_num: 444 Folder: NIA_SL_WORD1170_REAL01_F, Frame count: 125
# Label: ['전자기기'],label_num: 2180 Folder: NIA_SL_WORD1340_REAL01_F, Frame count: 163
# Label: ['미소'],label_num: 849 Folder: NIA_SL_WORD1399_REAL01_F, Frame count: 132
# Label: ['결벽'],label_num: 128 Folder: NIA_SL_WORD0971_REAL01_F, Frame count: 110
# Label: ['교수'],label_num: 284 Folder: NIA_SL_WORD0140_REAL01_F, Frame count: 113
# Label: ['세뇌'],label_num: 1366 Folder: NIA_SL_WORD2156_REAL01_F, Frame count: 117
# Label: ['예산군수어통역센터'],label_num: 1761 Folder: NIA_SL_WORD1834_REAL01_F, Frame count: 153
# Label: ['을지로'],label_num: 1957 Folder: NIA_SL_WORD1408_REAL01_F, Frame count: 104
# Label: ['오리알'],label_num: 1779 Folder: NIA_SL_WORD0736_REAL01_F, Frame count: 124
# Label: ['동대문구주민지원센터'],label_num: 653 Folder: NIA_SL_WORD1036_REAL01_F, Frame count: 107
# Label: ['병명'],label_num: 1038 Folder: NIA_SL_WORD0040_REAL01_F, Frame count: 109
# Label: ['팔천'],label_num: 2593 Folder: NIA_SL_WORD2878_REAL01_F, Frame count: 102
# Label: ['뒷산'],label_num: 678 Folder: NIA_SL_WORD0492_REAL01_F, Frame count: 118
# Label: ['증원'],label_num: 2264 Folder: NIA_SL_WORD0831_REAL01_F, Frame count: 133
# Label: ['서천군지부'],label_num: 1324 Folder: NIA_SL_WORD1827_REAL01_F, Frame count: 125
# Label: ['돕다'],label_num: 645 Folder: NIA_SL_WORD2389_REAL01_F, Frame count: 99
# Label: ['장로교'],label_num: 2133 Folder: NIA_SL_WORD0256_REAL01_F, Frame count: 116
# Label: ['폐업'],label_num: 2609 Folder: NIA_SL_WORD2252_REAL01_F, Frame count: 140
# Label: ['백사십구'],label_num: 922 Folder: NIA_SL_WORD2781_REAL01_F, Frame count: 120
# Label: ['수심'],label_num: 1425 Folder: NIA_SL_WORD2579_REAL01_F, Frame count: 143
# Label: ['충주시지부'],label_num: 2444 Folder: NIA_SL_WORD1799_REAL01_F, Frame count: 132
# Label: ['진도군주민지원센터'],label_num: 2282 Folder: NIA_SL_WORD1930_REAL01_F, Frame count: 133
# Label: ['주민센터'],label_num: 2238 Folder: NIA_SL_WORD0489_REAL01_F, Frame count: 124
# Label: ['일반인'],label_num: 2069 Folder: NIA_SL_WORD2040_REAL01_F, Frame count: 139
# Label: ['백팔십칠'],label_num: 1012 Folder: NIA_SL_WORD2819_REAL01_F, Frame count: 116
# Label: ['유성구주민지원센터'],label_num: 1917 Folder: NIA_SL_WORD1624_REAL01_F, Frame count: 144
# Label: ['혀'],label_num: 2681 Folder: NIA_SL_WORD1181_REAL01_F, Frame count: 125
# Label: ['선별'],label_num: 1330 Folder: NIA_SL_WORD0674_REAL01_F, Frame count: 129
# Label: ['살인'],label_num: 1227 Folder: NIA_SL_WORD1341_REAL01_F, Frame count: 137
# Label: ['종점'],label_num: 2230 Folder: NIA_SL_WORD0821_REAL01_F, Frame count: 131
# Label: ['재학'],label_num: 2159 Folder: NIA_SL_WORD0237_REAL01_F, Frame count: 106
# Label: ['시차'],label_num: 1471 Folder: NIA_SL_WORD0671_REAL01_F, Frame count: 127
# Label: ['누나'],label_num: 544 Folder: NIA_SL_WORD1516_REAL01_F, Frame count: 120
# Label: ['구십'],label_num: 320 Folder: NIA_SL_WORD2722_REAL01_F, Frame count: 108
# Label: ['이십이'],label_num: 2022 Folder: NIA_SL_WORD2654_REAL01_F, Frame count: 99
# Label: ['의욕'],label_num: 1975 Folder: NIA_SL_WORD2216_REAL01_F, Frame count: 128
# Label: ['화상채팅'],label_num: 2709 Folder: NIA_SL_WORD0182_REAL01_F, Frame count: 119
# Label: ['영문법'],label_num: 1738 Folder: NIA_SL_WORD0732_REAL01_F, Frame count: 135
# Label: ['동메달'],label_num: 659 Folder: NIA_SL_WORD0488_REAL01_F, Frame count: 107
# Label: ['부여군주민지원센터'],label_num: 1085 Folder: NIA_SL_WORD1823_REAL01_F, Frame count: 145
# Label: ['강요'],label_num: 76 Folder: NIA_SL_WORD2169_REAL01_F, Frame count: 126
# Label: ['외상값'],label_num: 1835 Folder: NIA_SL_WORD0747_REAL01_F, Frame count: 120
# Label: ['어차피'],label_num: 1643 Folder: NIA_SL_WORD2285_REAL01_F, Frame count: 110
# Label: ['반성하다'],label_num: 877 Folder: NIA_SL_WORD2076_REAL01_F, Frame count: 155
# Label: ['무주군수어통역센터'],label_num: 820 Folder: NIA_SL_WORD1859_REAL01_F, Frame count: 177
# Label: ['꺼지다'],label_num: 445 Folder: NIA_SL_WORD2358_REAL01_F, Frame count: 90
# Label: ['전기기술자'],label_num: 2168 Folder: NIA_SL_WORD0805_REAL01_F, Frame count: 138
# Label: ['사납다'],label_num: 1161 Folder: NIA_SL_WORD0638_REAL01_F, Frame count: 140
# Label: ['종아리맞다'],label_num: 2229 Folder: NIA_SL_WORD1166_REAL01_F, Frame count: 134
# Label: ['빌리다'],label_num: 1140 Folder: NIA_SL_WORD2385_REAL01_F, Frame count: 96
# Label: ['송아지'],label_num: 1407 Folder: NIA_SL_WORD0304_REAL01_F, Frame count: 136
# Label: ['쇼하다'],label_num: 1414 Folder: NIA_SL_WORD0915_REAL01_F, Frame count: 125
# Label: ['돌무덤'],label_num: 642 Folder: NIA_SL_WORD0265_REAL01_F, Frame count: 108
# Label: ['기민하다'],label_num: 404 Folder: NIA_SL_WORD2026_REAL01_F, Frame count: 144
# Label: ['결점'],label_num: 132 Folder: NIA_SL_WORD0922_REAL01_F, Frame count: 97
# Label: ['사하구주민지원센터'],label_num: 1219 Folder: NIA_SL_WORD1088_REAL01_F, Frame count: 115
# Label: ['제주특별자치도농아인협회'],label_num: 2207 Folder: NIA_SL_WORD2457_REAL01_F, Frame count: 132
# Label: ['종로3가'],label_num: 2223 Folder: NIA_SL_WORD1406_REAL01_F, Frame count: 128
# Label: ['교무실'],label_num: 281 Folder: NIA_SL_WORD0213_REAL01_F, Frame count: 134
# Label: ['무례'],label_num: 799 Folder: NIA_SL_WORD2259_REAL01_F, Frame count: 139
# Label: ['묻다'],label_num: 834 Folder: NIA_SL_WORD0530_REAL01_F, Frame count: 97
# Label: ['전문'],label_num: 2174 Folder: NIA_SL_WORD1398_REAL01_F, Frame count: 129
# Label: ['평안'],label_num: 2600 Folder: NIA_SL_WORD1173_REAL01_F, Frame count: 141
# Label: ['악영향'],label_num: 1559 Folder: NIA_SL_WORD0692_REAL01_F, Frame count: 130
# Label: ['고려대학교'],label_num: 172 Folder: NIA_SL_WORD1443_REAL01_F, Frame count: 141
# Label: ['북구주민지원센터'],label_num: 1097 Folder: NIA_SL_WORD1085_REAL01_F, Frame count: 108
# Label: ['무덤덤'],label_num: 798 Folder: NIA_SL_WORD1338_REAL01_F, Frame count: 141
# Label: ['십오만'],label_num: 1516 Folder: NIA_SL_WORD2901_REAL01_F, Frame count: 107
# Label: ['광기'],label_num: 249 Folder: NIA_SL_WORD2502_REAL01_F, Frame count: 91
# Label: ['순천시청'],label_num: 1449 Folder: NIA_SL_WORD1909_REAL01_F, Frame count: 145
# Label: ['무산'],label_num: 805 Folder: NIA_SL_WORD2029_REAL01_F, Frame count: 119
# Label: ['동거'],label_num: 647 Folder: NIA_SL_WORD0392_REAL01_F, Frame count: 133
# Label: ['백구십오'],label_num: 913 Folder: NIA_SL_WORD2827_REAL01_F, Frame count: 112
# Label: ['가발'],label_num: 18 Folder: NIA_SL_WORD0355_REAL01_F, Frame count: 118
# Label: ['공범'],label_num: 219 Folder: NIA_SL_WORD2119_REAL01_F, Frame count: 131
# Label: ['삼십억'],label_num: 1250 Folder: NIA_SL_WORD2977_REAL01_F, Frame count: 114
# Label: ['답답'],label_num: 582 Folder: NIA_SL_WORD1102_REAL01_F, Frame count: 130
# Label: ['함안군수화통역센터'],label_num: 2660 Folder: NIA_SL_WORD2455_REAL01_F, Frame count: 180
# Label: ['전근'],label_num: 2167 Folder: NIA_SL_WORD2193_REAL01_F, Frame count: 136
# Label: ['자석'],label_num: 2109 Folder: NIA_SL_WORD0783_REAL01_F, Frame count: 118
# Label: ['대물림'],label_num: 606 Folder: NIA_SL_WORD2229_REAL01_F, Frame count: 131
# Label: ['이의'],label_num: 2028 Folder: NIA_SL_WORD0770_REAL01_F, Frame count: 113
# Label: ['공주시청'],label_num: 225 Folder: NIA_SL_WORD1808_REAL01_F, Frame count: 138
# Label: ['거지'],label_num: 102 Folder: NIA_SL_WORD0199_REAL01_F, Frame count: 112
# Label: ['양양군지부'],label_num: 1615 Folder: NIA_SL_WORD1741_REAL01_F, Frame count: 148
# Label: ['수저통'],label_num: 1436 Folder: NIA_SL_WORD0657_REAL01_F, Frame count: 129
# Label: ['전남농아인협회'],label_num: 2171 Folder: NIA_SL_WORD1882_REAL01_F, Frame count: 148
# Label: ['연천'],label_num: 1707 Folder: NIA_SL_WORD1489_REAL01_F, Frame count: 143
# Label: ['고민'],label_num: 178 Folder: NIA_SL_WORD0001_REAL01_F, Frame count: 138
# Label: ['오만오천'],label_num: 1781 Folder: NIA_SL_WORD2891_REAL01_F, Frame count: 97
# Label: ['이천만'],label_num: 2032 Folder: NIA_SL_WORD2938_REAL01_F, Frame count: 105
# Label: ['고령군지부'],label_num: 175 Folder: NIA_SL_WORD1941_REAL01_F, Frame count: 134
# Label: ['포기'],label_num: 2610 Folder: NIA_SL_WORD2341_REAL01_F, Frame count: 108
# Label: ['추출'],label_num: 2421 Folder: NIA_SL_WORD0920_REAL01_F, Frame count: 112
# Label: ['영양군수어통역센터'],label_num: 1743 Folder: NIA_SL_WORD1972_REAL01_F, Frame count: 162
# Label: ['보건복지부'],label_num: 1044 Folder: NIA_SL_WORD0578_REAL01_F, Frame count: 145
# Label: ['생년월일'],label_num: 1295 Folder: NIA_SL_WORD0328_REAL01_F, Frame count: 111
# Label: ['노원구주민지원센터'],label_num: 526 Folder: NIA_SL_WORD1030_REAL01_F, Frame count: 111
# Label: ['함구'],label_num: 2659 Folder: NIA_SL_WORD2301_REAL01_F, Frame count: 122
# Label: ['맥없다'],label_num: 751 Folder: NIA_SL_WORD2219_REAL01_F, Frame count: 137
# Label: ['깃털'],label_num: 436 Folder: NIA_SL_WORD0302_REAL01_F, Frame count: 123
# Label: ['슬프다'],label_num: 1458 Folder: NIA_SL_WORD0009_REAL01_F, Frame count: 131
# Label: ['동해시청'],label_num: 669 Folder: NIA_SL_WORD1734_REAL01_F, Frame count: 133
# Label: ['한눈팔다'],label_num: 2652 Folder: NIA_SL_WORD1760_REAL01_F, Frame count: 122
# Label: ['알아차리다'],label_num: 1587 Folder: NIA_SL_WORD2483_REAL01_F, Frame count: 104
# Label: ['집중'],label_num: 2299 Folder: NIA_SL_WORD1320_REAL01_F, Frame count: 134
# Label: ['이백사십'],label_num: 1997 Folder: NIA_SL_WORD2836_REAL01_F, Frame count: 111
# Label: ['변덕'],label_num: 1027 Folder: NIA_SL_WORD1203_REAL01_F, Frame count: 114
# Label: ['100만원'],label_num: 0 Folder: NIA_SL_WORD0321_REAL01_F, Frame count: 96
# Label: ['똑똑하다'],label_num: 698 Folder: NIA_SL_WORD1206_REAL01_F, Frame count: 149
# Label: ['여경'],label_num: 1659 Folder: NIA_SL_WORD0725_REAL01_F, Frame count: 139
# Label: ['청양군주민지원센터'],label_num: 2382 Folder: NIA_SL_WORD1838_REAL01_F, Frame count: 126
# Label: ['실습'],label_num: 1501 Folder: NIA_SL_WORD0228_REAL01_F, Frame count: 105
# Label: ['삼백만'],label_num: 1233 Folder: NIA_SL_WORD2922_REAL01_F, Frame count: 98
# Label: ['양산'],label_num: 1607 Folder: NIA_SL_WORD0124_REAL01_F, Frame count: 151
# Label: ['성품'],label_num: 1365 Folder: NIA_SL_WORD2086_REAL01_F, Frame count: 142
# Label: ['과시'],label_num: 231 Folder: NIA_SL_WORD0916_REAL01_F, Frame count: 100
# Label: ['강남'],label_num: 53 Folder: NIA_SL_WORD1411_REAL01_F, Frame count: 119
# Label: ['환대'],label_num: 2724 Folder: NIA_SL_WORD0405_REAL01_F, Frame count: 140
# Label: ['오래도록'],label_num: 1777 Folder: NIA_SL_WORD0950_REAL01_F, Frame count: 102
# Label: ['철모'],label_num: 2362 Folder: NIA_SL_WORD0854_REAL01_F, Frame count: 133
# Label: ['울릉군수어통역센터'],label_num: 1875 Folder: NIA_SL_WORD1984_REAL01_F, Frame count: 186
# Label: ['백오\n'],label_num: 956 Folder: NIA_SL_WORD2737_REAL01_F, Frame count: 119
# Label: ['부안군주민지원센터'],label_num: 1081 Folder: NIA_SL_WORD1863_REAL01_F, Frame count: 141
# Label: ['평택시수어통역센터'],label_num: 2606 Folder: NIA_SL_WORD1714_REAL01_F, Frame count: 170
# Label: ['창피'],label_num: 2332 Folder: NIA_SL_WORD1215_REAL01_F, Frame count: 109
# Label: ['경기도'],label_num: 143 Folder: NIA_SL_WORD0243_REAL01_F, Frame count: 96
# Label: ['십일'],label_num: 1520 Folder: NIA_SL_WORD2643_REAL01_F, Frame count: 120
# Label: ['기막히다'],label_num: 403 Folder: NIA_SL_WORD1122_REAL01_F, Frame count: 138
# Label: ['터미널'],label_num: 2536 Folder: NIA_SL_WORD0172_REAL01_F, Frame count: 116
# Label: ['건달'],label_num: 108 Folder: NIA_SL_WORD0706_REAL01_F, Frame count: 143
# Label: ['과용'],label_num: 232 Folder: NIA_SL_WORD0615_REAL01_F, Frame count: 117
# Label: ['완납'],label_num: 1823 Folder: NIA_SL_WORD0741_REAL01_F, Frame count: 104
# Label: ['네배'],label_num: 514 Folder: NIA_SL_WORD1363_REAL01_F, Frame count: 162
# Label: ['당진시수어통역센터'],label_num: 586 Folder: NIA_SL_WORD1816_REAL01_F, Frame count: 160
# Label: ['이상'],label_num: 2009 Folder: NIA_SL_WORD1247_REAL01_F, Frame count: 131
# Label: ['독특'],label_num: 637 Folder: NIA_SL_WORD0490_REAL01_F, Frame count: 122
# Label: ['길몽'],label_num: 421 Folder: NIA_SL_WORD0446_REAL01_F, Frame count: 113
# Label: ['내뱉다'],label_num: 501 Folder: NIA_SL_WORD2330_REAL01_F, Frame count: 126
# Label: ['고아원'],label_num: 188 Folder: NIA_SL_WORD0383_REAL01_F, Frame count: 112
# Label: ['백오십오'],label_num: 962 Folder: NIA_SL_WORD2787_REAL01_F, Frame count: 110
# Label: ['아름답다'],label_num: 1542 Folder: NIA_SL_WORD2010_REAL01_F, Frame count: 138
# Label: ['광진구수어통역센터'],label_num: 267 Folder: NIA_SL_WORD1021_REAL01_F, Frame count: 152
# Label: ['사무실'],label_num: 1172 Folder: NIA_SL_WORD2183_REAL01_F, Frame count: 176
# Label: ['가시나무'],label_num: 22 Folder: NIA_SL_WORD0291_REAL01_F, Frame count: 113
# Label: ['솔직하다'],label_num: 1402 Folder: NIA_SL_WORD2090_REAL01_F, Frame count: 140
# Label: ['체온'],label_num: 2392 Folder: NIA_SL_WORD0288_REAL01_F, Frame count: 131
# Label: ['어젯밤'],label_num: 1641 Folder: NIA_SL_WORD0309_REAL01_F, Frame count: 115
# Label: ['전주시청'],label_num: 2185 Folder: NIA_SL_WORD1881_REAL01_F, Frame count: 141
# Label: ['책임이사'],label_num: 2338 Folder: NIA_SL_WORD0470_REAL01_F, Frame count: 110
# Label: ['마포구주민지원센터'],label_num: 724 Folder: NIA_SL_WORD1042_REAL01_F, Frame count: 113
# Label: ['수영구주민지원센터'],label_num: 1429 Folder: NIA_SL_WORD1094_REAL01_F, Frame count: 110
# Label: ['내버려두다'],label_num: 502 Folder: NIA_SL_WORD2327_REAL01_F, Frame count: 113
# Label: ['군산시수어통역센터'],label_num: 354 Folder: NIA_SL_WORD1850_REAL01_F, Frame count: 145
# Label: ['기차역'],label_num: 414 Folder: NIA_SL_WORD0156_REAL01_F, Frame count: 113
# Label: ['충혈'],label_num: 2446 Folder: NIA_SL_WORD1326_REAL01_F, Frame count: 110
# Label: ['양주시청'],label_num: 1621 Folder: NIA_SL_WORD1685_REAL01_F, Frame count: 161
# Label: ['견제하다'],label_num: 127 Folder: NIA_SL_WORD1520_REAL01_F, Frame count: 124
# Label: ['하늘'],label_num: 2633 Folder: NIA_SL_WORD2575_REAL01_F, Frame count: 114
# Label: ['태안군지부'],label_num: 2535 Folder: NIA_SL_WORD1839_REAL01_F, Frame count: 126
# Label: ['직책'],label_num: 2279 Folder: NIA_SL_WORD0836_REAL01_F, Frame count: 117
# Label: ['손녀'],label_num: 1398 Folder: NIA_SL_WORD0050_REAL01_F, Frame count: 138
# Label: ['서구수어통역센터'],label_num: 1298 Folder: NIA_SL_WORD1090_REAL01_F, Frame count: 155
# Label: ['제발'],label_num: 2197 Folder: NIA_SL_WORD2569_REAL01_F, Frame count: 122
# Label: ['어떻게'],label_num: 1633 Folder: NIA_SL_WORD0331_REAL01_F, Frame count: 104
# Label: ['교가'],label_num: 278 Folder: NIA_SL_WORD0406_REAL01_F, Frame count: 144
# Label: ['절수'],label_num: 2188 Folder: NIA_SL_WORD0809_REAL01_F, Frame count: 118
# Label: ['미치광이'],label_num: 854 Folder: NIA_SL_WORD0403_REAL01_F, Frame count: 128
# Label: ['악몽'],label_num: 1557 Folder: NIA_SL_WORD0690_REAL01_F, Frame count: 126
# Label: ['영암군수어통역센터'],label_num: 1740 Folder: NIA_SL_WORD1920_REAL01_F, Frame count: 158
# Label: ['가렵다'],label_num: 13 Folder: NIA_SL_WORD1101_REAL01_F, Frame count: 135
# Label: ['삼십만'],label_num: 1247 Folder: NIA_SL_WORD2904_REAL01_F, Frame count: 104
# Label: ['백이십구'],label_num: 981 Folder: NIA_SL_WORD2761_REAL01_F, Frame count: 121
# Label: ['팔'],label_num: 2568 Folder: NIA_SL_WORD2639_REAL01_F, Frame count: 87
# Label: ['종합운동장'],label_num: 2231 Folder: NIA_SL_WORD1445_REAL01_F, Frame count: 158
# Label: ['여성학과'],label_num: 1675 Folder: NIA_SL_WORD0724_REAL01_F, Frame count: 138
# Label: ['평택'],label_num: 2605 Folder: NIA_SL_WORD1484_REAL01_F, Frame count: 126
# Label: ['무안군지부'],label_num: 814 Folder: NIA_SL_WORD1901_REAL01_F, Frame count: 149
# Label: ['눈가림'],label_num: 546 Folder: NIA_SL_WORD2626_REAL01_F, Frame count: 99
# Label: ['부여군지부'],label_num: 1086 Folder: NIA_SL_WORD1821_REAL01_F, Frame count: 133
# Label: ['밀고'],label_num: 861 Folder: NIA_SL_WORD0539_REAL01_F, Frame count: 129
# Label: ['야단치다'],label_num: 1600 Folder: NIA_SL_WORD1284_REAL01_F, Frame count: 131
# Label: ['무념무상'],label_num: 797 Folder: NIA_SL_WORD2030_REAL01_F, Frame count: 141
# Label: ['의왕시수어통역센터'],label_num: 1972 Folder: NIA_SL_WORD1702_REAL01_F, Frame count: 157
# Label: ['치과의사'],label_num: 2449 Folder: NIA_SL_WORD0884_REAL01_F, Frame count: 140
# Label: ['백팔십'],label_num: 1004 Folder: NIA_SL_WORD2812_REAL01_F, Frame count: 106
# Label: ['장애아동수당'],label_num: 2136 Folder: NIA_SL_WORD0791_REAL01_F, Frame count: 131
# Label: ['전심전력'],label_num: 2178 Folder: NIA_SL_WORD0918_REAL01_F, Frame count: 102
# Label: ['실생활'],label_num: 1499 Folder: NIA_SL_WORD0679_REAL01_F, Frame count: 129
# Label: ['남매'],label_num: 480 Folder: NIA_SL_WORD1512_REAL01_F, Frame count: 127
# Label: ['필기시험'],label_num: 2626 Folder: NIA_SL_WORD0027_REAL01_F, Frame count: 138
# Label: ['한국농아인협회'],label_num: 2645 Folder: NIA_SL_WORD1002_REAL01_F, Frame count: 92
# Label: ['술값'],label_num: 1451 Folder: NIA_SL_WORD0662_REAL01_F, Frame count: 113
# Label: ['가능'],label_num: 10 Folder: NIA_SL_WORD1282_REAL01_F, Frame count: 125
# Label: ['친가족'],label_num: 2456 Folder: NIA_SL_WORD0610_REAL01_F, Frame count: 139
# Label: ['백칠십구'],label_num: 994 Folder: NIA_SL_WORD2811_REAL01_F, Frame count: 109
# Label: ['자라다'],label_num: 2103 Folder: NIA_SL_WORD1542_REAL01_F, Frame count: 134
# Label: ['파주'],label_num: 2561 Folder: NIA_SL_WORD1490_REAL01_F, Frame count: 165
# Label: ['징그럽다'],label_num: 2302 Folder: NIA_SL_WORD1110_REAL01_F, Frame count: 128
# Label: ['구십구'],label_num: 321 Folder: NIA_SL_WORD2731_REAL01_F, Frame count: 126
# Label: ['고성지부'],label_num: 184 Folder: NIA_SL_WORD1729_REAL01_F, Frame count: 123
# Label: ['백오십삼'],label_num: 961 Folder: NIA_SL_WORD2785_REAL01_F, Frame count: 114
# Label: ['한국은행'],label_num: 2648 Folder: NIA_SL_WORD0208_REAL01_F, Frame count: 131
# Label: ['막상막하'],label_num: 728 Folder: NIA_SL_WORD2339_REAL01_F, Frame count: 94
# Label: ['사십억'],label_num: 1186 Folder: NIA_SL_WORD2979_REAL01_F, Frame count: 101
# Label: ['남대문시장'],label_num: 479 Folder: NIA_SL_WORD1457_REAL01_F, Frame count: 149
# Label: ['밀거래단'],label_num: 860 Folder: NIA_SL_WORD0541_REAL01_F, Frame count: 168
# Label: ['애매하다'],label_num: 1594 Folder: NIA_SL_WORD1208_REAL01_F, Frame count: 144
# Label: ['순식간'],label_num: 1443 Folder: NIA_SL_WORD0989_REAL01_F, Frame count: 110
# Label: ['한명'],label_num: 2653 Folder: NIA_SL_WORD1109_REAL01_F, Frame count: 136
# Label: ['습자'],label_num: 1459 Folder: NIA_SL_WORD0666_REAL01_F, Frame count: 148
# Label: ['충북'],label_num: 2438 Folder: NIA_SL_WORD0250_REAL01_F, Frame count: 107
# Label: ['이집트'],label_num: 2030 Folder: NIA_SL_WORD2523_REAL01_F, Frame count: 85
# Label: ['부합되다'],label_num: 1095 Folder: NIA_SL_WORD2264_REAL01_F, Frame count: 150
# Label: ['신혼'],label_num: 1496 Folder: NIA_SL_WORD2144_REAL01_F, Frame count: 146
# Label: ['동대문구수어통역센터'],label_num: 652 Folder: NIA_SL_WORD1035_REAL01_F, Frame count: 141
# Label: ['성남'],label_num: 1342 Folder: NIA_SL_WORD1463_REAL01_F, Frame count: 131
# Label: ['지방경찰청장'],label_num: 2271 Folder: NIA_SL_WORD0084_REAL01_F, Frame count: 154
# Label: ['여자'],label_num: 1682 Folder: NIA_SL_WORD1275_REAL01_F, Frame count: 124
# Label: ['사업'],label_num: 1197 Folder: NIA_SL_WORD2189_REAL01_F, Frame count: 134
# Label: ['육십오억'],label_num: 1941 Folder: NIA_SL_WORD2984_REAL01_F, Frame count: 118
# Label: ['기름'],label_num: 401 Folder: NIA_SL_WORD1268_REAL01_F, Frame count: 141
# Label: ['무료교육'],label_num: 800 Folder: NIA_SL_WORD0521_REAL01_F, Frame count: 120
# Label: ['친하다'],label_num: 2463 Folder: NIA_SL_WORD1216_REAL01_F, Frame count: 138
# Label: ['오십육'],label_num: 1801 Folder: NIA_SL_WORD2688_REAL01_F, Frame count: 114
# Label: ['이십육'],label_num: 2021 Folder: NIA_SL_WORD2658_REAL01_F, Frame count: 107
# Label: ['동대문'],label_num: 651 Folder: NIA_SL_WORD1431_REAL01_F, Frame count: 115
# Label: ['고흥군지부'],label_num: 206 Folder: NIA_SL_WORD1886_REAL01_F, Frame count: 130
# Label: ['목포시청'],label_num: 782 Folder: NIA_SL_WORD1900_REAL01_F, Frame count: 147
# Label: ['팔십팔'],label_num: 2590 Folder: NIA_SL_WORD2720_REAL01_F, Frame count: 118
# Label: ['달서구수어통역센터'],label_num: 576 Folder: NIA_SL_WORD1100_REAL01_F, Frame count: 146
# Label: ['순창군지부'],label_num: 1446 Folder: NIA_SL_WORD1864_REAL01_F, Frame count: 131
# Label: ['오백오십만'],label_num: 1786 Folder: NIA_SL_WORD2927_REAL01_F, Frame count: 103
# Label: ['음악가'],label_num: 1961 Folder: NIA_SL_WORD0271_REAL01_F, Frame count: 148
# Label: ['요강'],label_num: 1842 Folder: NIA_SL_WORD0750_REAL01_F, Frame count: 131
# Label: ['충주시청'],label_num: 2445 Folder: NIA_SL_WORD1801_REAL01_F, Frame count: 153
# Label: ['팔백오십만'],label_num: 2576 Folder: NIA_SL_WORD2933_REAL01_F, Frame count: 116
# Label: ['차량번호판'],label_num: 2310 Folder: NIA_SL_WORD1331_REAL01_F, Frame count: 192
# Label: ['제천시지부'],label_num: 2209 Folder: NIA_SL_WORD1790_REAL01_F, Frame count: 122
# Label: ['중랑구주민지원센터'],label_num: 2254 Folder: NIA_SL_WORD1078_REAL01_F, Frame count: 116
# Label: ['맥없다'],label_num: 751 Folder: NIA_SL_WORD2224_REAL01_F, Frame count: 136
# Label: ['문득'],label_num: 829 Folder: NIA_SL_WORD2197_REAL01_F, Frame count: 109
# Label: ['여군'],label_num: 1661 Folder: NIA_SL_WORD0721_REAL01_F, Frame count: 115
# Label: ['출근'],label_num: 2428 Folder: NIA_SL_WORD0170_REAL01_F, Frame count: 103
# Label: ['생각'],label_num: 1292 Folder: NIA_SL_WORD1144_REAL01_F, Frame count: 136
# Label: ['임신'],label_num: 2091 Folder: NIA_SL_WORD1276_REAL01_F, Frame count: 152
# Label: ['장모'],label_num: 2135 Folder: NIA_SL_WORD2160_REAL01_F, Frame count: 124
# Label: ['자막'],label_num: 2105 Folder: NIA_SL_WORD0781_REAL01_F, Frame count: 124
# Label: ['영덕군지부'],label_num: 1729 Folder: NIA_SL_WORD1968_REAL01_F, Frame count: 128
# Label: ['교통기본교육'],label_num: 292 Folder: NIA_SL_WORD0184_REAL01_F, Frame count: 173
# Label: ['술집'],label_num: 1453 Folder: NIA_SL_WORD0663_REAL01_F, Frame count: 115
# Label: ['미신'],label_num: 850 Folder: NIA_SL_WORD0535_REAL01_F, Frame count: 107
# Label: ['양치'],label_num: 1626 Folder: NIA_SL_WORD1555_REAL01_F, Frame count: 118
# Label: ['죽다'],label_num: 2244 Folder: NIA_SL_WORD1538_REAL01_F, Frame count: 114
# Label: ['돕다'],label_num: 645 Folder: NIA_SL_WORD2388_REAL01_F, Frame count: 101
# Label: ['삼십칠'],label_num: 1257 Folder: NIA_SL_WORD2669_REAL01_F, Frame count: 109
# Label: ['오천'],label_num: 1809 Folder: NIA_SL_WORD2872_REAL01_F, Frame count: 93
# Label: ['긍정적'],label_num: 398 Folder: NIA_SL_WORD2060_REAL01_F, Frame count: 128
# Label: ['체온'],label_num: 2392 Folder: NIA_SL_WORD2573_REAL01_F, Frame count: 160
# Label: ['강약'],label_num: 75 Folder: NIA_SL_WORD0365_REAL01_F, Frame count: 115
# Label: ['팔십억'],label_num: 2582 Folder: NIA_SL_WORD2987_REAL01_F, Frame count: 99
# Label: ['구리시수어통역센터'],label_num: 306 Folder: NIA_SL_WORD1657_REAL01_F, Frame count: 170
# Label: ['남녀'],label_num: 478 Folder: NIA_SL_WORD1400_REAL01_F, Frame count: 136
# Label: ['날'],label_num: 472 Folder: NIA_SL_WORD2578_REAL01_F, Frame count: 83
# Label: ['포천시청'],label_num: 2614 Folder: NIA_SL_WORD1718_REAL01_F, Frame count: 141
# Label: ['고질적'],label_num: 196 Folder: NIA_SL_WORD2299_REAL01_F, Frame count: 119
# Label: ['백십일'],label_num: 952 Folder: NIA_SL_WORD2743_REAL01_F, Frame count: 130
# Label: ['의자'],label_num: 1976 Folder: NIA_SL_WORD1182_REAL01_F, Frame count: 132
# Label: ['합심'],label_num: 2663 Folder: NIA_SL_WORD2181_REAL01_F, Frame count: 132
# Label: ['여덟명'],label_num: 1663 Folder: NIA_SL_WORD1311_REAL01_F, Frame count: 134
# Label: ['고수입'],label_num: 187 Folder: NIA_SL_WORD2244_REAL01_F, Frame count: 133
# Label: ['걷다'],label_num: 112 Folder: NIA_SL_WORD1390_REAL01_F, Frame count: 140
# Label: ['왕족'],label_num: 1831 Folder: NIA_SL_WORD0744_REAL01_F, Frame count: 150
# Label: ['부럽다'],label_num: 1076 Folder: NIA_SL_WORD1220_REAL01_F, Frame count: 138
# Label: ['평택시지부'],label_num: 2607 Folder: NIA_SL_WORD1713_REAL01_F, Frame count: 116
# Label: ['완주군주민지원센터'],label_num: 1827 Folder: NIA_SL_WORD1869_REAL01_F, Frame count: 146
# Label: ['머리'],label_num: 755 Folder: NIA_SL_WORD1249_REAL01_F, Frame count: 141
# Label: ['구두액'],label_num: 300 Folder: NIA_SL_WORD0419_REAL01_F, Frame count: 122
# Label: ['와인'],label_num: 1822 Folder: NIA_SL_WORD0119_REAL01_F, Frame count: 128
# Label: ['온도'],label_num: 1816 Folder: NIA_SL_WORD2563_REAL01_F, Frame count: 115
# Label: ['백팔십삼'],label_num: 1007 Folder: NIA_SL_WORD2815_REAL01_F, Frame count: 115
# Label: ['당황'],label_num: 590 Folder: NIA_SL_WORD1128_REAL01_F, Frame count: 147
# Label: ['샛길'],label_num: 1291 Folder: NIA_SL_WORD0204_REAL01_F, Frame count: 154
# Label: ['주정뱅이'],label_num: 2242 Folder: NIA_SL_WORD0956_REAL01_F, Frame count: 110
# Label: ['보령시지부'],label_num: 1048 Folder: NIA_SL_WORD1818_REAL01_F, Frame count: 126
# Label: ['불량'],label_num: 1111 Folder: NIA_SL_WORD0927_REAL01_F, Frame count: 95
# Label: ['꺼지다'],label_num: 445 Folder: NIA_SL_WORD2356_REAL01_F, Frame count: 86
# Label: ['경주시수어통역센터'],label_num: 157 Folder: NIA_SL_WORD1939_REAL01_F, Frame count: 137
# Label: ['힘들다'],label_num: 2770 Folder: NIA_SL_WORD1222_REAL01_F, Frame count: 142
# Label: ['새집'],label_num: 1285 Folder: NIA_SL_WORD0624_REAL01_F, Frame count: 137
# Label: ['오산시수어통역센터'],label_num: 1789 Folder: NIA_SL_WORD1696_REAL01_F, Frame count: 183
# Label: ['제천시수어통역센터'],label_num: 2208 Folder: NIA_SL_WORD1791_REAL01_F, Frame count: 159
# Label: ['온순하다'],label_num: 1817 Folder: NIA_SL_WORD0713_REAL01_F, Frame count: 135
# Label: ['신통하다'],label_num: 1494 Folder: NIA_SL_WORD0677_REAL01_F, Frame count: 123
# Label: ['아끼다'],label_num: 1536 Folder: NIA_SL_WORD0687_REAL01_F, Frame count: 127
# Label: ['운동선수'],label_num: 1868 Folder: NIA_SL_WORD0161_REAL01_F, Frame count: 121
# Label: ['난감하다'],label_num: 471 Folder: NIA_SL_WORD0968_REAL01_F, Frame count: 112
# Label: ['잠실'],label_num: 2125 Folder: NIA_SL_WORD1447_REAL01_F, Frame count: 144
# Label: ['작은할아버지'],label_num: 2120 Folder: NIA_SL_WORD2157_REAL01_F, Frame count: 141
# Label: ['청송군지부'],label_num: 2380 Folder: NIA_SL_WORD1995_REAL01_F, Frame count: 129
# Label: ['구백오십'],label_num: 317 Folder: NIA_SL_WORD2863_REAL01_F, Frame count: 104
# Label: ['네쌍둥이'],label_num: 516 Folder: NIA_SL_WORD1318_REAL01_F, Frame count: 114
# Label: ['해하다'],label_num: 2670 Folder: NIA_SL_WORD2362_REAL01_F, Frame count: 98
# Label: ['조심'],label_num: 2213 Folder: NIA_SL_WORD1186_REAL01_F, Frame count: 141
# Label: ['사천시지부'],label_num: 1213 Folder: NIA_SL_WORD2428_REAL01_F, Frame count: 109
# Label: ['욕구'],label_num: 1844 Folder: NIA_SL_WORD2211_REAL01_F, Frame count: 111
# Label: ['사백만'],label_num: 1174 Folder: NIA_SL_WORD2924_REAL01_F, Frame count: 78
# Label: ['남자'],label_num: 494 Folder: NIA_SL_WORD1104_REAL01_F, Frame count: 136
# Label: ['백삼십사'],label_num: 934 Folder: NIA_SL_WORD2766_REAL01_F, Frame count: 112
# Label: ['마구간'],label_num: 708 Folder: NIA_SL_WORD0497_REAL01_F, Frame count: 141
# Label: ['알아서'],label_num: 1586 Folder: NIA_SL_WORD0019_REAL01_F, Frame count: 110
# Label: ['낙제'],label_num: 467 Folder: NIA_SL_WORD0218_REAL01_F, Frame count: 130
# Label: ['백십삼'],label_num: 948 Folder: NIA_SL_WORD2745_REAL01_F, Frame count: 120
# Label: ['차분'],label_num: 2313 Folder: NIA_SL_WORD1188_REAL01_F, Frame count: 139
# Label: ['회식'],label_num: 2739 Folder: NIA_SL_WORD0183_REAL01_F, Frame count: 125
# Label: ['38선'],label_num: 5 Folder: NIA_SL_WORD0619_REAL01_F, Frame count: 139
# Label: ['갈등'],label_num: 38 Folder: NIA_SL_WORD1287_REAL01_F, Frame count: 144
# Label: ['운전면허'],label_num: 1871 Folder: NIA_SL_WORD1501_REAL01_F, Frame count: 139
# Label: ['진단서'],label_num: 2280 Folder: NIA_SL_WORD0062_REAL01_F, Frame count: 137
# Label: ['센티미터'],label_num: 1375 Folder: NIA_SL_WORD0649_REAL01_F, Frame count: 121
# Label: ['나누다'],label_num: 457 Folder: NIA_SL_WORD1231_REAL01_F, Frame count: 147
# Label: ['중구수어통역센터'],label_num: 2246 Folder: NIA_SL_WORD1074_REAL01_F, Frame count: 141
# Label: ['싫다'],label_num: 1505 Folder: NIA_SL_WORD1278_REAL01_F, Frame count: 122
# Label: ['천안시지부'],label_num: 2351 Folder: NIA_SL_WORD1803_REAL01_F, Frame count: 135
# Label: ['원주'],label_num: 1890 Folder: NIA_SL_WORD2621_REAL01_F, Frame count: 94
# Label: ['도봉구수어통역센터'],label_num: 620 Folder: NIA_SL_WORD1032_REAL01_F, Frame count: 149
# Label: ['울음소리'],label_num: 1883 Folder: NIA_SL_WORD2098_REAL01_F, Frame count: 149
# Label: ['국왕'],label_num: 347 Folder: NIA_SL_WORD0278_REAL01_F, Frame count: 135
# Label: ['동두천시지부'],label_num: 657 Folder: NIA_SL_WORD1668_REAL01_F, Frame count: 140
# Label: ['비상식적'],label_num: 1133 Folder: NIA_SL_WORD2066_REAL01_F, Frame count: 125
# Label: ['사천'],label_num: 1210 Folder: NIA_SL_WORD2870_REAL01_F, Frame count: 85
# Label: ['들키다'],label_num: 684 Folder: NIA_SL_WORD2208_REAL01_F, Frame count: 108
# Label: ['인증'],label_num: 2057 Folder: NIA_SL_WORD0777_REAL01_F, Frame count: 102
# Label: ['소화불량'],label_num: 1390 Folder: NIA_SL_WORD0652_REAL01_F, Frame count: 108
# Label: ['홍콩'],label_num: 2705 Folder: NIA_SL_WORD2599_REAL01_F, Frame count: 103
# Label: ['체취'],label_num: 2393 Folder: NIA_SL_WORD0863_REAL01_F, Frame count: 150
# Label: ['열두번째'],label_num: 1715 Folder: NIA_SL_WORD0760_REAL01_F, Frame count: 96
# Label: ['시달리다'],label_num: 1463 Folder: NIA_SL_WORD0670_REAL01_F, Frame count: 128
# Label: ['귀찮다'],label_num: 375 Folder: NIA_SL_WORD1347_REAL01_F, Frame count: 153
# Label: ['목재'],label_num: 778 Folder: NIA_SL_WORD0799_REAL01_F, Frame count: 134
# Label: ['청도군수어통역센터'],label_num: 2372 Folder: NIA_SL_WORD1993_REAL01_F, Frame count: 199
# Label: ['회의록'],label_num: 2741 Folder: NIA_SL_WORD0769_REAL01_F, Frame count: 108
# Label: ['볼'],label_num: 1068 Folder: NIA_SL_WORD1375_REAL01_F, Frame count: 130
# Label: ['잠자다'],label_num: 2127 Folder: NIA_SL_WORD1245_REAL01_F, Frame count: 141
# Label: ['고난이도'],label_num: 169 Folder: NIA_SL_WORD0453_REAL01_F, Frame count: 115
# Label: ['연수구지부'],label_num: 1705 Folder: NIA_SL_WORD1612_REAL01_F, Frame count: 134
# Label: ['백이십육'],label_num: 985 Folder: NIA_SL_WORD2758_REAL01_F, Frame count: 140
# Label: ['배고프다'],label_num: 901 Folder: NIA_SL_WORD1197_REAL01_F, Frame count: 151
# Label: ['영월군수어통역센터'],label_num: 1747 Folder: NIA_SL_WORD1745_REAL01_F, Frame count: 154
# Label: ['꿈'],label_num: 454 Folder: NIA_SL_WORD1510_REAL01_F, Frame count: 123
# Label: ['원주시수어통역센터'],label_num: 1891 Folder: NIA_SL_WORD1748_REAL01_F, Frame count: 159
# Label: ['밥그릇'],label_num: 891 Folder: NIA_SL_WORD0093_REAL01_F, Frame count: 110
# Label: ['신기'],label_num: 1481 Folder: NIA_SL_WORD0442_REAL01_F, Frame count: 118
# Label: ['삼백팔십'],label_num: 1243 Folder: NIA_SL_WORD2850_REAL01_F, Frame count: 111
# Label: ['고모'],label_num: 177 Folder: NIA_SL_WORD1500_REAL01_F, Frame count: 136
# Label: ['쇄신'],label_num: 1412 Folder: NIA_SL_WORD0654_REAL01_F, Frame count: 107
# Label: ['상상'],label_num: 1273 Folder: NIA_SL_WORD2085_REAL01_F, Frame count: 129
# Label: ['삼백구십'],label_num: 1232 Folder: NIA_SL_WORD2851_REAL01_F, Frame count: 122
# Label: ['국기'],label_num: 345 Folder: NIA_SL_WORD0423_REAL01_F, Frame count: 122
# Label: ['양젖'],label_num: 1617 Folder: NIA_SL_WORD0716_REAL01_F, Frame count: 127
# Label: ['공군본부'],label_num: 217 Folder: NIA_SL_WORD0390_REAL01_F, Frame count: 112
# Label: ['꺼지다'],label_num: 445 Folder: NIA_SL_WORD2353_REAL01_F, Frame count: 94
# Label: ['벌칙사항'],label_num: 1019 Folder: NIA_SL_WORD0565_REAL01_F, Frame count: 179
# Label: ['휴학'],label_num: 2754 Folder: NIA_SL_WORD0377_REAL01_F, Frame count: 104
# Label: ['형식'],label_num: 2690 Folder: NIA_SL_WORD0714_REAL01_F, Frame count: 121
# Label: ['자습'],label_num: 2110 Folder: NIA_SL_WORD0483_REAL01_F, Frame count: 104
# Label: ['일어나다'],label_num: 2078 Folder: NIA_SL_WORD1273_REAL01_F, Frame count: 141
# Label: ['안동시수어통역센터'],label_num: 1564 Folder: NIA_SL_WORD1966_REAL01_F, Frame count: 151
# Label: ['힘'],label_num: 2769 Folder: NIA_SL_WORD1508_REAL01_F, Frame count: 102
# Label: ['회개'],label_num: 2733 Folder: NIA_SL_WORD0259_REAL01_F, Frame count: 125
# Label: ['섬나라'],label_num: 1336 Folder: NIA_SL_WORD0639_REAL01_F, Frame count: 133
# Label: ['십'],label_num: 1509 Folder: NIA_SL_WORD2641_REAL01_F, Frame count: 97
# Label: ['서초구주민지원센터'],label_num: 1326 Folder: NIA_SL_WORD1048_REAL01_F, Frame count: 122
# Label: ['사십이'],label_num: 1191 Folder: NIA_SL_WORD2674_REAL01_F, Frame count: 114
# Label: ['견습'],label_num: 125 Folder: NIA_SL_WORD0364_REAL01_F, Frame count: 110
# Label: ['경북농아인협회'],label_num: 149 Folder: NIA_SL_WORD1934_REAL01_F, Frame count: 143
# Label: ['형'],label_num: 2688 Folder: NIA_SL_WORD1574_REAL01_F, Frame count: 115
# Label: ['어색하다'],label_num: 1640 Folder: NIA_SL_WORD0012_REAL01_F, Frame count: 119
# Label: ['단양군지부'],label_num: 567 Folder: NIA_SL_WORD1778_REAL01_F, Frame count: 118
# Label: ['통영시청'],label_num: 2544 Folder: NIA_SL_WORD2450_REAL01_F, Frame count: 125
# Label: ['보건소'],label_num: 1045 Folder: NIA_SL_WORD0041_REAL01_F, Frame count: 141
# Label: ['고성군주민지원센터'],label_num: 181 Folder: NIA_SL_WORD2418_REAL01_F, Frame count: 122
# Label: ['후지다'],label_num: 2748 Folder: NIA_SL_WORD2540_REAL01_F, Frame count: 90
# Label: ['천호'],label_num: 2356 Folder: NIA_SL_WORD1404_REAL01_F, Frame count: 126
# Label: ['아기'],label_num: 1534 Folder: NIA_SL_WORD1189_REAL01_F, Frame count: 134
# Label: ['몸무게'],label_num: 785 Folder: NIA_SL_WORD2039_REAL01_F, Frame count: 153
# Label: ['조카'],label_num: 2217 Folder: NIA_SL_WORD1568_REAL01_F, Frame count: 117
# Label: ['군가'],label_num: 348 Folder: NIA_SL_WORD0425_REAL01_F, Frame count: 104
# Label: ['일곱배'],label_num: 2066 Folder: NIA_SL_WORD1366_REAL01_F, Frame count: 138
# Label: ['여객선'],label_num: 1658 Folder: NIA_SL_WORD0154_REAL01_F, Frame count: 132
# Label: ['열명'],label_num: 1716 Folder: NIA_SL_WORD1313_REAL01_F, Frame count: 146
# Label: ['위아래'],label_num: 1905 Folder: NIA_SL_WORD2571_REAL01_F, Frame count: 109
# Label: ['대기업'],label_num: 596 Folder: NIA_SL_WORD0195_REAL01_F, Frame count: 121
# Label: ['영천시지부'],label_num: 1754 Folder: NIA_SL_WORD1977_REAL01_F, Frame count: 153
# Label: ['엉뚱'],label_num: 1655 Folder: NIA_SL_WORD2093_REAL01_F, Frame count: 100
# Label: ['귀'],label_num: 371 Folder: NIA_SL_WORD1370_REAL01_F, Frame count: 86
# Label: ['금천구수어통역센터'],label_num: 393 Folder: NIA_SL_WORD1027_REAL01_F, Frame count: 161
# Label: ['교육자'],label_num: 287 Folder: NIA_SL_WORD0216_REAL01_F, Frame count: 111
# Label: ['군위주민지원센터'],label_num: 359 Folder: NIA_SL_WORD1949_REAL01_F, Frame count: 127
# Label: ['전주시수어통역센터'],label_num: 2183 Folder: NIA_SL_WORD1880_REAL01_F, Frame count: 141
# Label: ['한국농아인협회'],label_num: 2645 Folder: NIA_SL_WORD1001_REAL01_F, Frame count: 143
# Label: ['부채질'],label_num: 1088 Folder: NIA_SL_WORD0613_REAL01_F, Frame count: 105
# Label: ['마이동풍'],label_num: 719 Folder: NIA_SL_WORD2311_REAL01_F, Frame count: 112
# Label: ['인색하다'],label_num: 2053 Folder: NIA_SL_WORD2221_REAL01_F, Frame count: 133
# Label: ['달리다'],label_num: 573 Folder: NIA_SL_WORD1274_REAL01_F, Frame count: 113
# Label: ['울릉도'],label_num: 1878 Folder: NIA_SL_WORD0246_REAL01_F, Frame count: 119
# Label: ['금정구지부'],label_num: 390 Folder: NIA_SL_WORD1080_REAL01_F, Frame count: 124
# Label: ['수갑'],label_num: 1417 Folder: NIA_SL_WORD0420_REAL01_F, Frame count: 126
# Label: ['알록달록'],label_num: 1584 Folder: NIA_SL_WORD0718_REAL01_F, Frame count: 139
# Label: ['검사'],label_num: 116 Folder: NIA_SL_WORD0029_REAL01_F, Frame count: 116
# Label: ['수감자'],label_num: 1416 Folder: NIA_SL_WORD0283_REAL01_F, Frame count: 124
# Label: ['썩다'],label_num: 1529 Folder: NIA_SL_WORD1529_REAL01_F, Frame count: 119
# Label: ['남해군수화통역센터'],label_num: 496 Folder: NIA_SL_WORD2423_REAL01_F, Frame count: 142
# Label: ['철근'],label_num: 2360 Folder: NIA_SL_WORD0852_REAL01_F, Frame count: 130
# Label: ['이심전심'],label_num: 2011 Folder: NIA_SL_WORD0976_REAL01_F, Frame count: 102
# Label: ['세쌍둥이'],label_num: 1372 Folder: NIA_SL_WORD1317_REAL01_F, Frame count: 125
# Label: ['퇴임'],label_num: 2550 Folder: NIA_SL_WORD0162_REAL01_F, Frame count: 122
# Label: ['제주시청'],label_num: 2206 Folder: NIA_SL_WORD2463_REAL01_F, Frame count: 135
# Label: ['대박'],label_num: 607 Folder: NIA_SL_WORD2242_REAL01_F, Frame count: 93
# Label: ['10만원'],label_num: 1 Folder: NIA_SL_WORD0330_REAL01_F, Frame count: 102
# Label: ['수집가'],label_num: 1437 Folder: NIA_SL_WORD0053_REAL01_F, Frame count: 155
# Label: ['얌전하다'],label_num: 1604 Folder: NIA_SL_WORD0708_REAL01_F, Frame count: 131
# Label: ['일곱명'],label_num: 2065 Folder: NIA_SL_WORD1310_REAL01_F, Frame count: 134
# Label: ['기대'],label_num: 399 Folder: NIA_SL_WORD1288_REAL01_F, Frame count: 140
# Label: ['남양주시지부'],label_num: 489 Folder: NIA_SL_WORD1665_REAL01_F, Frame count: 128
# Label: ['남해군주민지원센터'],label_num: 497 Folder: NIA_SL_WORD2424_REAL01_F, Frame count: 137
# Label: ['가다'],label_num: 11 Folder: NIA_SL_WORD0946_REAL01_F, Frame count: 103
# Label: ['위인'],label_num: 1906 Folder: NIA_SL_WORD2094_REAL01_F, Frame count: 83
# Label: ['남양주시수어통역센터'],label_num: 488 Folder: NIA_SL_WORD1666_REAL01_F, Frame count: 163
# Label: ['예민'],label_num: 1759 Folder: NIA_SL_WORD2056_REAL01_F, Frame count: 129
# Label: ['후회'],label_num: 2750 Folder: NIA_SL_WORD1252_REAL01_F, Frame count: 138
# Label: ['꽃씨'],label_num: 448 Folder: NIA_SL_WORD0295_REAL01_F, Frame count: 113
# Label: ['백팔십육'],label_num: 1009 Folder: NIA_SL_WORD2818_REAL01_F, Frame count: 120
# Label: ['가수'],label_num: 21 Folder: NIA_SL_WORD0133_REAL01_F, Frame count: 116
# Label: ['용산구수어통역센터'],label_num: 1851 Folder: NIA_SL_WORD1065_REAL01_F, Frame count: 157
# Label: ['장난감'],label_num: 2129 Folder: NIA_SL_WORD2158_REAL01_F, Frame count: 131
# Label: ['팔십일'],label_num: 2588 Folder: NIA_SL_WORD2713_REAL01_F, Frame count: 121
# Label: ['고창군지부'],label_num: 200 Folder: NIA_SL_WORD1846_REAL01_F, Frame count: 117
# Label: ['근근이'],label_num: 379 Folder: NIA_SL_WORD0997_REAL01_F, Frame count: 128
# Label: ['칠백오십만'],label_num: 2474 Folder: NIA_SL_WORD2931_REAL01_F, Frame count: 104
# Label: ['불간섭'],label_num: 1109 Folder: NIA_SL_WORD2346_REAL01_F, Frame count: 96
# Label: ['무자비'],label_num: 818 Folder: NIA_SL_WORD2365_REAL01_F, Frame count: 104
# Label: ['연구'],label_num: 1694 Folder: NIA_SL_WORD2487_REAL01_F, Frame count: 108
# Label: ['미성년'],label_num: 848 Folder: NIA_SL_WORD2075_REAL01_F, Frame count: 143
# Label: ['고난이도'],label_num: 169 Folder: NIA_SL_WORD0449_REAL01_F, Frame count: 115
# Label: ['우습다'],label_num: 1861 Folder: NIA_SL_WORD2495_REAL01_F, Frame count: 96
# Label: ['아홉배'],label_num: 1555 Folder: NIA_SL_WORD1368_REAL01_F, Frame count: 123
# Label: ['낳다'],label_num: 500 Folder: NIA_SL_WORD1213_REAL01_F, Frame count: 138
# Label: ['불경'],label_num: 1110 Folder: NIA_SL_WORD0252_REAL01_F, Frame count: 151
# Label: ['한국민속촌'],label_num: 2646 Folder: NIA_SL_WORD1482_REAL01_F, Frame count: 166
# Label: ['차량점검'],label_num: 2311 Folder: NIA_SL_WORD1495_REAL01_F, Frame count: 147
# Label: ['삼척시수어통역센터'],label_num: 1262 Folder: NIA_SL_WORD1736_REAL01_F, Frame count: 177
# Label: ['감기'],label_num: 41 Folder: NIA_SL_WORD0037_REAL01_F, Frame count: 132
# Label: ['예정'],label_num: 1770 Folder: NIA_SL_WORD0735_REAL01_F, Frame count: 109
# Label: ['용품'],label_num: 1859 Folder: NIA_SL_WORD0110_REAL01_F, Frame count: 108
# Label: ['목마르다'],label_num: 777 Folder: NIA_SL_WORD2036_REAL01_F, Frame count: 135
# Label: ['팔천오백'],label_num: 2595 Folder: NIA_SL_WORD2879_REAL01_F, Frame count: 91
# Label: ['일억'],label_num: 2079 Folder: NIA_SL_WORD2954_REAL01_F, Frame count: 95
# Label: ['양계'],label_num: 1605 Folder: NIA_SL_WORD0709_REAL01_F, Frame count: 137
# Label: ['몰리다'],label_num: 783 Folder: NIA_SL_WORD1250_REAL01_F, Frame count: 150
# Label: ['양평'],label_num: 1628 Folder: NIA_SL_WORD1471_REAL01_F, Frame count: 119
# Label: ['아프다'],label_num: 1551 Folder: NIA_SL_WORD1152_REAL01_F, Frame count: 117
# Label: ['기대다'],label_num: 400 Folder: NIA_SL_WORD2352_REAL01_F, Frame count: 99
# Label: ['파주시지부'],label_num: 2563 Folder: NIA_SL_WORD1710_REAL01_F, Frame count: 149
# Label: ['강서구지부'],label_num: 73 Folder: NIA_SL_WORD1014_REAL01_F, Frame count: 114
# Label: ['칠'],label_num: 2464 Folder: NIA_SL_WORD2638_REAL01_F, Frame count: 84
# Label: ['성주시지부'],label_num: 1361 Folder: NIA_SL_WORD1962_REAL01_F, Frame count: 163
# Label: ['구경'],label_num: 297 Folder: NIA_SL_WORD1503_REAL01_F, Frame count: 118
# Label: ['무시하다'],label_num: 810 Folder: NIA_SL_WORD2381_REAL01_F, Frame count: 95
# Label: ['마음에들다'],label_num: 718 Folder: NIA_SL_WORD0500_REAL01_F, Frame count: 118
# Label: ['칠백만'],label_num: 2471 Folder: NIA_SL_WORD2930_REAL01_F, Frame count: 94
# Label: ['일반직'],label_num: 2070 Folder: NIA_SL_WORD0734_REAL01_F, Frame count: 98
# Label: ['예산군주민지원센터'],label_num: 1762 Folder: NIA_SL_WORD1835_REAL01_F, Frame count: 148
# Label: ['장애인'],label_num: 2138 Folder: NIA_SL_WORD0020_REAL01_F, Frame count: 117
# Label: ['걱정'],label_num: 106 Folder: NIA_SL_WORD1294_REAL01_F, Frame count: 147
# Label: ['어림없다'],label_num: 1639 Folder: NIA_SL_WORD2314_REAL01_F, Frame count: 111
# Label: ['노원'],label_num: 524 Folder: NIA_SL_WORD1428_REAL01_F, Frame count: 113
# Label: ['여성복'],label_num: 1674 Folder: NIA_SL_WORD0723_REAL01_F, Frame count: 120
# Label: ['백육십이'],label_num: 975 Folder: NIA_SL_WORD2794_REAL01_F, Frame count: 115
# Label: ['성인'],label_num: 1358 Folder: NIA_SL_WORD0641_REAL01_F, Frame count: 130
# Label: ['분필'],label_num: 1103 Folder: NIA_SL_WORD0224_REAL01_F, Frame count: 99
# Label: ['백오십이'],label_num: 964 Folder: NIA_SL_WORD2784_REAL01_F, Frame count: 116
# Label: ['맞추다'],label_num: 745 Folder: NIA_SL_WORD0389_REAL01_F, Frame count: 93
# Label: ['괴산군주민지원센터'],label_num: 275 Folder: NIA_SL_WORD1777_REAL01_F, Frame count: 125
# Label: ['이만'],label_num: 1990 Folder: NIA_SL_WORD2884_REAL01_F, Frame count: 90
# Label: ['상주시수어통역센터'],label_num: 1277 Folder: NIA_SL_WORD1960_REAL01_F, Frame count: 158
# Label: ['고추가루'],label_num: 202 Folder: NIA_SL_WORD0075_REAL01_F, Frame count: 138
# Label: ['남구주민지원센터'],label_num: 476 Folder: NIA_SL_WORD1634_REAL01_F, Frame count: 133
# Label: ['재미없다'],label_num: 2152 Folder: NIA_SL_WORD1731_REAL01_F, Frame count: 117
# Label: ['구천오백만'],label_num: 342 Folder: NIA_SL_WORD2953_REAL01_F, Frame count: 113
# Label: ['인력'],label_num: 2050 Folder: NIA_SL_WORD0773_REAL01_F, Frame count: 124
# Label: ['권투'],label_num: 370 Folder: NIA_SL_WORD1505_REAL01_F, Frame count: 120
# Label: ['확정'],label_num: 2722 Folder: NIA_SL_WORD0477_REAL01_F, Frame count: 127
# Label: ['의미'],label_num: 1965 Folder: NIA_SL_WORD1196_REAL01_F, Frame count: 143
# Label: ['삼천만'],label_num: 1266 Folder: NIA_SL_WORD2940_REAL01_F, Frame count: 104
# Label: ['촉박'],label_num: 2405 Folder: NIA_SL_WORD0934_REAL01_F, Frame count: 102
# Label: ['북구지부'],label_num: 1098 Folder: NIA_SL_WORD1083_REAL01_F, Frame count: 119
# Label: ['강화군수어통역센터'],label_num: 85 Folder: NIA_SL_WORD1610_REAL01_F, Frame count: 161
# Label: ['일몰'],label_num: 2068 Folder: NIA_SL_WORD2564_REAL01_F, Frame count: 98
# Label: ['넘기다'],label_num: 511 Folder: NIA_SL_WORD2292_REAL01_F, Frame count: 116
# Label: ['등록금'],label_num: 686 Folder: NIA_SL_WORD0493_REAL01_F, Frame count: 123
# Label: ['망아지'],label_num: 743 Folder: NIA_SL_WORD0507_REAL01_F, Frame count: 143
# Label: ['촉진'],label_num: 2406 Folder: NIA_SL_WORD0871_REAL01_F, Frame count: 118
# Label: ['성북구주민지원센터'],label_num: 1354 Folder: NIA_SL_WORD1054_REAL01_F, Frame count: 132
# Label: ['화실'],label_num: 2714 Folder: NIA_SL_WORD0551_REAL01_F, Frame count: 117
# Label: ['달변'],label_num: 574 Folder: NIA_SL_WORD2296_REAL01_F, Frame count: 157
# Label: ['뜻밖'],label_num: 704 Folder: NIA_SL_WORD2491_REAL01_F, Frame count: 113
# Label: ['팔만오천'],label_num: 2571 Folder: NIA_SL_WORD2897_REAL01_F, Frame count: 106
# Label: ['전남도청'],label_num: 2172 Folder: NIA_SL_WORD2476_REAL01_F, Frame count: 158
# Label: ['관악구지부'],label_num: 248 Folder: NIA_SL_WORD1017_REAL01_F, Frame count: 106
# Label: ['중독'],label_num: 2251 Folder: NIA_SL_WORD1569_REAL01_F, Frame count: 97
# Label: ['서귀포시지부'],label_num: 1303 Folder: NIA_SL_WORD2458_REAL01_F, Frame count: 110
# Label: ['거절'],label_num: 98 Folder: NIA_SL_WORD2226_REAL01_F, Frame count: 112
# Label: ['의성군지부'],label_num: 1970 Folder: NIA_SL_WORD1989_REAL01_F, Frame count: 140
# ...
# Label: ['강'],label_num: 52 Folder: NIA_SL_WORD0285_REAL01_F, Frame count: 126
# Label: ['시원하다'],label_num: 1468 Folder: NIA_SL_WORD1301_REAL01_F, Frame count: 123
# Label: ['무소유'],label_num: 808 Folder: NIA_SL_WORD1752_REAL01_F, Frame count: 116
# Label: ['위스키'],label_num: 1904 Folder: NIA_SL_WORD0108_REAL01_F, Frame count: 93
# Label: ['걸스카우트'],label_num: 113 Folder: NIA_SL_WORD0375_REAL01_F, Frame count: 100
# Label: ['영덕군수어통역센터'],label_num: 1727 Folder: NIA_SL_WORD1969_REAL01_F, Frame count: 153
# Label: ['동갑'],label_num: 646 Folder: NIA_SL_WORD0487_REAL01_F, Frame count: 111
# Label: ['칠십억'],label_num: 2480 Folder: NIA_SL_WORD2985_REAL01_F, Frame count: 113
# Label: ['훈련'],label_num: 2751 Folder: NIA_SL_WORD0241_REAL01_F, Frame count: 104
# Label: ['노원구지부'],label_num: 527 Folder: NIA_SL_WORD1028_REAL01_F, Frame count: 116
# Label: ['사용법'],label_num: 1200 Folder: NIA_SL_WORD0609_REAL01_F, Frame count: 150
# Label: ['오산시지부'],label_num: 1791 Folder: NIA_SL_WORD1695_REAL01_F, Frame count: 132
# Label: ['뺨맞다'],label_num: 1146 Folder: NIA_SL_WORD1246_REAL01_F, Frame count: 139
# Label: ['봐주다'],label_num: 1072 Folder: NIA_SL_WORD2620_REAL01_F, Frame count: 102
# Label: ['색종이'],label_num: 1290 Folder: NIA_SL_WORD0627_REAL01_F, Frame count: 119
# Label: ['오십억'],label_num: 1797 Folder: NIA_SL_WORD2981_REAL01_F, Frame count: 82
# Label: ['첫번째'],label_num: 2369 Folder: NIA_SL_WORD0058_REAL01_F, Frame count: 93
# Label: ['보복'],label_num: 1050 Folder: NIA_SL_WORD0994_REAL01_F, Frame count: 91
# Label: ['문화유산'],label_num: 833 Folder: NIA_SL_WORD0270_REAL01_F, Frame count: 117
# Label: ['의사'],label_num: 1966 Folder: NIA_SL_WORD0163_REAL01_F, Frame count: 129
# Label: ['구억오천만'],label_num: 335 Folder: NIA_SL_WORD2971_REAL01_F, Frame count: 112
# Label: ['강릉시지부'],label_num: 63 Folder: NIA_SL_WORD1726_REAL01_F, Frame count: 116
# Label: ['명예'],label_num: 771 Folder: NIA_SL_WORD0517_REAL01_F, Frame count: 97
# Label: ['꿀벌'],label_num: 452 Folder: NIA_SL_WORD2585_REAL01_F, Frame count: 120
# Label: ['광진구주민지원센터'],label_num: 268 Folder: NIA_SL_WORD1022_REAL01_F, Frame count: 106
# Label: ['무례'],label_num: 799 Folder: NIA_SL_WORD0519_REAL01_F, Frame count: 117
# Label: ['동의'],label_num: 662 Folder: NIA_SL_WORD2053_REAL01_F, Frame count: 137
# Label: ['완벽'],label_num: 1825 Folder: NIA_SL_WORD0595_REAL01_F, Frame count: 112
# Label: ['전주'],label_num: 2182 Folder: NIA_SL_WORD2623_REAL01_F, Frame count: 96
# Label: ['사억'],label_num: 1195 Folder: NIA_SL_WORD2960_REAL01_F, Frame count: 93
# Label: ['이력서'],label_num: 1988 Folder: NIA_SL_WORD0164_REAL01_F, Frame count: 144
# Label: ['이억'],label_num: 2026 Folder: NIA_SL_WORD2956_REAL01_F, Frame count: 96
# Label: ['장애인복지관'],label_num: 2141 Folder: NIA_SL_WORD0795_REAL01_F, Frame count: 152
# Label: ['감사'],label_num: 44 Folder: NIA_SL_WORD1290_REAL01_F, Frame count: 135
# Label: ['김포시수어통역센터'],label_num: 430 Folder: NIA_SL_WORD1663_REAL01_F, Frame count: 174
# Label: ['양산시청'],label_num: 1610 Folder: NIA_SL_WORD2436_REAL01_F, Frame count: 141
# Label: ['북한'],label_num: 1099 Folder: NIA_SL_WORD2591_REAL01_F, Frame count: 112
# Label: ['장흥군지부'],label_num: 2149 Folder: NIA_SL_WORD1925_REAL01_F, Frame count: 133
# Label: ['일임'],label_num: 2083 Folder: NIA_SL_WORD0710_REAL01_F, Frame count: 126
# Label: ['뽐내다'],label_num: 1149 Folder: NIA_SL_WORD0914_REAL01_F, Frame count: 106
# Label: ['어렵다'],label_num: 1634 Folder: NIA_SL_WORD1211_REAL01_F, Frame count: 136
# Label: ['형편없다'],label_num: 2692 Folder: NIA_SL_WORD2384_REAL01_F, Frame count: 90
# Label: ['속초시수어통역센터'],label_num: 1394 Folder: NIA_SL_WORD1739_REAL01_F, Frame count: 156
# Label: ['추억'],label_num: 2420 Folder: NIA_SL_WORD1202_REAL01_F, Frame count: 143
# Label: ['가명'],label_num: 17 Folder: NIA_SL_WORD0354_REAL01_F, Frame count: 108
# Label: ['치약'],label_num: 2455 Folder: NIA_SL_WORD0132_REAL01_F, Frame count: 131
# Label: ['인상'],label_num: 2052 Folder: NIA_SL_WORD1146_REAL01_F, Frame count: 136
# Label: ['동해시수어통역센터'],label_num: 667 Folder: NIA_SL_WORD1733_REAL01_F, Frame count: 158
# Label: ['십오억'],label_num: 1517 Folder: NIA_SL_WORD2974_REAL01_F, Frame count: 116
# Label: ['소금물'],label_num: 1379 Folder: NIA_SL_WORD0650_REAL01_F, Frame count: 119
# Label: ['달서구지부'],label_num: 578 Folder: NIA_SL_WORD1099_REAL01_F, Frame count: 107
# Label: ['강동구지부'],label_num: 60 Folder: NIA_SL_WORD1008_REAL01_F, Frame count: 118
# Label: ['용인시청'],label_num: 1858 Folder: NIA_SL_WORD1700_REAL01_F, Frame count: 137
# Label: ['상주시지부'],label_num: 1278 Folder: NIA_SL_WORD1959_REAL01_F, Frame count: 141
# Label: ['서구지부'],label_num: 1301 Folder: NIA_SL_WORD1089_REAL01_F, Frame count: 110
# Label: ['마르다'],label_num: 710 Folder: NIA_SL_WORD0969_REAL01_F, Frame count: 101
# Label: ['세종특별자치시농아인협회'],label_num: 1374 Folder: NIA_SL_WORD1639_REAL01_F, Frame count: 178
# Label: ['걷다'],label_num: 112 Folder: NIA_SL_WORD1393_REAL01_F, Frame count: 128
# Label: ['무리'],label_num: 801 Folder: NIA_SL_WORD1291_REAL01_F, Frame count: 131
# Label: ['주문서'],label_num: 2237 Folder: NIA_SL_WORD0496_REAL01_F, Frame count: 134
# Label: ['부천시지부'],label_num: 1091 Folder: NIA_SL_WORD1671_REAL01_F, Frame count: 127
# Label: ['고창군수어통역센터'],label_num: 198 Folder: NIA_SL_WORD1847_REAL01_F, Frame count: 154
# Label: ['나주시수어통역센터'],label_num: 463 Folder: NIA_SL_WORD1896_REAL01_F, Frame count: 172
# Label: ['하동군지부'],label_num: 2636 Folder: NIA_SL_WORD2451_REAL01_F, Frame count: 115
# Label: ['분혹색'],label_num: 1104 Folder: NIA_SL_WORD0324_REAL01_F, Frame count: 116
# Label: ['삼십육'],label_num: 1254 Folder: NIA_SL_WORD2668_REAL01_F, Frame count: 110
# Label: ['잠기다'],label_num: 2124 Folder: NIA_SL_WORD2117_REAL01_F, Frame count: 109
# Label: ['관악구주민지원센터'],label_num: 247 Folder: NIA_SL_WORD1019_REAL01_F, Frame count: 113
# Label: ['대박'],label_num: 607 Folder: NIA_SL_WORD0959_REAL01_F, Frame count: 114
# Label: ['사별'],label_num: 1178 Folder: NIA_SL_WORD1575_REAL01_F, Frame count: 116
# Label: ['독보적'],label_num: 627 Folder: NIA_SL_WORD0733_REAL01_F, Frame count: 143
# Label: ['털'],label_num: 2538 Folder: NIA_SL_WORD1265_REAL01_F, Frame count: 142
# Label: ['청원'],label_num: 2384 Folder: NIA_SL_WORD0860_REAL01_F, Frame count: 120
# Label: ['예산군지부'],label_num: 1763 Folder: NIA_SL_WORD1833_REAL01_F, Frame count: 132
# Label: ['경찰청장'],label_num: 161 Folder: NIA_SL_WORD0209_REAL01_F, Frame count: 112
# Label: ['콩가루'],label_num: 2508 Folder: NIA_SL_WORD0117_REAL01_F, Frame count: 132
# Label: ['불복종'],label_num: 1114 Folder: NIA_SL_WORD2306_REAL01_F, Frame count: 135
# Label: ['울릉군주민지원센터'],label_num: 1876 Folder: NIA_SL_WORD1985_REAL01_F, Frame count: 156
# Label: ['은평구지부'],label_num: 1956 Folder: NIA_SL_WORD1067_REAL01_F, Frame count: 106
# Label: ['제주시지부'],label_num: 2205 Folder: NIA_SL_WORD2461_REAL01_F, Frame count: 123
# Label: ['하남시지부'],label_num: 2630 Folder: NIA_SL_WORD1719_REAL01_F, Frame count: 159
# Label: ['부천시청'],label_num: 1092 Folder: NIA_SL_WORD1673_REAL01_F, Frame count: 152
# Label: ['외손자'],label_num: 1837 Folder: NIA_SL_WORD0749_REAL01_F, Frame count: 134
# Label: ['김포'],label_num: 429 Folder: NIA_SL_WORD1418_REAL01_F, Frame count: 138
# Label: ['확약'],label_num: 2720 Folder: NIA_SL_WORD0509_REAL01_F, Frame count: 131
# Label: ['고등학생'],label_num: 171 Folder: NIA_SL_WORD0212_REAL01_F, Frame count: 124
# Label: ['봐주다'],label_num: 1072 Folder: NIA_SL_WORD2594_REAL01_F, Frame count: 118
# Label: ['대물림'],label_num: 606 Folder: NIA_SL_WORD2230_REAL01_F, Frame count: 114
# Label: ['금정구주민지원센터'],label_num: 389 Folder: NIA_SL_WORD1082_REAL01_F, Frame count: 122
# Label: ['미남'],label_num: 844 Folder: NIA_SL_WORD1108_REAL01_F, Frame count: 140
# Label: ['이불'],label_num: 2007 Folder: NIA_SL_WORD0127_REAL01_F, Frame count: 100
# Label: ['안성시지부'],label_num: 1571 Folder: NIA_SL_WORD1677_REAL01_F, Frame count: 156
# Label: ['합의'],label_num: 2664 Folder: NIA_SL_WORD2223_REAL01_F, Frame count: 110
# Label: ['진주시지부'],label_num: 2289 Folder: NIA_SL_WORD2437_REAL01_F, Frame count: 111
# Label: ['남원시지부'],label_num: 492 Folder: NIA_SL_WORD1855_REAL01_F, Frame count: 117
# Label: ['공문'],label_num: 218 Folder: NIA_SL_WORD2175_REAL01_F, Frame count: 166
# Label: ['팔억오천만'],label_num: 2592 Folder: NIA_SL_WORD2969_REAL01_F, Frame count: 111
# Label: ['재택근무'],label_num: 2158 Folder: NIA_SL_WORD0166_REAL01_F, Frame count: 127
# Label: ['맞다'],label_num: 744 Folder: NIA_SL_WORD2317_REAL01_F, Frame count: 128
# Label: ['세종특별자치시'],label_num: 1373 Folder: NIA_SL_WORD2469_REAL01_F, Frame count: 141
# Label: ['백이십칠'],label_num: 988 Folder: NIA_SL_WORD2759_REAL01_F, Frame count: 112
# Label: ['모르다'],label_num: 772 Folder: NIA_SL_WORD1096_REAL01_F, Frame count: 84
# Label: ['삼백삼십'],label_num: 1235 Folder: NIA_SL_WORD2845_REAL01_F, Frame count: 115
# Label: ['돌벽'],label_num: 643 Folder: NIA_SL_WORD0486_REAL01_F, Frame count: 119
# Label: ['강릉'],label_num: 61 Folder: NIA_SL_WORD2630_REAL01_F, Frame count: 99
# Label: ['하남'],label_num: 2628 Folder: NIA_SL_WORD1464_REAL01_F, Frame count: 132
# Label: ['양산시수화통역센터'],label_num: 1608 Folder: NIA_SL_WORD2435_REAL01_F, Frame count: 185
# Label: ['구백오십만'],label_num: 318 Folder: NIA_SL_WORD2935_REAL01_F, Frame count: 122
# Label: ['화가'],label_num: 2706 Folder: NIA_SL_WORD2201_REAL01_F, Frame count: 131
# Label: ['비닐하우스'],label_num: 1128 Folder: NIA_SL_WORD0590_REAL01_F, Frame count: 116
# Label: ['강아지'],label_num: 74 Folder: NIA_SL_WORD0292_REAL01_F, Frame count: 123
# Label: ['회장'],label_num: 2742 Folder: NIA_SL_WORD0479_REAL01_F, Frame count: 126
# Label: ['자살'],label_num: 2107 Folder: NIA_SL_WORD1561_REAL01_F, Frame count: 114
# Label: ['칠십구'],label_num: 2476 Folder: NIA_SL_WORD2711_REAL01_F, Frame count: 108
# Label: ['서산시청'],label_num: 1312 Folder: NIA_SL_WORD1826_REAL01_F, Frame count: 133
# Label: ['헛수고'],label_num: 2679 Folder: NIA_SL_WORD2240_REAL01_F, Frame count: 132
# Label: ['외국인'],label_num: 1833 Folder: NIA_SL_WORD0014_REAL01_F, Frame count: 149
# Label: ['나주시청'],label_num: 465 Folder: NIA_SL_WORD1897_REAL01_F, Frame count: 148
# Label: ['친척'],label_num: 2462 Folder: NIA_SL_WORD0608_REAL01_F, Frame count: 130
# Label: ['칠십오만'],label_num: 2482 Folder: NIA_SL_WORD2913_REAL01_F, Frame count: 107
# Label: ['째려보다'],label_num: 2306 Folder: NIA_SL_WORD1397_REAL01_F, Frame count: 116
# Label: ['양다리'],label_num: 1606 Folder: NIA_SL_WORD2298_REAL01_F, Frame count: 127
# Label: ['춥다'],label_num: 2432 Folder: NIA_SL_WORD1248_REAL01_F, Frame count: 130
# Label: ['수상'],label_num: 1421 Folder: NIA_SL_WORD2128_REAL01_F, Frame count: 140
# Label: ['동구수어통역센터'],label_num: 648 Folder: NIA_SL_WORD1603_REAL01_F, Frame count: 161
# Label: ['수성구지부'],label_num: 1424 Folder: NIA_SL_WORD1605_REAL01_F, Frame count: 130
# Label: ['봐주다'],label_num: 1072 Folder: NIA_SL_WORD2360_REAL01_F, Frame count: 118
# Label: ['안양'],label_num: 1575 Folder: NIA_SL_WORD1473_REAL01_F, Frame count: 132
# Label: ['양평군수어통역센터'],label_num: 1629 Folder: NIA_SL_WORD1687_REAL01_F, Frame count: 159
# Label: ['동해시지부'],label_num: 668 Folder: NIA_SL_WORD1732_REAL01_F, Frame count: 138
# Label: ['속초시청'],label_num: 1396 Folder: NIA_SL_WORD1740_REAL01_F, Frame count: 130
# Label: ['전화번호'],label_num: 2186 Folder: NIA_SL_WORD0808_REAL01_F, Frame count: 133
# Label: ['무례'],label_num: 799 Folder: NIA_SL_WORD2260_REAL01_F, Frame count: 124
# Label: ['경남농아인협회'],label_num: 145 Folder: NIA_SL_WORD2408_REAL01_F, Frame count: 136
# Label: ['금연'],label_num: 385 Folder: NIA_SL_WORD0437_REAL01_F, Frame count: 105
# Label: ['뛰어나다'],label_num: 702 Folder: NIA_SL_WORD2019_REAL01_F, Frame count: 137
# Label: ['백이십팔'],label_num: 989 Folder: NIA_SL_WORD2760_REAL01_F, Frame count: 121
# Label: ['이란'],label_num: 1986 Folder: NIA_SL_WORD2522_REAL01_F, Frame count: 88
# Label: ['성씨'],label_num: 1357 Folder: NIA_SL_WORD0645_REAL01_F, Frame count: 127
# Label: ['거지'],label_num: 102 Folder: NIA_SL_WORD0373_REAL01_F, Frame count: 111
# Label: ['논산시청'],label_num: 535 Folder: NIA_SL_WORD1814_REAL01_F, Frame count: 157
# Label: ['경찰행정'],label_num: 162 Folder: NIA_SL_WORD0381_REAL01_F, Frame count: 128
# Label: ['오천만'],label_num: 1810 Folder: NIA_SL_WORD2944_REAL01_F, Frame count: 113
# Label: ['육십사'],label_num: 1936 Folder: NIA_SL_WORD2696_REAL01_F, Frame count: 111
# Label: ['비좁다'],label_num: 1136 Folder: NIA_SL_WORD0450_REAL01_F, Frame count: 125
# Label: ['호명'],label_num: 2694 Folder: NIA_SL_WORD0588_REAL01_F, Frame count: 108
# Label: ['교통안전교육'],label_num: 294 Folder: NIA_SL_WORD0181_REAL01_F, Frame count: 145
# Label: ['당황'],label_num: 590 Folder: NIA_SL_WORD2369_REAL01_F, Frame count: 96
# Label: ['육만오천'],label_num: 1927 Folder: NIA_SL_WORD2893_REAL01_F, Frame count: 106
# Label: ['장마'],label_num: 2134 Folder: NIA_SL_WORD2566_REAL01_F, Frame count: 121
# Label: ['삼백'],label_num: 1231 Folder: NIA_SL_WORD2842_REAL01_F, Frame count: 94
# Label: ['홍천군수어통역센터'],label_num: 2702 Folder: NIA_SL_WORD1766_REAL01_F, Frame count: 168
# Label: ['콧물'],label_num: 2507 Folder: NIA_SL_WORD1239_REAL01_F, Frame count: 147
# Label: ['보건복지'],label_num: 1043 Folder: NIA_SL_WORD0279_REAL01_F, Frame count: 129
# Label: ['양서'],label_num: 1611 Folder: NIA_SL_WORD0712_REAL01_F, Frame count: 107
# Label: ['유구무언'],label_num: 1908 Folder: NIA_SL_WORD2210_REAL01_F, Frame count: 112
# Label: ['사고방식'],label_num: 1156 Folder: NIA_SL_WORD0824_REAL01_F, Frame count: 125
# Label: ['번거롭다'],label_num: 1017 Folder: NIA_SL_WORD0562_REAL01_F, Frame count: 155
# Label: ['훌륭'],label_num: 2752 Folder: NIA_SL_WORD1199_REAL01_F, Frame count: 115
# Label: ['옛것'],label_num: 1774 Folder: NIA_SL_WORD0963_REAL01_F, Frame count: 122
# Label: ['유구무언'],label_num: 1908 Folder: NIA_SL_WORD2337_REAL01_F, Frame count: 135
# Label: ['옥천군지부'],label_num: 1815 Folder: NIA_SL_WORD1787_REAL01_F, Frame count: 144
# Label: ['여덟번째'],label_num: 1665 Folder: NIA_SL_WORD0680_REAL01_F, Frame count: 105
# Label: ['구화'],label_num: 343 Folder: NIA_SL_WORD2123_REAL01_F, Frame count: 126
# Label: ['햇빛'],label_num: 2672 Folder: NIA_SL_WORD2580_REAL01_F, Frame count: 105
# Label: ['서산시지부'],label_num: 1311 Folder: NIA_SL_WORD1824_REAL01_F, Frame count: 130
# Label: ['소식'],label_num: 1385 Folder: NIA_SL_WORD0978_REAL01_F, Frame count: 103
# Label: ['이십오'],label_num: 2018 Folder: NIA_SL_WORD2657_REAL01_F, Frame count: 109
# Label: ['양양군수어통역센터'],label_num: 1613 Folder: NIA_SL_WORD1742_REAL01_F, Frame count: 173
# Label: ['밀거래'],label_num: 859 Folder: NIA_SL_WORD0540_REAL01_F, Frame count: 117
# Label: ['가평군지부'],label_num: 32 Folder: NIA_SL_WORD1641_REAL01_F, Frame count: 149
# Label: ['불가능'],label_num: 1107 Folder: NIA_SL_WORD1878_REAL01_F, Frame count: 95
# Label: ['사십육'],label_num: 1190 Folder: NIA_SL_WORD2678_REAL01_F, Frame count: 121
# Label: ['서대문'],label_num: 1306 Folder: NIA_SL_WORD1436_REAL01_F, Frame count: 121
# Label: ['독도'],label_num: 625 Folder: NIA_SL_WORD2506_REAL01_F, Frame count: 100
# Label: ['부고'],label_num: 1073 Folder: NIA_SL_WORD0581_REAL01_F, Frame count: 125
# Label: ['관악구수어통역센터'],label_num: 246 Folder: NIA_SL_WORD1018_REAL01_F, Frame count: 161
# Label: ['베다'],label_num: 1022 Folder: NIA_SL_WORD0564_REAL01_F, Frame count: 146
# Label: ['진실'],label_num: 2287 Folder: NIA_SL_WORD0838_REAL01_F, Frame count: 123
# Label: ['연말'],label_num: 1700 Folder: NIA_SL_WORD0333_REAL01_F, Frame count: 129
# Label: ['백구'],label_num: 908 Folder: NIA_SL_WORD2741_REAL01_F, Frame count: 118
# Label: ['애처'],label_num: 1596 Folder: NIA_SL_WORD0704_REAL01_F, Frame count: 138
# Label: ['노랑'],label_num: 519 Folder: NIA_SL_WORD1323_REAL01_F, Frame count: 124
# Label: ['한글'],label_num: 2650 Folder: NIA_SL_WORD2200_REAL01_F, Frame count: 149
# Label: ['고성시수어통역센터'],label_num: 183 Folder: NIA_SL_WORD1730_REAL01_F, Frame count: 156
# Label: ['파주시청'],label_num: 2564 Folder: NIA_SL_WORD1712_REAL01_F, Frame count: 136
# Label: ['재량'],label_num: 2151 Folder: NIA_SL_WORD2236_REAL01_F, Frame count: 119
# Label: ['칼슘'],label_num: 2500 Folder: NIA_SL_WORD0889_REAL01_F, Frame count: 144
# Label: ['진도군지부'],label_num: 2283 Folder: NIA_SL_WORD1928_REAL01_F, Frame count: 136
# Label: ['구십팔'],label_num: 333 Folder: NIA_SL_WORD2730_REAL01_F, Frame count: 130
# Label: ['열번째'],label_num: 1718 Folder: NIA_SL_WORD0759_REAL01_F, Frame count: 101
# Label: ['황금색'],label_num: 2729 Folder: NIA_SL_WORD0348_REAL01_F, Frame count: 120
# Label: ['벌꿀'],label_num: 1018 Folder: NIA_SL_WORD0079_REAL01_F, Frame count: 129
# <torch.utils.data.dataloader.DataLoader object at 0x73b118e74c10>

# %%
print(len(dataloader))
# Out:
# 188

# %%
for batch_idx, (inputs, labels, lengths) in enumerate(dataloader):
    print(f"Batch {batch_idx}:")
    print(f"Inputs: {inputs}")
    print(f"Labels: {labels}")
    print(f"Lengths: {lengths}")
    print(f"Inputs shape: {inputs.shape}")
    print(f"Labels shape: {labels.shape}")
    
    # 배치 2개만 출력하고 종료
    if batch_idx == 1:
        break
# Out:
# Batch 0:
# Inputs: tensor([[[ 9.0718e+02,  2.3556e+02,  9.0718e+02,  ..., -1.8762e-01,
#            5.0495e-01,  2.4338e+00],
#          [ 9.1722e+02,  2.3588e+02,  9.1722e+02,  ..., -1.2512e-02,
#            1.3704e-01,  2.1267e+00],
#          [ 9.0717e+02,  2.3335e+02,  9.0717e+02,  ..., -1.9075e-01,
#            5.0099e-01,  2.4050e+00],
#          ...,
#          [ 9.1302e+02,  2.4398e+02,  9.1382e+02,  ...,  5.0804e-02,
#           -1.0943e-01,  2.1172e+00],
#          [ 9.0551e+02,  2.3500e+02,  9.0551e+02,  ..., -1.9046e-01,
#            5.0617e-01,  2.4234e+00],
#          [ 9.1141e+02,  2.3443e+02,  9.1054e+02,  ..., -5.4972e-02,
#            2.4577e-01,  2.1373e+00]]])
# Labels: tensor([2632])
# Lengths: tensor([116])
# Inputs shape: torch.Size([1, 116, 685])
# Labels shape: torch.Size([1])
# Batch 1:
# Inputs: tensor([[[ 8.9625e+02,  2.1753e+02,  8.9678e+02,  ..., -5.8807e-03,
#            4.9475e-02,  2.3519e+00],
#          [ 8.9733e+02,  2.1875e+02,  8.9733e+02,  ..., -9.9854e-02,
#            1.0286e-01,  2.1635e+00],
#          [ 8.9633e+02,  2.1754e+02,  8.9713e+02,  ..., -1.1860e-01,
#           -1.8445e-01,  2.1834e+00],
#          ...,
#          [ 8.9923e+02,  2.1355e+02,  8.9923e+02,  ..., -2.0815e-01,
#            4.6787e-01,  2.4673e+00],
#          [ 8.9861e+02,  2.1314e+02,  8.9861e+02,  ..., -2.0713e-01,
#            4.5639e-01,  2.4610e+00],
#          [ 8.9810e+02,  2.1806e+02,  8.9891e+02,  ..., -3.9845e-02,
#            1.5977e-01,  2.3374e+00]]])
# Labels: tensor([786])
# Lengths: tensor([114])
# Inputs shape: torch.Size([1, 114, 685])
# Labels shape: torch.Size([1])
# /tmp/ipykernel_1579769/4277021207.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   keypoints = [torch.tensor(k) for k in keypoints]

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, dim_model, dropout_p, max_len):
        super().__init__()
        
        self.dropout = nn.Dropout(dropout_p)
        
        # Encoding - From formula
        pos_encoding = torch.zeros(max_len, dim_model)
        positions_list = torch.arange(0, max_len, dtype=torch.float).view(-1, 1) # 0, 1, 2, 3, 4, 5
        division_term = torch.exp(torch.arange(0, dim_model, 2).float() * (-math.log(10000.0)) / dim_model) # 1000^(2i/dim_model)

        pos_encoding[:, 0::2] = torch.sin(positions_list * division_term)
        pos_encoding[:, 1::2] = torch.cos(positions_list * division_term)

        # Saving buffer (same as parameter without gradients needed)
        pos_encoding = pos_encoding.unsqueeze(0).transpose(0, 1)
        self.register_buffer("pos_encoding", pos_encoding)
        
    def forward(self, token_embedding: torch.tensor) -> torch.tensor:
        # Residual connection + pos encoding
        return self.dropout(token_embedding + self.pos_encoding[:token_embedding.size(0), :])

# %% [markdown]
# ## 모델 선언 ##

# %%
# 손실 함수 및 옵티마이저 설정
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
class TransformerModel(nn.Module):
    def __init__(self, input_dim, model_dim, num_heads, num_layers, num_classes):
        super(TransformerModel, self).__init__()
        self.input_fc = nn.Linear(input_dim, model_dim)
        encoder_layers = nn.TransformerEncoderLayer(d_model=model_dim, nhead=num_heads, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers)
        self.fc = nn.Linear(model_dim, num_classes)
        self.log_softmax = nn.LogSoftmax(dim=1)
        self.relu = nn.ReLU()  # 추가된 ReLU 활성화 함수
    
    def forward(self, x, src_key_padding_mask=None):
        x = self.input_fc(x)
        x = self.relu(x)  # 활성화 함수 적용
        x = self.transformer_encoder(x, src_key_padding_mask=src_key_padding_mask)
        x = x.mean(dim=1)  # 시퀀스 차원 축소
        x = self.fc(x)
        x = self.log_softmax(x)
        return x
    
model = tl.TransformerModel(input_dim, model_dim, num_heads, num_layers, num_classes).to(device)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

model.to(device)

min_loss = 100
num_epochs = 20

for epoch in range(num_epochs):
    model.train()
    batch_count = 0
    for inputs, labels, lengths in dataloader:
        
        mean = torch.mean(inputs)
        std = torch.std(inputs)
        inputs = (inputs - mean) / std
        
        inputs, labels = inputs.to(device), labels.to(device)  # 입력 데이터와 라벨을 GPU로 전송
        
        # 마스킹 생성
        src_key_padding_mask = (inputs.sum(dim=-1) == 0).to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs, src_key_padding_mask=src_key_padding_mask)
        loss = criterion(outputs, labels)
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        
        ll = loss.item()
        if ll < min_loss:
            min_loss = ll


    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

print(f'Minimum Loss: {min_loss:.4f}')
# Out:
# cuda
# /tmp/ipykernel_1530671/4277021207.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   keypoints = [torch.tensor(k) for k in keypoints]
# Epoch [1/20], Loss: 7.9369
# Epoch [2/20], Loss: 7.1457
# Epoch [3/20], Loss: 6.5580
# Epoch [4/20], Loss: 9.2144
# Epoch [5/20], Loss: 8.8607
# Epoch [6/20], Loss: 8.3717
# Epoch [7/20], Loss: 8.1646
# Epoch [8/20], Loss: 8.1160
# Epoch [9/20], Loss: 8.0122
# Epoch [10/20], Loss: 7.9000
# Epoch [11/20], Loss: 7.8757
# Epoch [12/20], Loss: 7.8605
# Epoch [13/20], Loss: 7.8351
# Epoch [14/20], Loss: 7.8129
# Epoch [15/20], Loss: 7.7821
# Epoch [16/20], Loss: 7.7583
# Epoch [17/20], Loss: 7.7552
# Epoch [18/20], Loss: 7.7464
# Epoch [19/20], Loss: 7.7331
# Epoch [20/20], Loss: 7.7264
# Minimum Loss: 6.3876

# %%
def create_padding_mask(sequences, pad_token=0):
    return (sequences == pad_token)

# 모델을 평가 모드로 전환
model.eval()

# 평가 데이터를 로드 (학습 데이터와 동일한 데이터로 테스트하는 경우 예제)
#dataloader = DataLoader(dataset, batch_size=1, shuffle=False)

# 평가 지표 초기화
correct = 0
total = 0

# 평가 모드에서 그라디언트 계산 비활성화
with torch.no_grad():
    for inputs, labels, lengths in dataloader:
        # 모델 출력 계산
        inputs, labels = inputs.to(device), labels.to(device)
        
        # 패딩 마스크 생성
        src_key_padding_mask = create_padding_mask(inputs[:,:,0])
        src_key_padding_mask = src_key_padding_mask.to(device)
        
        outputs = model(inputs, src_key_padding_mask=src_key_padding_mask)  

        # 소프트맥스 함수로 확률로 변환
        probabilities = torch.nn.functional.softmax(outputs, dim=1)
        
        # 가장 높은 확률을 가진 클래스의 인덱스 구하기
        _, predicted_classes = torch.max(probabilities, 1)
        
        # 정확도 계산
        total += labels.size(0)
        correct += (predicted_classes == labels).sum().item()
        
        # 예측된 클래스 인덱스를 원래 라벨로 변환
        for predicted_class, label in zip(predicted_classes, labels):
            predicted_label = word_list[predicted_class.item()]
            # 출력
            print(f"Actual Label (encoded): {label.item()}")
            print(f"Predicted Label (encoded): {predicted_class.item()}")
            print(f"Predicted Label: {predicted_label}")
            print('-' * 30)
            break
            

# 전체 정확도 출력
accuracy = 100 * correct / total
print(f'Accuracy of the model on the test data: {accuracy:.2f}%')
# Out:
# /tmp/ipykernel_1530671/4277021207.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   keypoints = [torch.tensor(k) for k in keypoints]
# Actual Label (encoded): 2632
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 721
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2098
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1464
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1553
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1038
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2681
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1643
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 281
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 219
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2032
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1997
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 956
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 501
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 414
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 13
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2136
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2648
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1682
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1842
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1453
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 952
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1291
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2120
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2739
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1210
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 985
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1019
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 567
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1655
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1416
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 11
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1694
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1605
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 106
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2050
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 704
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2126
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1222
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1168
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 823
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1422
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1524
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 394
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2585
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 426
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 289
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1415
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 93
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 433
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1299
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 601
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2552
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 296
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1388
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 871
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2260
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2503
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 304
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1725
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1293
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2292
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 109
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 2174
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# Actual Label (encoded): 1660
# Predicted Label (encoded): 112
# Predicted Label: 참외
# ------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 16
#      14 # 평가 모드에서 그라디언트 계산 비활성화
#      15 with torch.no_grad():
# ---> 16     for inputs, labels, lengths in dataloader:
#      17         # 모델 출력 계산
#      18         inputs, labels = inputs.to(device), labels.to(device)
#      20         # 패딩 마스크 생성
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[37], line 40, in SignLanguageDataset.__getitem__(self, index)
#      38 for file_path in json_file_list:
#      39     with open(file_path, 'r') as f:
# ---> 40         data = json.load(f)
#      41     frame_data = data['people']
#      42     if frame_data:
#
# File ~/anaconda3/envs/project/lib/python3.10/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~/anaconda3/envs/project/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/anaconda3/envs/project/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/anaconda3/envs/project/lib/python3.10/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:

# %%
print(max(probabilities[12]))
# Out:
# tensor(0.0012, device='cuda:0')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# CUDA 런타임 설정
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.train()
model.to(device)

min_loss = 100
num_epochs = 14
num_batches_to_train = 100

for epoch in range(num_epochs):
    
    batch_count = 0
    for inputs, labels in dataloader:
        
        mean = torch.mean(inputs)
        std = torch.std(inputs)
        inputs = (inputs - mean) / std
        
        inputs, labels = inputs.to(device), labels.to(device)  # 입력 데이터와 라벨을 GPU로 전송
        
        # 마스킹 생성
        src_key_padding_mask = (inputs.sum(dim=-1) == 0).to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs, src_key_padding_mask=src_key_padding_mask)
        loss = criterion(outputs, labels)
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        
        ll = loss.item()
        if ll < min_loss:
            min_loss = ll

        batch_count += inputs.size(0)
        if batch_count >= num_batches_to_train:
            break

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

print(f'Minimum Loss: {min_loss:.4f}')
# Out:
# cuda
# Epoch [1/14], Loss: 8.6446
# Epoch [2/14], Loss: 5.7826
# Epoch [3/14], Loss: 4.2756
# Epoch [4/14], Loss: 3.6182
# Epoch [5/14], Loss: 3.3103
# Epoch [6/14], Loss: 2.9136
# Epoch [7/14], Loss: 2.6531
# Epoch [8/14], Loss: 2.6265
# Epoch [9/14], Loss: 3.1065
# Epoch [10/14], Loss: 2.7106
# Epoch [11/14], Loss: 3.3941
# Epoch [12/14], Loss: 3.4774
# Epoch [13/14], Loss: 3.7048
# Epoch [14/14], Loss: 3.1528
# Minimum Loss: 2.0218

# %%
# 모델을 평가 모드로 전환
model.eval()

# 평가 데이터를 로드 (학습 데이터와 동일한 데이터로 테스트하는 경우 예제)
dataloader = DataLoader(dataset, batch_size=1, shuffle=False)

# 평가 지표 초기화
correct = 0
total = 0

def create_padding_mask(sequences, pad_token=0):
    return (sequences == pad_token)

# 평가 모드에서 그라디언트 계산 비활성화
with torch.no_grad():
    for inputs, labels in dataloader:
        # 모델 출력 계산
        inputs, labels = inputs.to(device), labels.to(device)
        
        # 패딩 마스크 생성
        src_key_padding_mask = create_padding_mask(inputs[:,:,0])
        src_key_padding_mask = src_key_padding_mask.to(device)
        
        outputs = model(inputs, src_key_padding_mask=src_key_padding_mask)
        # 모델 출력 계산
        print(outputs)
        """ 
        # 소프트맥스 함수로 확률로 변환
        probabilities = torch.nn.functional.softmax(outputs, dim=1)
        """
        
        # 가장 높은 확률을 가진 클래스의 인덱스 구하기
        _, predicted_class = torch.max(outputs, 1)
        
        # 정확도 계산
        total += labels.size(0)
        correct += (predicted_class == labels).sum().item()
        
        # 예측된 클래스 인덱스를 원래 라벨로 변환
        predicted_label = word_list[predicted_class.item()]
        
        # 출력
        print(f"Actual Label (encoded): {labels.item()}")
        print(f"Predicted Label (encoded): {predicted_class.item()}")
        print(f"Predicted Label: {predicted_label}")
        print('-' * 30)

# 전체 정확도 출력
accuracy = 100 * correct / total
print(f'Accuracy of the model on the test data: {accuracy:.2f}%')
# Out:
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2632
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 786
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1994
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2496
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2089
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 493
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 2122
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1383
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 955
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2755
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1119
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 295
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2765
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2342
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 730
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2111
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 721
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1071
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 870
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1879
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2108
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 392
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2580
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 1647
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 709
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 725
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 182
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2418
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1406
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1281
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 285
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 619
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 2098
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 2259
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2671
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 1505
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1752
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1106
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 209
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 895
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2097
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1340
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2250
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1090
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1767
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1300
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 425
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2569
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1464
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 97
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1124
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 308
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2730
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2096
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1944
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1334
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2228
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1930
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 337
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1632
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 212
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1149
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1426
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1008
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1553
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1924
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 681
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 804
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1624
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1690
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 444
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 2180
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 849
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 128
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 284
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1366
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1761
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1957
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1779
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 653
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1038
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2593
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 678
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2264
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1324
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 645
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2133
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2609
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 922
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1425
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2444
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2282
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2238
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2069
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1012
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1917
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 2681
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1330
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 1227
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2230
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2159
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1471
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 544
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 320
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2022
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1975
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2709
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1738
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 659
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1085
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 76
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1835
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1643
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 877
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 820
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 445
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2168
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1161
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 2229
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1140
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1407
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1414
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 642
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 404
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 132
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1219
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2207
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2223
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 281
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 799
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 834
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 2174
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4077, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 2600
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1559
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4077, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 172
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1097
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 798
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1516
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 249
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1449
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 805
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 647
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 913
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 18
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 219
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1250
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 582
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2660
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2167
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2109
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 606
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2028
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 225
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 102
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1615
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1436
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2171
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 1707
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 178
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1781
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2032
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 175
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2610
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2421
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1743
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1044
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1295
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 526
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2659
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 751
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 436
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1458
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 669
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2652
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1587
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4077, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 2299
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1997
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1027
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 0
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 698
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1659
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2382
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1501
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1233
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1607
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1365
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 231
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 53
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2724
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1777
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2362
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1875
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 956
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1081
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2606
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2332
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 143
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1520
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4077, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 403
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2536
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 108
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 232
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1823
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 514
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 586
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 2009
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 637
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 421
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 501
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 188
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 962
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1542
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 267
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1172
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 22
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1402
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2392
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1641
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# ...
# Actual Label (encoded): 454
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1891
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 891
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1481
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1243
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 177
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1412
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1273
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1232
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 345
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1617
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 217
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 445
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1019
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2754
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2690
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2110
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 2078
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1564
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2769
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2733
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1336
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1509
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1326
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1191
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 125
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 149
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2688
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1640
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 567
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2544
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1045
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 181
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2748
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 2356
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 1534
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 785
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2217
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 348
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8815,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 2066
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1658
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3962, -12.4076, -12.8814,  ..., -12.7235, -12.9763, -12.5696]],
#        device='cuda:0')
# Actual Label (encoded): 1716
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1905
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 596
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1754
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 1655
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 371
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 393
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 287
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 359
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2183
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# tensor([[-12.3956, -12.4071, -12.8809,  ..., -12.7229, -12.9759, -12.5692]],
#        device='cuda:0')
# Actual Label (encoded): 2645
# Predicted Label (encoded): 1012
# Predicted Label: 강북구주민지원센터
# ------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 16
#      14 # 평가 모드에서 그라디언트 계산 비활성화
#      15 with torch.no_grad():
# ---> 16     for inputs, labels in dataloader:
#      17         # 모델 출력 계산
#      18         inputs, labels = inputs.to(device), labels.to(device)
#      20         # 패딩 마스크 생성
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[5], line 34, in SignLanguageDataset.__getitem__(self, index)
#      32 for file_path in json_file_list:
#      33     with open(file_path, 'r') as f:
# ---> 34         data = json.load(f)
#      35     frame_data = data['people']
#      36     if frame_data:
#
# File ~/anaconda3/envs/project/lib/python3.10/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~/anaconda3/envs/project/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/anaconda3/envs/project/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/anaconda3/envs/project/lib/python3.10/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:
